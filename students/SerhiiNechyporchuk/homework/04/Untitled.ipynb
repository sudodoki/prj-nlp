# %% [markdown]
# ### todo
# * make search exhaustive inside one sentence

# %%
import pandas as pd
import logging
import spacy 
import spacy.symbols as ss
from spacy import displacy
import en_core_web_lg
from stanfordcorenlp import StanfordCoreNLP
from kanren import run, eq, membero, var, conde, Relation, facts

# %%
nlp = en_core_web_lg.load()

# %%
snlp = StanfordCoreNLP('http://localhost', port=9000)

# %%
dataset = [
    #"For the next four years Orwell mixed journalistic work – mainly for Tribune, The Observer and the Manchester Evening News, though he also contributed to many small-circulation political and literary magazines – with writing his best-known work, Nineteen Eighty-Four, which was published in 1949.",
    "Published July 11, 1960, To Kill a Mockingbird was an immediate bestseller and won great critical acclaim, including the Pulitzer Prize for Fiction in 1961.",
    "His sixth book, The Fault in Our Stars, was released in January 2012",
    "In the 1940s, Salinger confided to several people that he was working on a novel featuring Holden Caulfield, the teenage protagonist of his short story \"Slight Rebellion off Madison\", and The Catcher in the Rye was published on July 16, 1951, by Little, Brown and Company.",
    "In 2003, Hosseini released his first novel, The Kite Runner, the story of a young boy, Amir, struggling to establish a closer rapport with his father and coping with memories of a haunting childhood event. ",
    "Animal Farm: A Fairy Story was published in Britain on 17 August 1945, and a year later in the US, on 26 August 1946.",
    "The trilogy's second book, Catching Fire, was released in September 2009, and its third book, Mockingjay, was released on August 24, 2010.",
    "In September 2008, Scholastic Press released The Hunger Games, the first book of a trilogy by Collins.",
    "In 1973, King's first novel Carrie was accepted by publishing house Doubleday.",
    "In 2000, King published online a serialized horror novel, The Plant.",
    "Also in 2000, he wrote a digital novella, Riding the Bullet, and has said he sees e-books becoming 50% of the market \"probably by 2013 and maybe by 2012\".",
    "In 2006, King published an apocalyptic novel, Cell.",
    "In 2009, King published Ur, a novella written exclusively for the launch of the second-generation Amazon Kindle and available only on Amazon.com, and Throttle, a novella co-written with his son Joe Hill and released later as an audiobook titled Road Rage, which included Richard Matheson's short story \"Duel\".",
]

# %%
pd.read_csv('books.csv', index_col=0)[['authors', 'original_title', 'original_publication_year']]
# Out:
#                                                    authors  \
# book_id
# 1                                          Suzanne Collins
# 2                              J.K. Rowling, Mary GrandPré
# 3                                          Stephenie Meyer
# 4                                               Harper Lee
# 5                                      F. Scott Fitzgerald
# 6                                               John Green
# 7                                           J.R.R. Tolkien
# 8                                            J.D. Salinger
# 9                                                Dan Brown
# 10                                             Jane Austen
# 11                                         Khaled Hosseini
# 12                                           Veronica Roth
# 13                 George Orwell, Erich Fromm, Celâl Üster
# 14                                           George Orwell
# 15       Anne Frank, Eleanor Roosevelt, B.M. Mooyaart-D...
# 16                              Stieg Larsson, Reg Keeland
# 17                                         Suzanne Collins
# 18                 J.K. Rowling, Mary GrandPré, Rufus Beck
# 19                                          J.R.R. Tolkien
# 20                                         Suzanne Collins
# 21                             J.K. Rowling, Mary GrandPré
# 22                                            Alice Sebold
# 23                             J.K. Rowling, Mary GrandPré
# 24                             J.K. Rowling, Mary GrandPré
# 25                             J.K. Rowling, Mary GrandPré
# 26                                               Dan Brown
# 27                             J.K. Rowling, Mary GrandPré
# 28                                         William Golding
# 29           William Shakespeare, Robert           Jackson
# 30                                           Gillian Flynn
# ...                                                    ...
# 70                                        Orson Scott Card
# 71       Mary Wollstonecraft Shelley, Percy Bysshe Shel...
# 72                                            Stephen King
# 73                                         Stephenie Meyer
# 74                                              John Green
# 75                                          Helen Fielding
# 76                 Jane Austen, Tony Tanner, Ros Ballaster
# 77                              Louis Sachar, Louis Sachar
# 78                                       Lauren Weisberger
# 79       Homer, Robert Fagles, E.V. Rieu, Frédéric Mugl...
# 80       Antoine de Saint-Exupéry, Richard Howard, Dom ...
# 81                                         Jeannette Walls
# 82                                            Jon Krakauer
# 83       Charles Dickens, Richard Maxwell, Hablot Knigh...
# 84                                        Michael Crichton
# 85                                        Shel Silverstein
# 86                                            John Grisham
# 87                              Elie Wiesel, Marion Wiesel
# 88                                              John Green
# 89                                         William Goldman
# 90                                             S.E. Hinton
# 91                                           James Dashner
# 92                     Steven D. Levitt, Stephen J. Dubner
# 93                                 Frances Hodgson Burnett
# 94                 Gabriel García Márquez, Gregory Rabassa
# 95                          Oscar Wilde, Jeffrey Eugenides
# 96                                              E.L. James
# 97               Bram Stoker, Nina Auerbach, David J. Skal
# 98                              Stieg Larsson, Reg Keeland
# 99                                              E.L. James
#
#                                             original_title  \
# book_id
# 1                                         The Hunger Games
# 2                 Harry Potter and the Philosopher's Stone
# 3                                                 Twilight
# 4                                    To Kill a Mockingbird
# 5                                         The Great Gatsby
# 6                                   The Fault in Our Stars
# 7                       The Hobbit or There and Back Again
# 8                                   The Catcher in the Rye
# 9                                         Angels & Demons
# 10                                     Pride and Prejudice
# 11                                        The Kite Runner
# 12                                               Divergent
# 13                                    Nineteen Eighty-Four
# 14                              Animal Farm: A Fairy Story
# 15       Het Achterhuis: Dagboekbrieven 14 juni 1942 - ...
# 16                                   Män som hatar kvinnor
# 17                                           Catching Fire
# 18                Harry Potter and the Prisoner of Azkaban
# 19                              The Fellowship of the Ring
# 20                                              Mockingjay
# 21               Harry Potter and the Order of the Phoenix
# 22                                        The Lovely Bones
# 23                 Harry Potter and the Chamber of Secrets
# 24                     Harry Potter and the Goblet of Fire
# 25                    Harry Potter and the Deathly Hallows
# 26                                       The Da Vinci Code
# 27                  Harry Potter and the Half-Blood Prince
# 28                                      Lord of the Flies
# 29       An Excellent conceited Tragedie of Romeo and J...
# 30                                               Gone Girl
# ...                                                    ...
# 70                                            Ender's Game
# 71                 Frankenstein; or, The Modern Prometheus
# 72                                             The Shining
# 73                                                The Host
# 74                                      Looking for Alaska
# 75                                                     NaN
# 76                                   Sense and Sensibility
# 77                                                   Holes
# 78                                   The Devil Wears Prada
# 79                                                Ὀδύσσεια
# 80                                         Le Petit Prince
# 81                                        The Glass Castle
# 82                                           Into the Wild
# 83                                    A Tale of Two Cities
# 84                                           Jurassic Park
# 85                                         The Giving Tree
# 86                                          A Time to Kill
# 87                                 Un di Velt Hot Geshvign
# 88                                             Paper Towns
# 89                                      The Princess Bride
# 90                                           The Outsiders
# 91                                         The Maze Runner
# 92       Freakonomics: A Rogue Economist Explores the H...
# 93                                       The Secret Garden
# 94                                    Cien años de soledad
# 95                              The Picture of Dorian Gray
# 96                                      Fifty Shades Freed
# 97                                                 Dracula
# 98                             Flickan som lekte med elden
# 99                                     Fifty Shades Darker
#
#          original_publication_year
# book_id
# 1                           2008.0
# 2                           1997.0
# 3                           2005.0
# 4                           1960.0
# 5                           1925.0
# 6                           2012.0
# 7                           1937.0
# 8                           1951.0
# 9                           2000.0
# 10                          1813.0
# 11                          2003.0
# 12                          2011.0
# 13                          1949.0
# 14                          1945.0
# 15                          1947.0
# 16                          2005.0
# 17                          2009.0
# 18                          1999.0
# 19                          1954.0
# 20                          2010.0
# 21                          2003.0
# 22                          2002.0
# 23                          1998.0
# 24                          2000.0
# 25                          2007.0
# 26                          2003.0
# 27                          2005.0
# 28                          1954.0
# 29                          1595.0
# 30                          2012.0
# ...                            ...
# 70                          1985.0
# 71                          1818.0
# 72                          1977.0
# 73                          2008.0
# 74                          2005.0
# 75                          1996.0
# 76                          1811.0
# 77                          1998.0
# 78                          2003.0
# 79                          -720.0
# 80                          1946.0
# 81                          2005.0
# 82                          1996.0
# 83                          1859.0
# 84                          1990.0
# 85                          1964.0
# 86                          1989.0
# 87                          1958.0
# 88                          2008.0
# 89                          1973.0
# 90                          1967.0
# 91                          2009.0
# 92                          2005.0
# 93                          1911.0
# 94                          1967.0
# 95                          1891.0
# 96                          2012.0
# 97                          1897.0
# 98                          2006.0
# 99                          2011.0
#
# [99 rows x 3 columns]

# %%
test = dataset[-1]

# %%
displacy.render(nlp(test), jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="8975" height="1099.5" style="max-width: none; height: 1099.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">2009,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">King</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">published</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Ur,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">novella</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">written</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">exclusively</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">launch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">second-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">generation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Amazon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Kindle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">available</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Amazon.com,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Throttle,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">novella</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">co-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">written</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fi

# %%
BOOK_NAME = '__BOOK_NAME__'
REL_DATE = '__REL_DATE__'
variables = set([BOOK_NAME, REL_DATE])
REL_SYN = set(['release', 'publish', 'accept'])
BOOK_SYN = set(['book', 'novel'])
RULES = [
    [((REL_SYN, None, None), (ss.nsubjpass, ss.dobj), (BOOK_NAME, ss.WORK_OF_ART)),
     ((REL_SYN, None, None), (ss.prep,), (['in', 'on'], None)),
     ((['in', 'on'], None, None), (ss.pobj,), (REL_DATE, ss.DATE))],
    
    [((REL_SYN, None,None), (ss.nsubjpass,ss.dobj), (BOOK_SYN, None, None)),
     ((BOOK_SYN, None,None), (ss.appos,), (BOOK_NAME, None, ss.PROPN)),
     ((REL_SYN, None, None), (ss.prep,), (['in', 'on'], None, None)),
     ((['in', 'on'], None, None), (ss.pobj,), (REL_DATE, ss.DATE, None))],
    
    #[((['release'], None), (ss.dobj,), (['novel'], None)),
    # ((['novel'], None), (ss.appos,), (BOOK_NAME, ss.WORK_OF_ART)),
    # ((['release'], None), (ss.prep,), (['in'], None)),
    # ((['in'], None), (ss.pobj,), (REL_DATE, ss.DATE))]
]

# %%
def is_variable(rchild_lemmas):
    return isinstance(rchild_lemmas, str) and rchild_lemmas in variables

def child_eq(rdeps, rchild, child):
    (rchild_lemmas, rchild_ent, rchild_pos) = rchild
    (child_lemma, child_ent, child_pos, dep) = child.lemma_, child.ent_type, child.pos, child.dep
    if is_variable(rchild_lemmas):
        if (not rchild_pos or rchild_pos == child_pos) and (not rchild_ent or rchild_ent == child_ent) and (dep in rdeps):
            return {rchild_lemmas: child}
        else:
             return False
    else:
        return  child_lemma in rchild_lemmas and (not rchild_pos or rchild_pos == child_pos) and (not rchild_ent or rchild_end == child_ent) and (dep in rdeps)

def match():
    for ri, rule in enumerate(RULES):
        print("Rule ", ri)
        matches = []
        tree = nlp(test)
        bindings = {}
        for subrule in rule:
            ((rhead_lemmas, rhead_ent, _), rdeps, rchild) = subrule
            #print(subrule)
            matched = False
            for tok in tree:
                same_lemma = tok.lemma_ in rhead_lemmas
                same_ent = (not rhead_ent or (rhead_ent == tok.pos))
                same_child = None
                #print("  ", tok)
                for ch in tok.children:
                    #print("    ", rchild, ch)
                    res =  child_eq(rdeps, rchild, ch)
                    if res:
                        if isinstance(res, dict):
                            bindings.update(res)
                        same_child = res
                #print("  ", same_lemma, same_ent, same_child)
                matched = same_lemma and same_ent and same_child
                if matched:
                    break
            matches.append(matched)
        print("MATCHES", matches)
        if all(matches):
            return bindings
match()
# Out:
# Rule  0
# MATCHES [False, False, True, {'__REL_DATE__': 2009}]

# %%
prep = Relation('prep') 
pobj = Relation('pobj')
facts(prep, ('released', 'in'))
facts(pobj, ('in', 'January'))
             
x = var()
y = var()
run(1, x, 
    prep('released', y),
    pobj(y, x)
   )
# Out:
# ('January',)

# %%
[(tok.head.text, tok.dep_, tok.text, tok.ent_type_, tok.pos_) for tok in list(nlp(test))]
# Out:
# [('published', 'prep', 'In', '', 'ADP'),
#  ('In', 'pobj', '2006', 'DATE', 'NUM'),
#  ('published', 'punct', ',', '', 'PUNCT'),
#  ('published', 'nsubj', 'King', '', 'PROPN'),
#  ('published', 'ROOT', 'published', '', 'VERB'),
#  ('novel', 'det', 'an', '', 'DET'),
#  ('novel', 'amod', 'apocalyptic', '', 'ADJ'),
#  ('published', 'dobj', 'novel', '', 'NOUN'),
#  ('novel', 'punct', ',', '', 'PUNCT'),
#  ('novel', 'appos', 'Cell', 'PERSON', 'PROPN'),
#  ('published', 'punct', '.', '', 'PUNCT')]

# %%
for ent in nlp(test).ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# 2006 3 7 DATE
# Cell 46 50 PERSON

# %%
snlp.annotate(dataset[0])
# Out:
# '{"sentences":[{"index":0,"parse":"(ROOT\\n  (S\\n    (VP\\n      (VP (VBN Published)\\n        (NP-TMP (NNP July) (CD 11) (, ,) (CD 1960))\\n        (, ,)\\n        (S\\n          (VP (TO To)\\n            (VP (VB Kill)\\n              (SBAR\\n                (S\\n                  (NP (DT a) (NNP Mockingbird))\\n                  (VP (VBD was)\\n                    (NP (DT an) (JJ immediate) (NN bestseller)))))))))\\n      (CC and)\\n      (VP (VBD won)\\n        (NP\\n          (NP (JJ great) (JJ critical) (NN acclaim))\\n          (, ,)\\n          (PP (VBG including)\\n            (NP\\n              (NP (DT the) (NNP Pulitzer) (NNP Prize))\\n              (PP (IN for)\\n                (NP\\n                  (NP (NN Fiction))\\n                  (PP (IN in)\\n                    (NP (CD 1961))))))))))\\n    (. .)))","basicDependencies":[{"dep":"ROOT","governor":0,"governorGloss":"ROOT","dependent":14,"dependentGloss":"bestseller"},{"dep":"csubj","governor":14,"governorGloss":"bestseller","dependent":1,"dependentGloss":"Published"},{"dep":"nmod:tmod","governor":1,"governorGloss":"Published","dependent":2,"dependentGloss":"July"},{"dep":"nummod","governor":2,"governorGloss":"July","dependent":3,"dependentGloss":"11"},{"dep":"punct","governor":2,"governorGloss":"July","dependent":4,"dependentGloss":","},{"dep":"nummod","governor":2,"governorGloss":"July","dependent":5,"dependentGloss":"1960"},{"dep":"punct","governor":1,"governorGloss":"Published","dependent":6,"dependentGloss":","},{"dep":"mark","governor":8,"governorGloss":"Kill","dependent":7,"dependentGloss":"To"},{"dep":"advcl","governor":1,"governorGloss":"Published","dependent":8,"dependentGloss":"Kill"},{"dep":"det","governor":10,"governorGloss":"Mockingbird","dependent":9,"dependentGloss":"a"},{"dep":"dobj","governor":8,"governorGloss":"Kill","dependent":10,"dependentGloss":"Mockingbird"},{"dep":"cop","governor":14,"governorGloss":"bestseller","dependent":11,"dependentGloss":"was"},{"dep":"det","governor":14,"governorGloss":"bestseller","dependent":12,"dependentGloss":"an"},{"dep":"amod","governor":14,"governorGloss":"bestseller","dependent":13,"dependentGloss":"immediate"},{"dep":"cc","governor":14,"governorGloss":"bestseller","dependent":15,"dependentGloss":"and"},{"dep":"conj","governor":14,"governorGloss":"bestseller","dependent":16,"dependentGloss":"won"},{"dep":"amod","governor":19,"governorGloss":"acclaim","dependent":17,"dependentGloss":"great"},{"dep":"amod","governor":19,"governorGloss":"acclaim","dependent":18,"dependentGloss":"critical"},{"dep":"dobj","governor":16,"governorGloss":"won","dependent":19,"dependentGloss":"acclaim"},{"dep":"punct","governor":14,"governorGloss":"bestseller","dependent":20,"dependentGloss":","},{"dep":"case","governor":24,"governorGloss":"Prize","dependent":21,"dependentGloss":"including"},{"dep":"det","governor":24,"governorGloss":"Prize","dependent":22,"dependentGloss":"the"},{"dep":"compound","governor":24,"governorGloss":"Prize","dependent":23,"dependentGloss":"Pulitzer"},{"dep":"nmod","governor":14,"governorGloss":"bestseller","dependent":24,"dependentGloss":"Prize"},{"dep":"case","governor":26,"governorGloss":"Fiction","dependent":25,"dependentGloss":"for"},{"dep":"nmod","governor":24,"governorGloss":"Prize","dependent":26,"dependentGloss":"Fiction"},{"dep":"case","governor":28,"governorGloss":"1961","dependent":27,"dependentGloss":"in"},{"dep":"nmod","governor":24,"governorGloss":"Prize","dependent":28,"dependentGloss":"1961"},{"dep":"punct","governor":14,"governorGloss":"bestseller","dependent":29,"dependentGloss":"."}],"enhancedDependencies":[{"dep":"ROOT","governor":0,"governorGloss":"ROOT","dependent":14,"dependentGloss":"bestseller"},{"dep":"csubj","governor":14,"governorGloss":"bestseller","dependent":1,"dependentGloss":"Published"},{"dep":"csubj","governor":16,"governorGloss":"won","dependent":1,"dependentGloss":"Published"},{"dep":"nmod:tmod","governor":1,"governorGloss":"Published","dependent":2,"dependentGlo ...
