# %%
from nltk.corpus import sentiwordnet as swn
from nltk.corpus import wordnet as wn
import numpy as np
import nltk
import spacy
import spacy.symbols as ss
from spacy import displacy
import en_core_web_lg
import pandas as pd
pd.set_option('display.max_colwidth', 300)

# %%
nltk.download('sentiwordnet')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     /usr/local/lib/nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/local/lib/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
nlp = en_core_web_lg.load()

# %%
df = pd.read_table("../../../../../tasks/02-structural-linguistics/examiner-headlines.txt", names=['title'])[:50]

# %%
df = df.assign(doc=df['title'].apply(nlp))

# %%
def has_proper_name(doc):
    return len([tok for tok in doc if tok.pos == ss.PROPN]) != 0

# %%
df = df.assign(has_propn = df['doc'].apply(lambda x: has_proper_name(x)))

# %%
def spacy_pos2wordnet_pos(pos):
    if pos == ss.NOUN:
        return wn.NOUN
    elif pos == ss.VERB:
        return wn.VERB
    elif pos == ss.ADV:
        return wn.ADV
    elif pos == ss.ADJ:
        return wn.ADJ

# %%
def is_content_word(tok):
    return tok.pos == ss.NOUN or tok.tag_.startswith('V') or tok.pos == ss.ADJ or tok.pos == ss.ADV

# %%
def get_mean_sentiment(tok, topn):
    wn_pos = spacy_pos2wordnet_pos(tok.pos)
    if not wn_pos:
        return np.nan
    synsets = list(swn.senti_synsets(tok.lemma_, wn_pos))[:topn]
    if len(synsets) == 0:
        return np.nan
    sentiments = map(lambda node: node.pos_score(), synsets)
    mean_sentiment = np.mean(list(sentiments))
    return mean_sentiment

# %%
def has_positive_sentiment(doc):
    content_words = filter(is_content_word, doc)
    sentiments = [get_mean_sentiment(tok, topn=5) for tok in content_words]
    if len(sentiments) == 0:
        return False
    else:
        return np.nanmax(sentiments) >= 0.5

# %%
df.assign(sentiment = df['doc'].apply(lambda x: has_positive_sentiment(x)))
# Out:
#                                                                                title  \
# 0                     Halep enters Rogers Cup final in straight sets win over Errani
# 1                                                         The phantoms of St. Mary's
# 2                     Talladega turmoil could spell trouble for NASCAR's Chase field
# 3                                     Burn those calories! Try the Very Steep Trail.
# 4                                       It's the end of the world... and I feel fine
# 5                                      2011-2012 NHL team preview: Detroit Red Wings
# 6               Cal coach Jeff Tedford taking a different approach in 2010 -- Part 1
# 7                                     Google science fair to encourage STEM learning
# 8                                      SF Beer Week 2013: what's for dinner (part 2)
# 9         Jersey Shore Season 6 cast's salaries revealed; More than President Obama!
# 10                                                              Homemade Fish Sticks
# 11                                                           Greening up your winter
# 12                                               Diy repurposed sewing table project
# 13                         Furniture and cabinet design trends; where is it heading?
# 14                                        Xbox 720 announcement at E3 2013 indicated
# 15                       Top ten books in the intelligent design controversy 2009 #1
# 16                                                       A guide to a banking career
# 17                   Game of Thrones: Compendium of characters and their connections
# 18                                  Sweeter than 'The Hummingbird and the Honey Bee'
# 19        NU Hosts Illinois in First Nationally Televised Network Game at Welsh-Ryan
# 20  Brazilian & bikini waxing how to choose an sf bay area hair removal salon or spa
# 21                                                 Back to school, gluten-free style
# 22   President Obama's Inauguration: Kelly Clarkson sings 'My Country, 'Tis of Thee'
# 23                                           Use Affirmations for Positive Mothering
# 24                         Pamper Yourself like a Pharaoh at the Ritz Carlton Denver
# 25                 This year's Bloomsday in Chicago event and the Poetry Pentathalon
# 26               Police warn public of Toronto man who failed to disclose HIV status
# 27      Oosterhouse fiancée Amy Smart lists Beverly Hills home for $1.4 mil (photos)
# 28      Obstacle holding back CBD Oil and medical marijuana from becoming mainstream
# 29                  Rescued blind dog looking for her seeing eye person/guide person
# 30                                                          Tekkoshocon IX: AMV room
# 31        Study finds that young Americans are Democrats, want government to do more
# 32                                                Cell phones and other misdemeanors
# 33                                   'Once Upon a Time' season 3 Tinkerbell spoilers
# 34                                              Free fishing bill signed by Christie
# 35    Recall: Weight loss pill Bethel 30 is recalled due to a hidden drug ingredient
# 36                                                  In the beginning there was trust
# 37                                                             Hawks cooled by Spurs
# 38                                               Bonnaroo 2010 live report: Thursday
# 39                                             How it all plays out on Church Street
# 40                                                      Confessions from the balcony
# 41        'Psych' season premiere date revealed as 'Psych: The Musical' airing looms
# 42                                            Magnificent Mile Art Fest set for July
# 43                  What's new at Lake Tahoe's Alpine Meadows ski resort this season
# 44                                          War becomes personal in Freehold's Henry
# 45                         Laugh in iambic pentameter at this comic take on the Bard
# 46                                                    Wedding season springs forward
# 47                                         6 new must-have games for Windows Phone 7
# 48                                        Serious Weight Loss With These Simple Tips
# 49     Cops: Man, 25, dies after crashing into steel guardrail, tree at a high speed
#
#                                                                                                         doc  \
# 0                                (Halep, enters, Rogers, Cup, final, in, straight, sets, win, over, Errani)
# 1                                                                        (The, phantoms, of, St., Mary, 's)
# 2                                (Talladega, turmoil, could, spell, trouble, for, NASCAR, 's, Chase, field)
# 3                                               (Burn, those, calories, !, Try, the, Very, Steep, Trail, .)
# 4                                               (It, 's, the, end, of, the, world, ..., and, I, feel, fine)
# 5                                               (2011, -, 2012, NHL, team, preview, :, Detroit, Red, Wings)
# 6                        (Cal, coach, Jeff, Tedford, taking, a, different, approach, in, 2010, --, Part, 1)
# 7                                                    (Google, science, fair, to, encourage, STEM, learning)
# 8                                           (SF, Beer, Week, 2013, :, what, 's, for, dinner, (, part, 2, ))
# 9              (Jersey, Shore, Season, 6, cast, 's, salaries, revealed, ;, More, than, President, Obama, !)
# 10                                                                                 (Homemade, Fish, Sticks)
# 11                                                                             (Greening, up, your, winter)
# 12                                                                (Diy, repurposed, sewing, table, project)
# 13                                  (Furniture, and, cabinet, design, trends, ;, where, is, it, heading, ?)
# 14                                                       (Xbox, 720, announcement, at, E3, 2013, indicated)
# 15                                 (Top, ten, books, in, the, intelligent, design, controversy, 2009, #, 1)
# 16                                                                       (A, guide, to, a, banking, career)
# 17                              (Game, of, Thrones, :, Compendium, of, characters, and, their, connections)
# 18                                            (Sweeter, than, ', The, Hummingbird, and, the, Honey, Bee, ')
# 19               (NU, Hosts, Illinois, in, First, Nationally, Televised, Network, Game, at, Welsh, -, Ryan)
# 20        (Brazilian, &, bikini, waxing, how, to, choose, an, sf, bay, area, hair, removal, salon, or, spa)
# 21                                                            (Back, to, school, ,, gluten, -, free, style)
# 22  (President, Obama, 's, Inauguration, :, Kelly, Clarkson, sings, ', My, Country, ,, ', Tis, of, Thee, ')
# 23                                                            (Use, Affirmations, for, Positive, Mothering)
# 24                                     (Pamper, Yourself, like, a, Pharaoh, at, the, Ritz, Carlton, Denver)
# 25                           (This, year, 's, Bloomsday, in, Chicago, event, and, the, Poetry, Pentathalon)
# 26                         (Police, warn, public, of, Toronto, man, who, failed, to, disclose, HIV, status)
# 27          (Oosterhouse, fiancée, Amy, Smart, lists, Beverly, Hills, home, for, $, 1.4, mil, (, photos, ))
# 28                 (Obstacle, holding, back, CBD, Oil, and, medical, marijuana, from, becoming, mainstream)
# 29                          (Rescued, blind, dog, looking, for, her, seeing, eye, person, /, guide, person)
# 30                                                                          (Tekkoshocon, IX, :, AMV, room)
# 31                (Study, finds, that, young, Americans, are, Democrats, ,, want, government, to, do, more)
# 32                                                                 (Cell, phones, and, other, misdemeanors)
# 33                                             (', Once, Upon, a, Time, ', season, 3, Tinkerbell, spoilers)
# 34                                                              (Free, fishing, bill, signed, by, Christie)
# 35          (Recall, :, Weight, loss, pill, Bethel, 30, is, recalled, due, to, a, hidden, drug, ingredient)
# 36                                                                  (In, the, beginning, there, was, trust)
# 37                                                                               (Hawks, cooled, by, Spurs)
# 38                                                              (Bonnaroo, 2010, live, report, :, Thursday)
# 39                                                           (How, it, all, plays, out, on, Church, Street)
# 40                                                                        (Confessions, from, the, balcony)
# 41         (', Psych, ', season, premiere, date, revealed, as, ', Psych, :, The, Musical, ', airing, looms)
# 42                                                           (Magnificent, Mile, Art, Fest, set, for, July)
# 43                         (What, 's, new, at, Lake, Tahoe, 's, Alpine, Meadows, ski, resort, this, season)
# 44                                                        (War, becomes, personal, in, Freehold, 's, Henry)
# 45                                    (Laugh, in, iambic, pentameter, at, this, comic, take, on, the, Bard)
# 46                                                                      (Wedding, season, springs, forward)
# 47                                                   (6, new, must, -, have, games, for, Windows, Phone, 7)
# 48                                                       (Serious, Weight, Loss, With, These, Simple, Tips)
# 49     (Cops, :, Man, ,, 25, ,, dies, after, crashing, into, steel, guardrail, ,, tree, at, a, high, speed)
#
#     has_propn  sentiment
# 0        True      False
# 1        True      False
# 2        True      False
# 3        True      False
# 4       False      False
# 5        True      False
# 6        True      False
# 7        True      False
# 8        True      False
# 9        True      False
# 10      False      False
# 11      False      False
# 12       True      False
# 13      False      False
# 14       True      False
# 15      False      False
# 16      False      False
# 17       True      False
# 18       True       True
# 19       True      False
# 20       True      False
# 21      False      False
# 22       True      False
# 23       True      False
# 24       True      False
# 25       True      False
# 26       True      False
# 27       True      False
# 28       True      False
# 29      False      False
# 30       True      False
# 31       True      False
# 32       True      False
# 33       True      False
# 34       True      False
# 35       True      False
# 36      False      False
# 37      False      False
# 38       True      False
# 39       True      False
# 40      False      False
# 41       True      False
# 42       True      False
# 43       True      False
# 44       True      False
# 45       True      False
# 46      False      False
# 47       True      False
# 48       True      False
# 49      False      False

# %%
list(swn.senti_synsets('enter', 'v'))
# Out:
# [SentiSynset('enter.v.01'),
#  SentiSynset('enter.v.02'),
#  SentiSynset('enroll.v.01'),
#  SentiSynset('figure.v.02'),
#  SentiSynset('record.v.01'),
#  SentiSynset('enter.v.06'),
#  SentiSynset('accede.v.02'),
#  SentiSynset('insert.v.01'),
#  SentiSynset('embark.v.02')]

# %%
[(tok.text, tok.tag_) for tok in nlp("It's the end of the world... and I feel fine")]
# Out:
# [('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('the', 'DT'),
#  ('end', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('...', 'NFP'),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ('feel', 'VBP'),
#  ('fine', 'JJ')]
