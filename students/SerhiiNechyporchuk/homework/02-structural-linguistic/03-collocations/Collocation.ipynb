# %%
from nltk.corpus import sentiwordnet as swn
from nltk.corpus import wordnet as wn
import numpy as np
import nltk
import spacy
import spacy.symbols as ss
from spacy import displacy
import en_core_web_lg
import pandas as pd
from tqdm import tqdm_notebook, tqdm_pandas
from collections import Counter
pd.set_option('display.max_colwidth', 300)
pd.set_option('display.max_rows', 300)

# %%
tqdm_notebook().pandas()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
nlp = en_core_web_lg.load()

# %%
df = pd.read_table("../../../../../tasks/02-structural-linguistics/blog2008.txt", names=['text'])[:]

# %%
df = df.assign(doc=df.text.progress_apply(nlp))
# Out:
# HBox(children=(IntProgress(value=0, max=300894), HTML(value='')))

# %%
say_syns = set([
    "say", "tell", "speak", "claim", "communicate", "talk",
    "explain", "verbalize", "chat", "communicate", "describe",
    "express", "advertise", "broadcast", "declare", "name"])
def find_collocations(doc, say_syns=say_syns):
    collocations = []
    for tok in doc:
        if tok.lemma_ in say_syns and tok.pos == ss.VERB:
            for verb_child in tok.children:
                if verb_child.pos == ss.ADV and verb_child.text.endswith('ly'):
                    collocations.append((tok.lemma_, verb_child.lemma_))
                    for adv_child in verb_child.children:
                        if adv_child.dep == ss.conj:
                            collocations.append((tok.lemma_, adv_child.lemma_))
    return collocations

# %%
df = df.assign(collocations = df['doc'].progress_apply(find_collocations))
# Out:
# HBox(children=(IntProgress(value=0, max=300894), HTML(value='')))

# %%
df[df['collocations'].progress_apply(lambda x: len(x) != 0)]
# Out:
# HBox(children=(IntProgress(value=0, max=300894), HTML(value='')))
#                                                                                                                                                                                                                                                                                                                text  \
# 40                                                                                                                           The electoral commission initially claimed that roughly a quarter of returning officers disappeared for 36 hours without announcing results and had switched off their mobile phones .
# 176                                                                                                                                                                    The government still is n't saying definitively but it would appear that they are giving credence to reports that Bhutto was shot to death .
# 264                                                                                                                                                                                                                                                           These pages recently said goodbye to global warming .
# 725                                                                                                                                                                                                                        Not overtly and not directly , but she will speak in code saying that Obama ca n't win .
# 1147                                                                                                                                                                                                  By the media continually telling the public that they want change it soon became a self-fulfilling prophecy .
# 1547                                                                                                                                                   In the name of academic freedom of speech , Ahmadinejad was invited and subsequently spoke to an appreciative audience at Columbia University in September .
# 1555                                                                                                                                          When you bring this question up , you 're really saying , ' You 're a racist ' or ' Are you a racist ? '\nAnd the answer is , ' No , I 'm not a racist , '  he said .
# 1782                                                                                                                                                                             John McCain had one of his better debates , especially when talking about foreign policy and his record as a fiscal conservative .
# 1795                    He cites a footnote in an essay by by Dr. Gerd Puin on p . 743 of Ibn Warraq 's 2002 book What The Koran Really Says : Angelika Neuwirth has given the impression the photographs taken in order to build up the " Koran Archiv " in Munich ... were destroyed at the end of World War II .
# 2298                                                                                                                                                                                                   Mrs. Clinton quickly said she had meant no slight , and on Monday she issued a statement proposing a truce .
# 2688                                                                                                                                                   This disconent was fed by people like Carter who talked consistently about America 's better days being behind it and that we must learn to live with less .
# 20962                                               He 's risen so quickly , but his history has n't been bogged down with an association of Chicago politics and I ca n't tell you why exactly , except perhaps that some may have bought into the established narrative and ca n't separate themselves from it .
# 21056                                                                                                                                                                                             I habitually told my small groups of supporters , " If I even make a misleading statement , do n't support me . "
# 21183                                                                                                                                                                                                            I think I probably speak for a lot of Americans when I say I 'm fed up with this double standard .
# 21266                                                                                                                                                                  Officials previously said al-Qahtani had been subjected to a harsh interrogation authorized by former Defense Secretary Donald H. Rumsfeld .
# 21385                                                                                                                           While Obama has repeatedly said " nobody clapped " and that his message was met with silence , the record from that speech from the Detroit Economic Club tells a different story .
# ...                                                                                                                                                                                                                                                                                                             ...
# 285693                                                                                                                                                                                                                                              John McCain does n't understand ,  the announcer says sternly :
# 285721                                                                                                                            I 'm told reliably by people in both the Obama and Clinton camps that there were discussions this weekend -- in advance of Hillary 's appearance on Monday -- on how to proceed .
# ...
# 6249                                   [(say, gleefully)]
# 6387                              [(communicate, freely)]
# 6554                                 [(speak, privately)]
# 6640            [(speak, recently), (speak, exclusively)]
# 6674                                [(say, convincingly)]
# 6959                                   [(say, literally)]
# 7021                                [(say, triumphantly)]
# 7210                                 [(talk, forcefully)]
# 7397                                [(express, actually)]
# 7543                                  [(say, ultimately)]
# 7663                               [(say, interestingly)]
# 7921                                    [(say, probably)]
# 7943                               [(say, unequivocally)]
# 8039                                   [(talk, actively)]
# 8203                                   [(talk, blithely)]
# 8258                                [(express, famously)]
# 8716                                    [(claim, surely)]
# 8823                                  [(say, eventually)]
# 8898                              [(speak, infrequently)]
# 8979                                  [(say, previously)]
# 9102                               [(declare, ominously)]
# 9106                                     [(tell, flatly)]
# 9189                                     [(say, clearly)]
# 9279                                   [(talk, directly)]
# 9290                                  [(say, repeatedly)]
# 9847                              [(describe, variously)]
# 9875                               [(declare, gleefully)]
# 9885                                   [(say, typically)]
# 9906                                    [(say, famously)]
# 9957                                 [(explain, clearly)]
# 9988    [(describe, eloquently), (describe, desperately)]
# 10143                              [(say, unfortunately)]
# 10147                                [(describe, simply)]
# 10372                                  [(say, basically)]
# 10412                                     [(say, really)]
# 10624                                     [(say, firmly)]
# 10703                                       [(say, only)]
# 11040                                 [(claim, solemnly)]
# 11041                               [(claim, previously)]
# 11282                                 [(tell, privately)]
# 11516                                       [(say, only)]
# 11574                                   [(say, probably)]
# 11773                                    [(say, clearly)]
# 12151                                 [(explain, easily)]
# 12850                                  [(say, currently)]
# 12900                                  [(speak, briefly)]
# 12928                                [(say, differently)]
# 13280                                    [(tell, glibly)]
# 13557                               [(say, dismissively)]
# 13768                                  [(claim, falsely)]
# 13769                                     [(say, really)]
# 13790                                 [(say, eventually)]
# 13799                                 [(tell, willingly)]
# 13816                                   [(say, directly)]
# 14080                              [(tell, subsequently)]
# 14112                                    [(talk, rarely)]
# 14120                                    [(claim, oddly)]
# 14219                                     [(speak, only)]
# 14306                                     [(say, simply)]
# 14413                                    [(talk, really)]
# 14521                                [(tell, repeatedly)]
# 15150                                  [(say, obviously)]
# 15207                                 [(speak, fiercely)]
# 15218                                 [(speak, fiercely)]
# 15220                               [(speak, eloquently)]
# 15258                                   [(say, publicly)]
# 15349                                  [(tell, actually)]
# 15391                                   [(tell, bluntly)]
# 15392                                     [(say, really)]
# 15469                               [(express, actually)]
# 15741                                   [(say, actually)]
# 15971                                    [(say, finally)]
# 16092                                  [(tell, probably)]
# 16117                              [(talk, particularly)]
# 16311                                  [(tell, recently)]
# 16349                                   [(say, probably)]
# 16453                                     [(say, simply)]
# 16461                                     [(say, flatly)]
# 16495                            [(express, notoriously)]
# 16519                                  [(claim, falsely)]
# 16529                                [(say, responsibly)]
# 16638                                 [(say, apparently)]
# 16738                               [(claim, apparently)]
# 16891                               [(say, dismissively)]
# 17059                             [(communicate, really)]
# 17129                                   [(say, stupidly)]
# 17233                                  [(tell, recently)]
# 17336                                  [(tell, probably)]
# 17497                            [(explain, necessarily)]
# 17608                                 [(say, originally)]
# 17941                               [(express, recently)]
# 18051                                [(tell, apparently)]
# 18168                               [(declare, publicly)]
# 18253                                  [(describe, only)]
# 18270                             [(declare, arrogantly)]
# 18299                               [(declare, famously)]
# 18351                                 [(say, explicitly)]
# 18431                                   [(say, actually)]
# 18533                                     [(say, simply)]
# 18896                                   [(say, famously)]
# 19069                              [(speak, technically)]
# 19254                                 [(explain, easily)]
# 19412                                 [(say, repeatedly)]
# 19443                                   [(talk, frankly)]
# 19476                                 [(tell, privately)]
# 19765                                 [(say, especially)]
# 19940                             [(declare, officially)]
# 20181                                 [(say, repeatedly)]
# 20361                             [(declare, forcefully)]
# 20367                                 [(declare, surely)]
# 20962                                   [(tell, exactly)]
# 21056                                [(tell, habitually)]
# 21183                                 [(speak, probably)]
# 21266                                 [(say, previously)]
# 21385                                 [(say, repeatedly)]
# ...                                                   ...
# 285693                                   [(say, sternly)]
# 285721                                 [(tell, reliably)]
# 285744                                  [(say, suddenly)]
# 285912                                  [(say, somberly)]
# 285954                                   [(talk, merely)]
# 286054                                 [(tell, actually)]
# 286141                                   [(tell, barely)]
# 286209                                   [(say, sternly)]
# 286283                               [(speak, currently)]
# 286287                                  [(say, recently)]
# 286335                                  [(say, recently)]
# 286349                                   [(tell, barely)]
# 286379                                  [(say, recently)]
# 286382               [(say, actually), (say, repeatedly)]
# 286781                                 [(say, mockingly)]
# 286858                                    [(say, openly)]
# 287055                                    [(say, merely)]
# 287244                                  [(say, actually)]
# 287250                                  [(say, recently)]
# 287254                                [(say, explicitly)]
# 287426                              [(claim, frequently)]
# 288157                                 [(speak, plainly)]
# 288201                                [(speak, directly)]
# 288219                                [(speak, directly)]
# 288277                                  [(say, severely)]
# 288311                                   [(say, sternly)]
# 288437                                     [(tell, only)]
# 288534                                  [(say, politely)]
# 288540                                [(say, apparently)]
# 288542                                  [(say, recently)]
# 288576                                [(claim, actually)]
# 289047             [(talk, sensibly), (talk, coherently)]
# 289066                                  [(say, directly)]
# 289102                               [(express, clearly)]
# 289339                              [(declare, publicly)]
# 289353                  [(say, actually), (say, clearly)]
# 289417                                [(claim, publicly)]
# 289476                                   [(say, finally)]
# 289477                            [(communicate, poorly)]
# 289692                           [(describe, personally)]
# 289710                                [(say, apparently)]
# 289730                                   [(tell, really)]
# 289731                                [(say, strikingly)]
# 289991                                   [(tell, simply)]
# 290104                        [(advertise, aggressively)]
# 290262                              [(say, definitively)]
# 290269                                  [(say, actually)]
# 290499                                   [(tell, simply)]
# 290555                                  [(say, famously)]
# 290605                                    [(say, surely)]
# 290869                                  [(say, recently)]
# 290959                                  [(say, suddenly)]
# 291005                                [(say, explicitly)]
# 291030                                [(speak, directly)]
# 291109                               [(say, essentially)]
# 291114                                [(declare, flatly)]
# 291282                                   [(say, sternly)]
# 291439                                  [(say, actually)]
# 291483                                   [(tell, simply)]
# 291584                              [(talk, responsibly)]
# 291756                                  [(say, actually)]
# 291815                                   [(tell, simply)]
# 291897                             [(tell, specifically)]
# 291914                                    [(say, grimly)]
# 291916                                [(say, repeatedly)]
# 291922                                [(claim, formerly)]
# 291950                                  [(say, recently)]
# 292079                                  [(say, actually)]
# 292196                                   [(tell, simply)]
# 292328                                  [(tell, falsely)]
# 292397                              [(speak, truthfully)]
# 292459                             [(talk, consistently)]
# 292540                                  [(say, actually)]
# 293057                                  [(say, recently)]
# 293222                               [(say, indignantly)]
# 293268        [(declare, openly), (communicate, finally)]
# 293323                               [(say, indignantly)]
# 293350                             [(tell, dramatically)]
# 293375                                    [(say, merely)]
# 293427                                    [(say, merely)]
# 293455                                    [(say, merely)]
# 293495                               [(say, immediately)]
# 293650                              [(claim, previously)]
# 293680                                [(claim, formerly)]
# 293684                  [(claim, sweetly), (say, merely)]
# 293706                                  [(say, actually)]
# 293744                                  [(say, actually)]
# 293756                              [(claim, previously)]
# 293799                                [(say, explicitly)]
# 293802                                [(say, explicitly)]
# 293806                                [(say, explicitly)]
# 293910                                  [(say, actually)]
# 293993                                  [(say, actually)]
# 294344                                    [(say, really)]
# 294606                                   [(say, sternly)]
# 294776                             [(say, independently)]
# 294940                                 [(claim, falsely)]
# 294952                                    [(say, simply)]
# 294956                                  [(talk, clearly)]
# 295076                                 [(say, obviously)]
# 295077                                   [(say, clearly)]
# 295078                                    [(say, simply)]
# 295081                [(say, repeatedly), (say, clearly)]
# 295119                                   [(say, bluntly)]
# 295308                                  [(say, actually)]
# 295352                               [(tell, explicitly)]
# 295460                          [(talk, unconditionally)]
# 295517                              [(say, definitively)]
# 295822                                 [(say, basically)]
# 295867                                    [(name, aptly)]
# 295942                            [(describe, obviously)]
# 296175                                    [(say, simply)]
# 296652                                 [(say, precisely)]
# 296897                             [(describe, superbly)]
# 296983                                   [(tell, kindly)]
# 297012                              [(declare, formally)]
# 297097                             [(explain, patiently)]
# 297368                                    [(say, merely)]
# 297378                                   [(say, clearly)]
# 297441                                  [(say, recently)]
# 297448                                  [(say, recently)]
# 297454                              [(say, specifically)]
# 297497                [(speak, loudly), (speak, clearly)]
# 297650                                   [(say, finally)]
# 297651                                      [(say, only)]
# 297813                               [(talk, repeatedly)]
# 298146                               [(name, reportedly)]
# 298322                              [(declare, publicly)]
# 298372                          [(claim, simultaneously)]
# 298398                               [(name, reportedly)]
# 298401                               [(name, officially)]
# 298740                                  [(tell, bluntly)]
# 299049                                [(say, previously)]
# 299059                                  [(say, probably)]
# 299185                              [(say, consistently)]
# 299378                              [(express, publicly)]
# 299647                                  [(tell, usually)]
# 299989                         [(communicate, privately)]
# 299996                              [(say, incidentally)]
# 300005                [(say, publicly), (say, privately)]
# 300074                                 [(speak, frankly)]
# 300183                                    [(say, simply)]
# 300201                                    [(say, simply)]
# 300233    [(express, hopefully), (express, passionately)]
# 300277                                    [(speak, only)]
# 300513                              [(say, definitively)]
# 300582                                [(say, forcefully)]
# 300590                               [(declare, falsely)]
# 300591                               [(declare, falsely)]
# 300596                                  [(express, only)]
#
# [2356 rows x 3 columns]

# %%
counters = {say_syn: Counter() for say_syn in say_syns}
for pairs in df['collocations']:
    for (say_syn, adv) in pairs:
        counters[say_syn].update([adv])

# %%
result = pd.DataFrame(
    [(say_syn, ",".join([adv for (adv, _) in counters[say_syn].most_common(10)])) for say_syn in say_syns],
    columns=['verb', 'most_used_adv'])
result
# Out:
#            verb  \
# 0     broadcast
# 1       declare
# 2       explain
# 3      describe
# 4          talk
# 5         speak
# 6     verbalize
# 7          chat
# 8     advertise
# 9         claim
# 10         tell
# 11          say
# 12  communicate
# 13         name
# 14      express
#
#                                                                                          most_used_adv
# 0                      widely,inadvertently,publicly,allegedly,clearly,nationally,presently,repeatedly
# 1    publicly,falsely,suddenly,recently,officially,unequivocally,openly,proudly,triumphantly,ominously
# 2                clearly,fully,patiently,probably,certainly,really,easily,exactly,recently,necessarily
# 3   accurately,only,previously,specifically,adequately,thusly,really,perfectly,correctly,unfortunately
# 4             directly,really,only,openly,actually,publicly,clearly,repeatedly,specifically,personally
# 5              directly,publicly,only,fiercely,recently,generally,forcefully,openly,politically,loudly
# 6
# 7                                                                              directly,coincidentally
# 8                                    heavily,aggressively,originally,openly,proudly,largely,previously
# 9     falsely,previously,repeatedly,recently,initially,actually,absurdly,credibly,publicly,ludicrously
# 10              recently,reportedly,privately,finally,basically,repeatedly,actually,really,only,simply
# 11               recently,actually,repeatedly,simply,explicitly,publicly,basically,really,only,clearly
# 12            effectively,directly,freely,really,indirectly,apparently,loudly,hopefully,daily,actually
# 13       aptly,reportedly,recently,specifically,really,apparently,explicitly,directly,only,differently
# 14                  repeatedly,privately,actually,freely,openly,publicly,starkly,finally,only,verbally

# %%
result.to_csv('collocation_result.csv', index=False)
