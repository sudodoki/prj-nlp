# %% [markdown]
# # Read data

# %%
import pandas as pd
data = pd.read_csv('curated-full.tsv', sep='\t', encoding='utf8', header=None)
data.columns=['id','type','question','answer']
data[:5]
# Out:
#      id     type                                           question  \
# 0  1756  factoid                       When is Fashion week in NYC?
# 1  1434  factoid  What site did Lindbergh begin his flight from ...
# 2  1790  factoid  What country is the holy city of Mecca located...
# 3  1992  factoid                                How hot is the sun?
# 4  2128  factoid  What flavor filling did the original Twinkies ...
#
#                                               answer
# 0                          Sept?(ember)?|Feb(ruary)?
# 1             Long Island|New\s?York|Roosevelt Field
# 2                                       Saudi Arabia
# 3  (5,?778|6,?[05]00)\s*K|(5,?505|6,?[50]00).*C|(...
# 4                                             banana

# %% [markdown]
# # CHANGE QUESTION TO YES NO

# %%
#some rundom results can be

# %%
import rstr
import re

def generate_answer_from_pattern(pattern):
    value = rstr.xeger(pattern)
    value = re.sub(r"\s+", ' ', value)
    #return value
    if len(value)>len(pattern):
        return  re.sub(r"[^\w\s]", ' ', pattern)
    else:
        return value
data['answer_value'] =  data['answer'].apply(generate_answer_from_pattern)

# %%
data[['question','answer_value']][:100]
# Out:
#                                              question  \
# 0                        When is Fashion week in NYC?
# 1   What site did Lindbergh begin his flight from ...
# 2   What country is the holy city of Mecca located...
# 3                                 How hot is the sun?
# 4   What flavor filling did the original Twinkies ...
# 5                   What is the state song of Kansas?
# 6   What war is connected with the book "Charge of...
# 7          Where was the first atomic bomb detonated?
# 8                      What continent is Scotland in?
# 9   What island did the U.S. gain after the Spanis...
# 10                           How deep is Crater Lake?
# 11     What are the people who make fireworks called?
# 12                          Who painted "Sunflowers"?
# 13             Who played Frodo in Lord of The Rings?
# 14                       What is the capital of Laos?
# 15               How hot does it get in Death Valley?
# 16      What is the southwestern-most tip of England?
# 17                  What is the motto for California?
# 18                    How many Great Lakes are there?
# 19      What is the name of the second Beatles album?
# 20   How many bombs were detonated in 2005 in London?
# 21          How many planets are in our solar system?
# 22                       How big is the planet Venus?
# 23             When did the Klondike gold rush occur?
# 24                                 When was JFK born?
# 25         What city hosted the 1936 Summer Olympics?
# 26                What is Marilyn Monroe's real name?
# 27   How many Olympic gold medals did Carl Lewis win?
# 28   What year did Wilt Chamberlain score 100 points?
# 29  What is the name of the airport in Dallas Ft. ...
# ..                                                ...
# 70  What is the abbreviation for the London stock ...
# 71                   When were the Los Angeles riots?
# 72               What is the Boston Strangler's name?
# 73  Which film received the first best picture Aca...
# 74         What is the world's second largest island?
# 75                 What year was the IBM PC invented?
# 76   How old do you have to be to join the U.S. Navy?
# 77                       When was Julius Caesar born?
# 78                When did Yankee Stadium first open?
# 79                          What are pennies made of?
# 80                                   how much is 1+1?
# 81                    What is capital city of Russia?
# 82                        How fast can a cheetah run?
# 83                          How did Harry Chapin die?
# 84                How much did the first Barbie cost?
# 85  What company owns the soft drink brand "Gatora...
# 86          Who won the Oscar for best actor in 1970?
# 87                       Who invented the cotton gin?
# 88                       When was Maria Theresa born?
# 89         What is the gift for the 20th anniversary?
# 90           What is another name for the North Star?
# 91                                how did stalin die?
# 92                How long is the Great Barrier Reef?
# 93          What is the North Korean national anthem?
# 94  What year did Ellis Island open its doors to i...
# 95                          How did Adolf Hitler die?
# 96  When a game of baseball is forfeited, what is ...
# 97                          What animal is veal from?
# 98                How many layers of skin do we have?
# 99              What is the oldest college bowl game?
#
#                                answer_value
# 0                                  February
# 1                           Roosevelt Field
# 2                              Saudi Arabia
# 3                                    5778.0
# 4                                    banana
# 5                         Home on the Range
# 6                                   Crimean
# 7                                New Mexico
# 8                                    Europe
# 9                               Puerto Rico
# 10                                    594 m
# 11                            Pyrotechnists
# 12                                 van Gogh
# 13                                     Wood
# 14                                Vientiane
# 15                                   56.6°C
# 16                                 Cornwall
# 17                                 Eureka
# 18                                     five
# 19                             Second Album
# 20                                     four
# 21                                     nine
# 22                               3761 miles
# 23                                     1898
# 24                                     1917
# 25                                   Berlin
# 26                               Norma Jean
# 27                                       10
# 28                                     1962
# 29  Dallas-Fort Worth International Airport
# ..                                      ...
# 70                                   LuSBE,
# 71                                     1992
# 72                           Albert DeSalvo
# 73                                  Wings
# 74                               New Guinea
# 75                                     1981
# 76                                       17
# 77                                   100 BC
# 78                                     1923
# 79                                     zinc
# 80                                        2
# 81                                   Moscow
# 82                                 120 km/h
# 83                             car accident
# 84                                        3
# 85                                  PepsiCo
# 86                          George C$ Scott
# 87                                  Whitney
# 88                                     1717
# 89                                 platinum
# 90                                  Polaris
# 91                      cerebral hemorrhage
# 92                                  2000 km
# 93                      the national anthem
# 94                                     1892
# 95                                  Suicide
# 96                                    9 : 0
# 97                                     calf
# 98                                    three
# 99                                Rose Bowl
#
# [100 rows x 2 columns]

# %% [markdown]
# Обставинні питання в англійській мові складаються за двома паттернами:
# 1. підмет є в питанні
# ```(питальне слово) + (допоміжне дієслово) + (підмет) + (основне дієслово) ? + (додаток/обставина) ?```
# _(Where) (was) (the first atomic bomb) (detonated)? => (the first atomic bomb) (was) (detonated) + відповідь (in New Mexico)_
# _(Where) (was) (the first atomic bomb)? => (the first atomic bomb) (was) + відповідь (in New Mexico)_
#
# 2. питальне слово заміняє підмет
# ```(питальне слово) + (основне дієслово) + (додаток/обставина) ?```
# _(Who) (discovered) (America)? => відповідь (Columbus) + (discovered) (America)_
# _(What) (is) (the state song of Kansas)? => відповідь (Home on the Range) + (is) (the state song of Kansas)_ (edited)
# Оці частинки, що я виділила дужками, називаються в NLP чанками (chunks). Ти їх можеш виділити через дерево складників або через простіший інструмент - chunker. Він є в nltk, наприклад.
#
# А далі перестановка з урахуванням кількох моментів:
# 1. якщо допоміжне дієслово do/did/does, то основне треба перетворити: `did ... happen` => `happened`
# 2. є розширені питальні слова з which/what/how (what music, which style, how deep), де відповідь буде об’єднуватись з питальним словом (pop music, disco style, 593.0 deep)
# 3. до питань про час та місце треба добирати прийменники (in 1999, on May 7)
# 4. у типі 2 можуть бути лише питальні слова who і what

# %%
def get_chunks(sent):

    grammar = """Q1: {^<WRB><JJ>*(<VBZ>|<VBD>)*}
                    {^<VB><PRP><WRB>}
                Q2: {<WP><VBZ>*}
                {^<NNP>}
                {^<JJ>}
                {<WDT>}
                Q_symbol: {<.>*}
               S2: {<.*>+}
               }<Q1|Q2|Q_symbol>+{
               """
    chunkParser = nltk.RegexpParser(grammar)


    tagged = nltk.pos_tag(nltk.word_tokenize(sent))
    tree = chunkParser.parse(tagged)
    return tree

def print_tree(tree):    
    for subtree in tree.subtrees():
        if subtree.label() in ["Q1","Q2",'Q_symbol','S2']: 
            print(subtree.label()+str(subtree.leaves()))

# %%
import nltk
from nltk import chunk, tag, tokenize

for sent in data['question'].values[[3,15,18,21,23,109,242,673]]:
    tokens = tokenize.word_tokenize(sent)
    tagged_sent = tag.pos_tag(tokens)
    print(tagged_sent)
    print_tree(get_chunks(sent))
    print('-----------------')
#tree.draw()
# Out:
# [('How', 'WRB'), ('hot', 'JJ'), ('is', 'VBZ'), ('the', 'DT'), ('sun', 'NN'), ('?', '.')]
# Q1[('How', 'WRB'), ('hot', 'JJ'), ('is', 'VBZ')]
# S2[('the', 'DT'), ('sun', 'NN')]
# Q_symbol[('?', '.')]
# -----------------
# [('How', 'WRB'), ('hot', 'JJ'), ('does', 'VBZ'), ('it', 'PRP'), ('get', 'VB'), ('in', 'IN'), ('Death', 'NNP'), ('Valley', 'NNP'), ('?', '.')]
# Q1[('How', 'WRB'), ('hot', 'JJ'), ('does', 'VBZ')]
# S2[('it', 'PRP'), ('get', 'VB'), ('in', 'IN'), ('Death', 'NNP'), ('Valley', 'NNP')]
# Q_symbol[('?', '.')]
# -----------------
# [('How', 'WRB'), ('many', 'JJ'), ('Great', 'NNP'), ('Lakes', 'NNP'), ('are', 'VBP'), ('there', 'RB'), ('?', '.')]
# Q1[('How', 'WRB'), ('many', 'JJ')]
# S2[('Great', 'NNP'), ('Lakes', 'NNP'), ('are', 'VBP'), ('there', 'RB')]
# Q_symbol[('?', '.')]
# -----------------
# [('How', 'WRB'), ('many', 'JJ'), ('planets', 'NNS'), ('are', 'VBP'), ('in', 'IN'), ('our', 'PRP$'), ('solar', 'NN'), ('system', 'NN'), ('?', '.')]
# Q1[('How', 'WRB'), ('many', 'JJ')]
# S2[('planets', 'NNS'), ('are', 'VBP'), ('in', 'IN'), ('our', 'PRP$'), ('solar', 'NN'), ('system', 'NN')]
# Q_symbol[('?', '.')]
# -----------------
# [('When', 'WRB'), ('did', 'VBD'), ('the', 'DT'), ('Klondike', 'NNP'), ('gold', 'NN'), ('rush', 'NN'), ('occur', 'NN'), ('?', '.')]
# Q1[('When', 'WRB'), ('did', 'VBD')]
# S2[('the', 'DT'), ('Klondike', 'NNP'), ('gold', 'NN'), ('rush', 'NN'), ('occur', 'NN')]
# Q_symbol[('?', '.')]
# -----------------
# [('In', 'IN'), ('which', 'WDT'), ('city', 'NN'), ('would', 'MD'), ('you', 'PRP'), ('find', 'VB'), ('the', 'DT'), ('Louvre', 'NNP'), ('?', '.')]
# S2[('In', 'IN')]
# Q2[('which', 'WDT')]
# S2[('city', 'NN'), ('would', 'MD'), ('you', 'PRP'), ('find', 'VB'), ('the', 'DT'), ('Louvre', 'NNP')]
# Q_symbol[('?', '.')]
# -----------------
# [('Which', 'JJ'), ('disciple', 'VBZ'), ('received', 'VBD'), ('30', 'CD'), ('pieces', 'NNS'), ('of', 'IN'), ('silver', 'NN'), ('for', 'IN'), ('betraying', 'VBG'), ('Jesus', 'NNP'), ('?', '.')]
# Q2[('Which', 'JJ')]
# S2[('disciple', 'VBZ'), ('received', 'VBD'), ('30', 'CD'), ('pieces', 'NNS'), ('of', 'IN'), ('silver', 'NN'), ('for', 'IN'), ('betraying', 'VBG'), ('Jesus', 'NNP')]
# Q_symbol[('?', '.')]
# -----------------
# [('Tell', 'VB'), ('me', 'PRP'), ('where', 'WRB'), ('the', 'DT'), ('DuPont', 'NNP'), ('company', 'NN'), ('is', 'VBZ'), ('located', 'VBN'), ('.', '.')]
# Q1[('Tell', 'VB'), ('me', 'PRP'), ('where', 'WRB')]
# S2[('the', 'DT'), ('DuPont', 'NNP'), ('company', 'NN'), ('is', 'VBZ'), ('located', 'VBN')]
# Q_symbol[('.', '.')]
# -----------------

# %%
def translate_Q1(data, answer):
    question_chunks = data['Q1']
    vb=''
    for item in  question_chunks:        
        if item[1]=='VBZ':
            vb=item[0]
        
    cc = ''
    if question_chunks[0][0].lower() in ['where', 'when']:
        cc = 'in'
        
    end = ''
    for item in  question_chunks:        
        if item[1]=='JJ':
            end=item[0]
    
    sent = ' '.join(pair[0] for pair in data['S2'])
    
    return  ' '.join([sent,vb,cc,answer,end])

def translate_Q2(data, answer):
    question_chunks = data['Q2']
    vb=''
    if len(question_chunks)==2:
        vb=question_chunks[1][0]
  
    sent = ' '.join(pair[0] for pair in data['S2'])
    return  ' '.join([answer, vb,sent])

def get_statement_sent(question, answer):
    tree = get_chunks(question)
    data ={}
    for subtree in tree.subtrees():
        data[subtree.label()] = subtree.leaves()
    if 'Q1' in data:
        return translate_Q1(data, answer)
    else:
        return translate_Q2(data, answer)
    
get_statement_sent('When is Fashion week in NYC?','February')
# Out:
# 'Fashion week in NYC is in February '

# %%
data[:5]
# Out:
#      id     type                                           question  \
# 0  1756  factoid                       When is Fashion week in NYC?
# 1  1434  factoid  What site did Lindbergh begin his flight from ...
# 2  1790  factoid  What country is the holy city of Mecca located...
# 3  1992  factoid                                How hot is the sun?
# 4  2128  factoid  What flavor filling did the original Twinkies ...
#
#                                               answer     answer_value  \
# 0                          Sept?(ember)?|Feb(ruary)?         February
# 1             Long Island|New\s?York|Roosevelt Field  Roosevelt Field
# 2                                       Saudi Arabia     Saudi Arabia
# 3  (5,?778|6,?[05]00)\s*K|(5,?505|6,?[50]00).*C|(...           5778.0
# 4                                             banana           banana
#
#                                           statements
# 0                Fashion week in NYC is in February
# 1  Roosevelt Field  site did Lindbergh begin his ...
# 2  Saudi Arabia  country is the holy city of Mecc...
# 3                    the sun is  5505!/K Sm4x= C hot
# 4  banana  flavor filling did the original Twinki...

# %%
data['statements'] = data[['question','answer_value']].apply(lambda row: get_statement_sent(row['question'],row['answer_value']),axis=1)

# %%
data[['question','statements'] ]
# Out:
#                                               question  \
# 0                         When is Fashion week in NYC?
# 1    What site did Lindbergh begin his flight from ...
# 2    What country is the holy city of Mecca located...
# 3                                  How hot is the sun?
# 4    What flavor filling did the original Twinkies ...
# 5                    What is the state song of Kansas?
# 6    What war is connected with the book "Charge of...
# 7           Where was the first atomic bomb detonated?
# 8                       What continent is Scotland in?
# 9    What island did the U.S. gain after the Spanis...
# 10                            How deep is Crater Lake?
# 11      What are the people who make fireworks called?
# 12                           Who painted "Sunflowers"?
# 13              Who played Frodo in Lord of The Rings?
# 14                        What is the capital of Laos?
# 15                How hot does it get in Death Valley?
# 16       What is the southwestern-most tip of England?
# 17                   What is the motto for California?
# 18                     How many Great Lakes are there?
# 19       What is the name of the second Beatles album?
# 20    How many bombs were detonated in 2005 in London?
# 21           How many planets are in our solar system?
# 22                        How big is the planet Venus?
# 23              When did the Klondike gold rush occur?
# 24                                  When was JFK born?
# 25          What city hosted the 1936 Summer Olympics?
# 26                 What is Marilyn Monroe's real name?
# 27    How many Olympic gold medals did Carl Lewis win?
# 28    What year did Wilt Chamberlain score 100 points?
# 29   What is the name of the airport in Dallas Ft. ...
# ..                                                 ...
# 837                    Who succeeded Ferdinand Marcos?
# 838  How far is it from the pitcher's mound to home...
# 839                 How many stomachs does a cow have?
# 840                What dress size was Marilyn Monroe?
# 841       What year did California become a territory?
# 842                       What class of drug is Xanax?
# 843                What year did Nintendo 64 come out?
# 844           What year did Marco Polo travel to Asia?
# 845               What is Canada's most populous city?
# 846   What country was the Battle of Verdun fought in?
# 847              What president declared Mothers' Day?
# 848  Who was the only golfer to win the U.S. and Br...
# 849                Where was President Lincoln buried?
# 850    Where was the movie "Somewhere in Time" filmed?
# 851  What is the name of the longest running soap o...
# 852                  What does an English stone equal?
# 853                   What is the currency of Denmark?
# 854                         When was Sputnik launched?
# 855      What percent of the U.S. is African American?
# 856                    When was the Red Cross founded?
# 857         What country was Catherine the Great from?
# 858     What cathedral is in Claude Monet's paintings?
# 859  who received the Nobel Prize for Physiology an...
# 860                        When was Adolf Hitler born?
# 861   What is the length of Churchill Downs racetrack?
# 862             What country does Greenland belong to?
# 863                       Where is Anne Frank's diary?
# 864  When did Alexandra Graham Bell invent the tele...
# 865    how many lines per page are in Gutenberg bible?
# 866            in which country was microsoft founded?
#
#                                             statements
# 0                  Fashion week in NYC is in February
# 1    Roosevelt Field  site did Lindbergh begin his ...
# 2    Saudi Arabia  country is the holy city of Mecc...
# 3                               the sun is  5778.0 hot
# 4    banana  flavor filling did the original Twinki...
# 5        Home on the Range is the state song of Kansas
# 6    Crimean  war is connected with the book `` Cha...
# 7      the first atomic bomb detonated  in New Mexico
# 8                     Europe  continent is Scotland in
# 9    Puerto Rico  island did the U.S. gain after th...
# 10                          Crater Lake is  594 m deep
# 11                Pyrotechnists  make fireworks called
# 12                  van Gogh  painted `` Sunflowers ''
# 13             Wood  played Frodo in Lord of The Rings
# 14                    Vientiane is the capital of Laos
# 15             it get in Death Valley does  56.6°C hot
# 16    Cornwall is the southwestern-most tip of England
# 17                Eureka   is the motto for California
# 18                   Great Lakes are there   five many
# 19   Second Album is the name of the second Beatles...
# 20   bombs were detonated in 2005 in London   four ...
# 21         planets are in our solar system   nine many
# 22                 the planet Venus is  3761 miles big
# 23              the Klondike gold rush occur  in 1898
# 24                                  JFK born  in 1917
# 25        Berlin  city hosted the 1936 Summer Olympics
# 26           Norma Jean is Marilyn Monroe 's real name
# 27    Olympic gold medals did Carl Lewis win   10 many
# 28    1962  year did Wilt Chamberlain score 100 points
# 29   Dallas-Fort Worth International Airport is the...
# ..                                                 ...
# 837         Corazon Aquino  succeeded Ferdinand Marcos
# 838  far is it from the pitcher 's mound to home pl...
# 839                  stomachs does a cow have   4 many
# 840                   8  dress size was Marilyn Monroe
# 841       1848  year did California become a territory
# 842             Benzodiazepine  class of drug is Xanax
# 843                1996  year did Nintendo 64 come out
# 844           1271  year did Marco Polo travel to Asia
# 845            Toronto is Canada 's most populous city
# 846  The Battle of Verdun 1916.  country was the Ba...
# 847           Wilson  president declared Mothers ' Day
# 848  Bobby Jones  was the only golfer to win the U....
# 849             President Lincoln buried  in Illinois
# 850  the movie `` Somewhere in Time '' filmed  in G...
# 851  Coronation Street is the name of the longest r...
# 852               14 pound does an English stone equal
# 853                  kroner is the currency of Denmark
# 854                         Sputnik launched  in 1957
# 855    12.2 %  percent of the U.S. is African American
# 856                    the Red Cross founded  in 1859
# 857      Prussia  country was Catherine the Great from
# 858   Rouen  cathedral is in Claude Monet 's paintings
# 859    Gurdon Yamanaka     2   received the Nobel P...
# 860                    Adolf Hitler born  in 20 April
# 861  seven furlongs 1   mile 2 k ilo  m eters   is ...
# 862          Denmark  country does Greenland belong to
# 863               Anne Frank 's diary is in Amsterdam
# 864  Alexandra Graham Bell invent the telephone  in...
# 865    lines per page are in Gutenberg bible   42 many
# 866                 U S  country was microsoft founded
#
# [867 rows x 2 columns]

# %%
data.to_csv('statements.csv', index=False, encoding='utf8')
