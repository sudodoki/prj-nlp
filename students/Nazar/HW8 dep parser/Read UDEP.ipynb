# %%
import warnings
warnings.filterwarnings('ignore')

import sys
import os
import numpy as np
import gensim


model = gensim.models.KeyedVectors.load_word2vec_format('ubercorpus.lowercased.tokenized.word2vec.300d.bz2', binary=False)

# %%
#https://github.com/EmilStenstrom/conllu
#https://github.com/UniversalDependencies/UD_English-EWT
from conllu import parse, parse_tree
from collections import OrderedDict
import numpy as np

# %%
with open('../UD_Ukrainian-IU/uk_iu-ud-train.conllu') as f:
    c= f.read()
    trees= parse(c)

# %%
tree=trees[0]

# %%
tree[5]
# Out:
# OrderedDict([('id', 6),
#              ('form', 'була'),
#              ('lemma', 'бути'),
#              ('upostag', 'VERB'),
#              ('xpostag', 'Vapis-sf'),
#              ('feats',
#               OrderedDict([('Aspect', 'Imp'),
#                            ('Gender', 'Fem'),
#                            ('Mood', 'Ind'),
#                            ('Number', 'Sing'),
#                            ('Tense', 'Past'),
#                            ('VerbForm', 'Fin')])),
#              ('head', 0),
#              ('deprel', 'root'),
#              ('deps', None),
#              ('misc', OrderedDict([('Id', '0008')]))])

# %%
from enum import Enum
class Action_type(Enum):
    Left = 1
    Right = 2
    Reduse = 3
    Shift = 4
    
class oracle:
    def __init__(self, tree):
        self.rel=[]
        self.stack=[OrderedDict([('id', 0),('form','ROOT'),("head",0),("lemma","root")])]
        self.queue=tree
        self.step_processor={Action_type.Left:self.Left,
                             Action_type.Shift:self.Shift,
                             Action_type.Right:self.Right,
                             Action_type.Reduse:self.Reduse}
        
    def Shift(self):
        self.stack.append(self.queue.pop(0))
        
    def Left(self):
        self.rel.append((self.stack.pop()['id'],self.queue[0]['id']))
        
    def Right(self):
        self.rel.append((self.queue[0]['id'],self.stack[-1]['id']))
        self.stack.append(self.queue.pop(0))
        
    def Reduse(self):
        self.stack.pop()
        
    def do_steps(self, debug=False):
        history_step1=-1
        histiry_step2=-1
        self.features =[]
        self.labels = []
        self.dep = []
        while self.stack or self.queue:
            top_stack = self.stack[-1] if len(self.stack) > 0 else None
            first_queue =  self.queue[0] if len(self.queue) > 0 else None
            step_type=self.get_action(top_stack,first_queue)
            self.labels.append(step_type)
            if (step_type==Action_type.Left):
                self.dep.append(top_stack['deprel'])
            if (step_type==Action_type.Right):
                self.dep.append(first_queue['deprel'])
            else:
                self.dep.append('-')

            self.features.append(extract_features(self.stack, self.queue, self.rel,history_step1,histiry_step2))
            histiry_step2=history_step1
            history_step1=step_type.value
            if debug:
                self.info(step_type)
            self.step_processor[step_type]()
        return self.rel
    
    def get_action(self, stack,queue):
        if stack and not queue:
            return Action_type.Reduse
        if stack['head']==queue['id']:
             return Action_type.Left
        if stack['id']==queue['head']:
             return Action_type.Right
            
        if stack['id'] in  [i[0] for i in self.rel] and stack["id"] > queue["head"]:
             return Action_type.Reduse
        else:
            return Action_type.Shift
    
    def info(self, step_type):
        print('step: ', step_type)
        print('stack',  self.print_item(self.stack))
        print('queue',  self.print_item(self.queue))
        print('rel',  self.rel)
        print("====================================")

    def print_item(self, lst):
        return [i['form'] for i in lst]
    
    def get_relations(tree):
        return [(i['id'],i['head']) for i in tree]

# %% [markdown]
# # is static oracle do all transitions Well ?

# %%
correct_parsed_count=0
incorect_parsed_count = 0
incorect_tree_indexes=[]

for index,tree in enumerate(trees):
    o = oracle(tree.copy())
    parsed_relations = o.do_steps()
    gold_relations = oracle.get_relations(tree)
    correct_parsed_count+=len(set(gold_relations))
    incorect_parsed_count+= len(set(gold_relations)-set(parsed_relations)) +len(set(parsed_relations)-set(gold_relations)) 
    if set(parsed_relations)!=set(gold_relations):
        incorect_tree_indexes.append(index)

# %%
print ('trees count: ', len(trees))
print ('oracle_acc: ', correct_parsed_count/(incorect_parsed_count+correct_parsed_count))
# Out:
# trees count:  4513
# oracle_acc:  0.9742738158560476

# %%
print(incorect_tree_indexes)
# Out:
# [4, 7, 8, 12, 13, 18, 21, 23, 26, 28, 32, 33, 34, 42, 43, 45, 46, 50, 53, 54, 66, 69, 110, 119, 127, 164, 169, 175, 177, 178, 179, 182, 194, 195, 200, 202, 203, 209, 220, 230, 244, 245, 248, 259, 270, 287, 288, 290, 302, 306, 313, 328, 344, 346, 353, 355, 364, 401, 403, 416, 423, 435, 436, 438, 441, 443, 453, 454, 461, 469, 480, 489, 491, 496, 497, 499, 500, 505, 507, 508, 509, 511, 516, 517, 522, 529, 530, 531, 537, 551, 554, 557, 579, 581, 634, 649, 665, 666, 679, 719, 789, 798, 819, 828, 835, 841, 863, 868, 869, 894, 903, 913, 963, 971, 974, 978, 982, 986, 989, 994, 1006, 1014, 1017, 1018, 1021, 1023, 1024, 1026, 1048, 1063, 1079, 1091, 1101, 1107, 1112, 1115, 1117, 1121, 1149, 1152, 1156, 1157, 1160, 1165, 1208, 1214, 1219, 1228, 1230, 1235, 1246, 1247, 1281, 1285, 1287, 1292, 1318, 1347, 1356, 1357, 1366, 1369, 1380, 1382, 1385, 1397, 1413, 1421, 1438, 1453, 1455, 1475, 1484, 1507, 1532, 1534, 1556, 1570, 1576, 1589, 1598, 1605, 1613, 1621, 1625, 1628, 1632, 1657, 1658, 1683, 1687, 1697, 1714, 1718, 1728, 1758, 1770, 1795, 1810, 1829, 1833, 1851, 1860, 1863, 1918, 1931, 1935, 1944, 1952, 1970, 1979, 2027, 2032, 2041, 2046, 2061, 2077, 2082, 2085, 2121, 2152, 2157, 2173, 2177, 2188, 2193, 2210, 2224, 2225, 2237, 2239, 2245, 2260, 2265, 2291, 2298, 2303, 2317, 2323, 2325, 2327, 2331, 2333, 2334, 2339, 2343, 2348, 2355, 2357, 2410, 2420, 2435, 2436, 2444, 2447, 2449, 2468, 2474, 2475, 2478, 2479, 2486, 2489, 2496, 2499, 2503, 2505, 2520, 2521, 2523, 2531, 2538, 2548, 2557, 2559, 2570, 2575, 2578, 2582, 2587, 2598, 2599, 2606, 2608, 2616, 2617, 2618, 2620, 2623, 2632, 2637, 2643, 2694, 2712, 2715, 2722, 2725, 2729, 2751, 2765, 2766, 2769, 2770, 2772, 2773, 2778, 2780, 2797, 2799, 2801, 2817, 2839, 2848, 2860, 2872, 2883, 2908, 2910, 2911, 2913, 2914, 2915, 2923, 2924, 2926, 2927, 2963, 2965, 2967, 2975, 2985, 2995, 2996, 3017, 3021, 3044, 3053, 3062, 3065, 3066, 3070, 3080, 3090, 3101, 3102, 3103, 3104, 3109, 3118, 3121, 3125, 3126, 3130, 3134, 3136, 3143, 3151, 3173, 3174, 3175, 3190, 3200, 3208, 3212, 3227, 3228, 3235, 3237, 3243, 3246, 3249, 3255, 3256, 3261, 3273, 3293, 3302, 3303, 3345, 3353, 3354, 3375, 3389, 3392, 3408, 3424, 3427, 3428, 3431, 3434, 3440, 3444, 3450, 3473, 3483, 3500, 3535, 3537, 3555, 3559, 3566, 3594, 3595, 3599, 3615, 3625, 3627, 3637, 3641, 3645, 3649, 3655, 3663, 3664, 3671, 3676, 3683, 3707, 3719, 3735, 3764, 3765, 3766, 3768, 3776, 3791, 3798, 3802, 3808, 3810, 3812, 3815, 3820, 3841, 3842, 3843, 3844, 3847, 3851, 3886, 3887, 3894, 3909, 3914, 3925, 3940, 3941, 3942, 3944, 3945, 3948, 3952, 3963, 3964, 3969, 3976, 3978, 3998, 4009, 4024, 4025, 4027, 4038, 4097, 4108, 4109, 4116, 4119, 4131, 4134, 4140, 4141, 4145, 4146, 4147, 4149, 4154, 4155, 4166, 4194, 4198, 4206, 4211, 4212, 4213, 4230, 4231, 4232, 4236, 4242, 4283, 4284, 4288, 4299, 4332, 4334, 4345, 4384, 4412, 4414, 4432, 4454, 4455, 4456, 4458, 4461, 4462, 4464, 4466, 4469, 4470, 4492, 4495]

# %%
def analize_error(tree):
    o = oracle(tree.copy())
    parsed_relations = o.do_steps()
    gold_relations = oracle.get_relations(tree)
    print(set(gold_relations)- set(parsed_relations))
    print(set(parsed_relations)- set(gold_relations))
    print('-----------------------------------------')
    tree= tree
    for item in tree:
        print('{0}({1}) <- {2}({3})'.format(item['id'], item['form'], item['head'], tree[item['head'] - 1]["form"]
                             if item['head'] > 0 else "root"))
    
analize_error(trees[incorect_tree_indexes[0]])
# Out:
# {(35, 31), (44, 9)}
# set()
# -----------------------------------------
# 1(Як) <- 6(сюжетів)
# 2(і) <- 6(сюжетів)
# 3(багато) <- 6(сюжетів)
# 4(інших) <- 6(сюжетів)
# 5(її) <- 6(сюжетів)
# 6(сюжетів) <- 9(виявилася)
# 7(,) <- 6(сюжетів)
# 8(вона) <- 9(виявилася)
# 9(виявилася) <- 0(root)
# 10(візіонерським) <- 11(передбаченням)
# 11(передбаченням) <- 9(виявилася)
# 12(:) <- 23(почали)
# 13(за) <- 15(десятиліття)
# 14(якесь) <- 15(десятиліття)
# 15(десятиліття) <- 23(почали)
# 16(після) <- 17(написання)
# 17(написання) <- 15(десятиліття)
# 18(твору) <- 17(написання)
# 19(несамовиті) <- 20(ревнителі)
# 20(ревнителі) <- 23(почали)
# 21(нового) <- 22(ладу)
# 22(ладу) <- 20(ревнителі)
# 23(почали) <- 9(виявилася)
# 24(нищити) <- 23(почали)
# 25(культурні) <- 26(скарби)
# 26(скарби) <- 24(нищити)
# 27(,) <- 33(володіли)
# 28(до) <- 33(володіли)
# 29(того) <- 28(до)
# 30(ж) <- 28(до)
# 31(засобами) <- 33(володіли)
# 32(вони) <- 33(володіли)
# 33(володіли) <- 23(почали)
# 34(непорівнянно) <- 35(потужнішими)
# 35(потужнішими) <- 31(засобами)
# 36(,) <- 39(сектярі)
# 37(аніж) <- 39(сектярі)
# 38(гнані) <- 39(сектярі)
# 39(сектярі) <- 35(потужнішими)
# 40(при) <- 41(початку)
# 41(початку) <- 39(сектярі)
# 42(християнської) <- 43(ери)
# 43(ери) <- 41(початку)
# 44(.) <- 9(виявилася)

# %%
#this is non-projective dependency tree, and . error

# %%
analize_error(trees[incorect_tree_indexes[1]])
# Out:
# {(8, 0), (1, 4)}
# set()
# -----------------------------------------
# 1(Мало) <- 4(років)
# 2(не) <- 1(Мало)
# 3(сто) <- 4(років)
# 4(років) <- 5(тому)
# 5(тому) <- 8(радив)
# 6(Микола) <- 8(радив)
# 7(Зеров) <- 6(Микола)
# 8(радив) <- 0(root)
# 9(не) <- 10(гаючись)
# 10(гаючись) <- 12(перевіяти)
# 11(«) <- 12(перевіяти)
# 12(перевіяти) <- 8(радив)
# 13(на) <- 14(току)
# 14(току) <- 12(перевіяти)
# 15(критики) <- 14(току)
# 16(») <- 12(перевіяти)
# 17(наші) <- 19(набутки)
# 18(мистецькі) <- 19(набутки)
# 19(набутки) <- 12(перевіяти)
# 20(,) <- 21(відсіяти)
# 21(відсіяти) <- 12(перевіяти)
# 22(полову) <- 21(відсіяти)
# 23(,) <- 24(виважити)
# 24(виважити) <- 12(перевіяти)
# 25(все) <- 26(найдобірніше)
# 26(найдобірніше) <- 24(виважити)
# 27(й) <- 28(означити)
# 28(означити) <- 12(перевіяти)
# 29(тяглість) <- 28(означити)
# 30(національної) <- 31(традиції)
# 31(традиції) <- 29(тяглість)
# 32(.) <- 8(радив)

# %%
#need to fix

# %%
analize_error(trees[incorect_tree_indexes[2]])
# Out:
# {(7, 12), (10, 13), (6, 12), (32, 3), (12, 3)}
# set()
# -----------------------------------------
# 1(Лесю) <- 3(цензурували)
# 2(Українку) <- 1(Лесю)
# 3(цензурували) <- 0(root)
# 4(надзвичайно) <- 5(пильно)
# 5(пильно) <- 3(цензурували)
# 6(,) <- 12(мала)
# 7(адже) <- 12(мала)
# 8(в) <- 10(іконостасі)
# 9(радянському) <- 10(іконостасі)
# 10(іконостасі) <- 13(постати)
# 11(вона) <- 12(мала)
# 12(мала) <- 3(цензурували)
# 13(постати) <- 12(мала)
# 14(бездоганною) <- 15(марксисткою)
# 15(марксисткою) <- 13(постати)
# 16(,) <- 19(інтернаціоналісткою)
# 17(«) <- 19(інтернаціоналісткою)
# 18(пролетарською) <- 19(інтернаціоналісткою)
# 19(інтернаціоналісткою) <- 15(марксисткою)
# 20(») <- 19(інтернаціоналісткою)
# 21(,) <- 23(другом)
# 22(«) <- 23(другом)
# 23(другом) <- 15(марксисткою)
# 24(робітників) <- 23(другом)
# 25(») <- 23(другом)
# 26(,) <- 27(предтечею)
# 27(предтечею) <- 15(марксисткою)
# 28(соціалістичного) <- 29(реалізму)
# 29(реалізму) <- 27(предтечею)
# 30(et) <- 15(марксисткою)
# 31(cetera) <- 30(et)
# 32(.) <- 3(цензурували)

# %%
non projective + dot problem

# %%
analize_error(trees[incorect_tree_indexes[3]])
# Out:
# {(25, 29), (3, 0), (26, 28), (38, 3), (1, 5), (29, 24), (34, 24), (30, 24)}
# set()
# -----------------------------------------
# 1(Найперш) <- 5(перегородити)
# 2(барикада) <- 3(мала)
# 3(мала) <- 0(root)
# 4(би) <- 3(мала)
# 5(перегородити) <- 3(мала)
# 6(затишну) <- 7(вітальню)
# 7(вітальню) <- 5(перегородити)
# 8(косачівського) <- 9(дому)
# 9(дому) <- 7(вітальню)
# 10(,) <- 24(стояла)
# 11(бо) <- 24(стояла)
# 12(,) <- 14(дізнаємося)
# 13(як) <- 14(дізнаємося)
# 14(дізнаємося) <- 24(стояла)
# 15(з) <- 17(пояснень)
# 16(академічних) <- 17(пояснень)
# 17(пояснень) <- 14(дізнаємося)
# 18(,) <- 14(дізнаємося)
# 19(Ольга) <- 24(стояла)
# 20(Драгоманова) <- 19(Ольга)
# 21(-) <- 22(Косач)
# 22(Косач) <- 20(Драгоманова)
# 23(«) <- 24(стояла)
# 24(стояла) <- 3(мала)
# 25(на) <- 29(позиціях)
# 26(ліберально) <- 28(буржуазних)
# 27(-) <- 26(ліберально)
# 28(буржуазних) <- 29(позиціях)
# 29(позиціях) <- 24(стояла)
# 30(») <- 24(стояла)
# 31(,) <- 34(донька)
# 32(а) <- 34(донька)
# 33(її) <- 34(донька)
# 34(донька) <- 24(стояла)
# 35(—) <- 37(марксистських)
# 36(на) <- 37(марксистських)
# 37(марксистських) <- 34(донька)
# 38(.) <- 3(мала)

# %% [markdown]
# (25, 29) need to fix, .dot problem

# %%
tree
# Out:
# [OrderedDict([('id', 1),
#               ('form', 'Як'),
#               ('lemma', 'як'),
#               ('upostag', 'SCONJ'),
#               ('xpostag', 'Css'),
#               ('feats', None),
#               ('head', 6),
#               ('deprel', 'mark'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0020')]))]),
#  OrderedDict([('id', 2),
#               ('form', 'і'),
#               ('lemma', 'і'),
#               ('upostag', 'PART'),
#               ('xpostag', 'Q'),
#               ('feats', None),
#               ('head', 6),
#               ('deprel', 'discourse'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0021')]))]),
#  OrderedDict([('id', 3),
#               ('form', 'багато'),
#               ('lemma', 'багато'),
#               ('upostag', 'DET'),
#               ('xpostag', 'Mlc-n'),
#               ('feats',
#                OrderedDict([('Case', 'Nom'),
#                             ('NumType', 'Card'),
#                             ('PronType', 'Ind')])),
#               ('head', 6),
#               ('deprel', 'det:numgov'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0022')]))]),
#  OrderedDict([('id', 4),
#               ('form', 'інших'),
#               ('lemma', 'інший'),
#               ('upostag', 'DET'),
#               ('xpostag', 'Pi----pga'),
#               ('feats',
#                OrderedDict([('Case', 'Gen'),
#                             ('Number', 'Plur'),
#                             ('PronType', 'Ind')])),
#               ('head', 6),
#               ('deprel', 'det'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0023')]))]),
#  OrderedDict([('id', 5),
#               ('form', 'її'),
#               ('lemma', 'її'),
#               ('upostag', 'DET'),
#               ('xpostag', 'Ppp3--pga'),
#               ('feats',
#                OrderedDict([('Case', 'Gen'),
#                             ('Number', 'Plur'),
#                             ('Person', '3'),
#                             ('Poss', 'Yes'),
#                             ('PronType', 'Prs'),
#                             ('Uninflect', 'Yes')])),
#               ('head', 6),
#               ('deprel', 'det'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0024')]))]),
#  OrderedDict([('id', 6),
#               ('form', 'сюжетів'),
#               ('lemma', 'сюжет'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncmpgn'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Gen'),
#                             ('Gender', 'Masc'),
#                             ('Number', 'Plur')])),
#               ('head', 9),
#               ('deprel', 'advcl'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0025'), ('SpaceAfter', 'No')]))]),
#  OrderedDict([('id', 7),
#               ('form', ','),
#               ('lemma', ','),
#               ('upostag', 'PUNCT'),
#               ('xpostag', 'U'),
#               ('feats', None),
#               ('head', 6),
#               ('deprel', 'punct'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0026')]))]),
#  OrderedDict([('id', 8),
#               ('form', 'вона'),
#               ('lemma', 'вона'),
#               ('upostag', 'PRON'),
#               ('xpostag', 'Pp-3f-snn'),
#               ('feats',
#                OrderedDict([('Case', 'Nom'),
#                             ('Gender', 'Fem'),
#                             ('Number', 'Sing'),
#                             ('Person', '3'),
#                             ('PronType', 'Prs')])),
#               ('head', 9),
#               ('deprel', 'nsubj'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0027')]))]),
#  OrderedDict([('id', 9),
#               ('form', 'виявилася'),
#               ('lemma', 'виявитися'),
#               ('upostag', 'VERB'),
#               ('xpostag', 'Vmeis-sf'),
#               ('feats',
#                OrderedDict([('Aspect', 'Perf'),
#                             ('Gender', 'Fem'),
#                             ('Mood', 'Ind'),
#                             ('Number', 'Sing'),
#                             ('Tense', 'Past'),
#                             ('VerbForm', 'Fin')])),
#               ('head', 0),
#               ('deprel', 'root'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0028')]))]),
#  OrderedDict([('id', 10),
#               ('form', 'візіонерським'),
#               ('lemma', 'візіонерський'),
#               ('upostag', 'ADJ'),
#               ('xpostag', 'Ao-nsif'),
#               ('feats',
#                OrderedDict([('Case', 'Ins'),
#                             ('Gender', 'Neut'),
#                             ('Number', 'Sing')])),
#               ('head', 11),
#               ('deprel', 'amod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0029')]))]),
#  OrderedDict([('id', 11),
#               ('form', 'передбаченням'),
#               ('lemma', 'передбачення'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncnsin'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Ins'),
#                             ('Gender', 'Neut'),
#                             ('Number', 'Sing')])),
#               ('head', 9),
#               ('deprel', 'xcomp:sp'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002a'), ('SpaceAfter', 'No')]))]),
#  OrderedDict([('id', 12),
#               ('form', ':'),
#               ('lemma', ':'),
#               ('upostag', 'PUNCT'),
#               ('xpostag', 'U'),
#               ('feats', None),
#               ('head', 23),
#               ('deprel', 'punct'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002b')]))]),
#  OrderedDict([('id', 13),
#               ('form', 'за'),
#               ('lemma', 'за'),
#               ('upostag', 'ADP'),
#               ('xpostag', 'Spsa'),
#               ('feats', OrderedDict([('Case', 'Acc')])),
#               ('head', 15),
#               ('deprel', 'case'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002c')]))]),
#  OrderedDict([('id', 14),
#               ('form', 'якесь'),
#               ('lemma', 'якийсь'),
#               ('upostag', 'DET'),
#               ('xpostag', 'Pi--n-saa'),
#               ('feats',
#                OrderedDict([('Case', 'Acc'),
#                             ('Gender', 'Neut'),
#                             ('Number', 'Sing'),
#                             ('PronType', 'Ind')])),
#               ('head', 15),
#               ('deprel', 'det'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002d')]))]),
#  OrderedDict([('id', 15),
#               ('form', 'десятиліття'),
#               ('lemma', 'десятиліття'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncnsan'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Acc'),
#                             ('Gender', 'Neut'),
#                             ('Number', 'Sing')])),
#               ('head', 23),
#               ('deprel', 'obl'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002e')]))]),
#  OrderedDict([('id', 16),
#               ('form', 'після'),
#               ('lemma', 'після'),
#               ('upostag', 'ADP'),
#               ('xpostag', 'Spsg'),
#               ('feats', OrderedDict([('Case', 'Gen')])),
#               ('head', 17),
#               ('deprel', 'case'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002f')]))]),
#  OrderedDict([('id', 17),
#               ('form', 'написання'),
#               ('lemma', 'написання'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncnsgn'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Gen'),
#                             ('Gender', 'Neut'),
#                             ('Number', 'Sing')])),
#               ('head', 15),
#               ('deprel', 'nmod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002g')]))]),
#  OrderedDict([('id', 18),
#               ('form', 'твору'),
#               ('lemma', 'твір'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncmsgn'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Gen'),
#                             ('Gender', 'Masc'),
#                             ('Number', 'Sing')])),
#               ('head', 17),
#               ('deprel', 'nmod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002h')]))]),
#  OrderedDict([('id', 19),
#               ('form', 'несамовиті'),
#               ('lemma', 'несамовитий'),
#               ('upostag', 'ADJ'),
#               ('xpostag', 'Ao--pns'),
#               ('feats', OrderedDict([('Case', 'Nom'), ('Number', 'Plur')])),
#               ('head', 20),
#               ('deprel', 'amod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002i')]))]),
#  OrderedDict([('id', 20),
#               ('form', 'ревнителі'),
#               ('lemma', 'ревнитель'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncmpny'),
#               ('feats',
#                OrderedDict([('Animacy', 'Anim'),
#                             ('Case', 'Nom'),
#                             ('Gender', 'Masc'),
#                             ('Number', 'Plur')])),
#               ('head', 23),
#               ('deprel', 'nsubj'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002j')]))]),
#  OrderedDict([('id', 21),
#               ('form', 'нового'),
#               ('lemma', 'новий'),
#               ('upostag', 'ADJ'),
#               ('xpostag', 'Afpmsgf'),
#               ('feats',
#                OrderedDict([('Case', 'Gen'),
#                             ('Degree', 'Pos'),
#                             ('Gender', 'Masc'),
#                             ('Number', 'Sing')])),
#               ('head', 22),
#               ('deprel', 'amod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002k')]))]),
#  OrderedDict([('id', 22),
#               ('form', 'ладу'),
#               ('lemma', 'лад'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncmsgn'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Gen'),
#                             ('Gender', 'Masc'),
#                             ('Number', 'Sing')])),
#               ('head', 20),
#               ('deprel', 'nmod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002l')]))]),
#  OrderedDict([('id', 23),
#               ('form', 'почали'),
#               ('lemma', 'почати'),
#               ('upostag', 'VERB'),
#               ('xpostag', 'Vmeis-p'),
#               ('feats',
#                OrderedDict([('Aspect', 'Perf'),
#                             ('Mood', 'Ind'),
#                             ('Number', 'Plur'),
#                             ('Tense', 'Past'),
#                             ('VerbForm', 'Fin')])),
#               ('head', 9),
#               ('deprel', 'parataxis'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002m')]))]),
#  OrderedDict([('id', 24),
#               ('form', 'нищити'),
#               ('lemma', 'нищити'),
#               ('upostag', 'VERB'),
#               ('xpostag', 'Vmpn'),
#               ('feats', OrderedDict([('Aspect', 'Imp'), ('VerbForm', 'Inf')])),
#               ('head', 23),
#               ('deprel', 'xcomp'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002n')]))]),
#  OrderedDict([('id', 25),
#               ('form', 'культурні'),
#               ('lemma', 'культурний'),
#               ('upostag', 'ADJ'),
#               ('xpostag', 'Afp-pasn'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Acc'),
#                             ('Degree', 'Pos'),
#                             ('Number', 'Plur')])),
#               ('head', 26),
#               ('deprel', 'amod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002o')]))]),
#  OrderedDict([('id', 26),
#               ('form', 'скарби'),
#               ('lemma', 'скарб'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncmpan'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Acc'),
#                             ('Gender', 'Masc'),
#                             ('Number', 'Plur')])),
#               ('head', 24),
#               ('deprel', 'obj'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002p'), ('SpaceAfter', 'No')]))]),
#  OrderedDict([('id', 27),
#               ('form', ','),
#               ('lemma', ','),
#               ('upostag', 'PUNCT'),
#               ('xpostag', 'U'),
#               ('feats', None),
#               ('head', 33),
#               ('deprel', 'punct'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002q')]))]),
#  OrderedDict([('id', 28),
#               ('form', 'до'),
#               ('lemma', 'до'),
#               ('upostag', 'ADP'),
#               ('xpostag', 'Spsg'),
#               ('feats', OrderedDict([('Case', 'Gen')])),
#               ('head', 33),
#               ('deprel', 'cc'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002r')]))]),
#  OrderedDict([('id', 29),
#               ('form', 'того'),
#               ('lemma', 'те'),
#               ('upostag', 'PRON'),
#               ('xpostag', 'Pd--nnsgn'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Gen'),
#                             ('Gender', 'Neut'),
#                             ('Number', 'Sing'),
#                             ('PronType', 'Dem')])),
#               ('head', 28),
#               ('deprel', 'fixed'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002s')]))]),
#  OrderedDict([('id', 30),
#               ('form', 'ж'),
#               ('lemma', 'ж'),
#               ('upostag', 'PART'),
#               ('xpostag', 'Q'),
#               ('feats', None),
#               ('head', 28),
#               ('deprel', 'fixed'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002t')]))]),
#  OrderedDict([('id', 31),
#               ('form', 'засобами'),
#               ('lemma', 'засіб'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncmpin'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Ins'),
#                             ('Gender', 'Masc'),
#                             ('Number', 'Plur')])),
#               ('head', 33),
#               ('deprel', 'obj'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002u')]))]),
#  OrderedDict([('id', 32),
#               ('form', 'вони'),
#               ('lemma', 'вони'),
#               ('upostag', 'PRON'),
#               ('xpostag', 'Pp-3--pnn'),
#               ('feats',
#                OrderedDict([('Case', 'Nom'),
#                             ('Number', 'Plur'),
#                             ('Person', '3'),
#                             ('PronType', 'Prs')])),
#               ('head', 33),
#               ('deprel', 'nsubj'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002v')]))]),
#  OrderedDict([('id', 33),
#               ('form', 'володіли'),
#               ('lemma', 'володіти'),
#               ('upostag', 'VERB'),
#               ('xpostag', 'Vmpis-p'),
#               ('feats',
#                OrderedDict([('Aspect', 'Imp'),
#                             ('Mood', 'Ind'),
#                             ('Number', 'Plur'),
#                             ('Tense', 'Past'),
#                             ('VerbForm', 'Fin')])),
#               ('head', 23),
#               ('deprel', 'conj'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002w')]))]),
#  OrderedDict([('id', 34),
#               ('form', 'непорівнянно'),
#               ('lemma', 'непорівнянно'),
#               ('upostag', 'ADV'),
#               ('xpostag', 'R'),
#               ('feats', None),
#               ('head', 35),
#               ('deprel', 'advmod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002x')]))]),
#  OrderedDict([('id', 35),
#               ('form', 'потужнішими'),
#               ('lemma', 'потужніший'),
#               ('upostag', 'ADJ'),
#               ('xpostag', 'Afc-pif'),
#               ('feats',
#                OrderedDict([('Case', 'Ins'),
#                             ('Degree', 'Cmp'),
#                             ('Number', 'Plur')])),
#               ('head', 31),
#               ('deprel', 'amod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002y'), ('SpaceAfter', 'No')]))]),
#  OrderedDict([('id', 36),
#               ('form', ','),
#               ('lemma', ','),
#               ('upostag', 'PUNCT'),
#               ('xpostag', 'U'),
#               ('feats', None),
#               ('head', 39),
#               ('deprel', 'punct'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '002z')]))]),
#  OrderedDict([('id', 37),
#               ('form', 'аніж'),
#               ('lemma', 'аніж'),
#               ('upostag', 'SCONJ'),
#               ('xpostag', 'Css'),
#               ('feats', None),
#               ('head', 39),
#               ('deprel', 'mark'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0030')]))]),
#  OrderedDict([('id', 38),
#               ('form', 'гнані'),
#               ('lemma', 'гнаний'),
#               ('upostag', 'ADJ'),
#               ('xpostag', 'Ap--pns-pp'),
#               ('feats',
#                OrderedDict([('Aspect', 'Imp'),
#                             ('Case', 'Nom'),
#                             ('Number', 'Plur'),
#                             ('VerbForm', 'Part'),
#                             ('Voice', 'Pass')])),
#               ('head', 39),
#               ('deprel', 'amod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0031')]))]),
#  OrderedDict([('id', 39),
#               ('form', 'сектярі'),
#               ('lemma', 'сектяр'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncmpny'),
#               ('feats',
#                OrderedDict([('Animacy', 'Anim'),
#                             ('Case', 'Nom'),
#                             ('Gender', 'Masc'),
#                             ('Number', 'Plur')])),
#               ('head', 35),
#               ('deprel', 'advcl'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0032')]))]),
#  OrderedDict([('id', 40),
#               ('form', 'при'),
#               ('lemma', 'при'),
#               ('upostag', 'ADP'),
#               ('xpostag', 'Spsl'),
#               ('feats', OrderedDict([('Case', 'Loc')])),
#               ('head', 41),
#               ('deprel', 'case'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0033')]))]),
#  OrderedDict([('id', 41),
#               ('form', 'початку'),
#               ('lemma', 'початок'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncmsln'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Loc'),
#                             ('Gender', 'Masc'),
#                             ('Number', 'Sing')])),
#               ('head', 39),
#               ('deprel', 'nmod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0034')]))]),
#  OrderedDict([('id', 42),
#               ('form', 'християнської'),
#               ('lemma', 'християнський'),
#               ('upostag', 'ADJ'),
#               ('xpostag', 'Ao-fsgf'),
#               ('feats',
#                OrderedDict([('Case', 'Gen'),
#                             ('Gender', 'Fem'),
#                             ('Number', 'Sing')])),
#               ('head', 43),
#               ('deprel', 'amod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0035')]))]),
#  OrderedDict([('id', 43),
#               ('form', 'ери'),
#               ('lemma', 'ера'),
#               ('upostag', 'NOUN'),
#               ('xpostag', 'Ncfsgn'),
#               ('feats',
#                OrderedDict([('Animacy', 'Inan'),
#                             ('Case', 'Gen'),
#                             ('Gender', 'Fem'),
#                             ('Number', 'Sing')])),
#               ('head', 41),
#               ('deprel', 'nmod'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0036'), ('SpaceAfter', 'No')]))]),
#  OrderedDict([('id', 44),
#               ('form', '.'),
#               ('lemma', '.'),
#               ('upostag', 'PUNCT'),
#               ('xpostag', 'U'),
#               ('feats', None),
#               ('head', 9),
#               ('deprel', 'punct'),
#               ('deps', None),
#               ('misc', OrderedDict([('Id', '0037')]))])]

# %%
# generate features
def extract_features(stack, queue, rel, history_step1, histiry_step2):
    #print("stack",stack)
    stack1=stack[-1]['lemma'] if len(stack)>0 else ''
    stack2=stack[-2]['lemma'] if len(stack)>1 else ''
    stack3=stack[-3]['lemma'] if len(stack)>2 else ''
    queue1=queue[0]['lemma'] if len(queue)>0 else ''
    queue2=queue[1]['lemma'] if len(queue)>1 else ''
    queue3=queue[2]['lemma'] if len(queue)>2 else ''
    queue4=queue[3]['lemma'] if len(queue)>4 else ''
    
    features = dict()
    if len(stack) > 0:
        stack_top = stack[-1]
        s0_features = get_pymorphy_word_features(stack_top["form"],'s0_',stack2,queue1, True  )
    else:
        s0_features = get_pymorphy_word_features('there_is_no_word','s0_',stack2,queue1 , True )
    features = {**features, **s0_features}
    
    if len(stack) > 1:
        s1_features = get_pymorphy_word_features(stack[-2]["form"],'s1_',stack2,queue1 , True )
    else:
        s1_features = get_pymorphy_word_features('there_is_no_word','s1_',stack2,queue1, True )
    features = {**features, **s1_features}
    
        
    if queue:
        queue_top = queue[0]
        q0_features = get_pymorphy_word_features(queue_top["form"],'q0_',stack1,queue2, True )
    else: 
        q0_features = get_pymorphy_word_features('there_is_no_word','q0_',stack1,queue2, True )
    features = {**features, **q0_features}
    
    if len(queue)>1:
        queue1 = queue[1]
        q1_features = get_pymorphy_word_features(queue1["form"],'q1_',stack1,queue3)
    else: 
        q1_features = get_pymorphy_word_features('there_is_no_word','q1_',stack1,queue3)
    features = {**features, **q1_features}
    
    if len(queue)>1:
        queue1 = queue[1]
        q2_features = get_pymorphy_word_features(queue1["form"],'q2_',stack1,queue4)
    else: 
        q2_features = get_pymorphy_word_features('there_is_no_word','q2_',stack1,queue4)
    features = {**features, **q2_features}
    
    features['history_step1']=history_step1
    features['histiry_step2']=histiry_step2


    features['stack_len']=len(stack)
    features['queue_len']=len(queue)
    features['rel_len']=len(rel)
    features['parrent_of']= sum([int(i[1]==stack_top['id']) for i in rel])
    if stack and queue:
        features["distance"] = queue[0]["id"] - stack[-1]["id"]
        features["word_index"] = queue[0]["id"]
    else:
        features["distance"]=-1
        features["word_index"]=-1
    return features

import pymorphy2
morph = pymorphy2.MorphAnalyzer(lang='uk')

def get_pymorphy_word_features(word, prefix, left, right, add_embeding=False):
    word_info = morph.parse(word)[0]
    try:
        left_tag = morph.parse(left)[0].tag.POS
    except:
        left_tag=''
    try:
        right_tag = morph.parse(right)[0].tag.POS
    except:
        right_tag=''

    features = dict()
    if add_embeding:
        try:
            word_vector=model.get_vector(word_info.normal_form.lower())
        except:
            word_vector=[0]*300
        for i in range(0,300):
            features[prefix+'vector+'+str(i)]=word_vector[i]
    features[prefix+'POS']=word_info.tag.POS
    features[prefix+'animacy']=word_info.tag.animacy
    features[prefix+'aspect']=word_info.tag.aspect
    features[prefix+'case']=word_info.tag.case
    features[prefix+'number']=word_info.tag.number
    features[prefix+'number']=word_info.tag.number
    features[prefix+'person']=word_info.tag.person
    features[prefix+'tense']=word_info.tag.tense
    features[prefix+'transitivity']=word_info.tag.transitivity
    features[prefix+'left_item']= '{0}_{1}'.format(left_tag, word_info.tag.POS)
    features[prefix+'item_right']= '{0}_{1}'.format(word_info.tag.POS,right_tag)
    features[prefix+'left_right']= '{0}_{1}'.format(left_tag, right_tag)

    return features

# %%
model.init_sims(replace=True)

# %% [markdown]
# # collect  features

# %%
label_encode_columns = ['POS','animacy','aspect','case','number','person','tense','item','left_right','pref','suf']

# %%
from sklearn import preprocessing
label_encoders={}

# %%
label_encoders
# Out:
# {'POS': LabelEncoder(),
#  'animacy': LabelEncoder(),
#  'aspect': LabelEncoder(),
#  'case': LabelEncoder(),
#  'item': LabelEncoder(),
#  'left_right': LabelEncoder(),
#  'number': LabelEncoder(),
#  'person': LabelEncoder(),
#  'tense': LabelEncoder()}

# %%
import pandas as pd

# %%
def get_vectors(trees):
    from tqdm import tqdm
    features =[]
    labels = []
    dep_labels = []


    for index in tqdm(range(0,len(trees))):
        tree=trees[index]
        o = oracle(tree.copy())
        parsed_relations = o.do_steps()
        features=features + o.features
        labels=labels + o.labels
        dep_labels=dep_labels+o.dep
    
    features_df = pd.DataFrame(features)
    features_df.shape
    features_df.fillna(0, inplace=True)
    #print(features_df)
    for sub in label_encode_columns:
        for col in features_df.columns:
            if sub in col:
                if sub not in label_encoders:
                    #print('train encoder', sub)
                    label_encoders[sub]= preprocessing.LabelEncoder()
                    val = []
                    for col_serch in features_df.columns:
                        if sub in col_serch:
                            features_df[col_serch]=features_df[col_serch].astype(str)
                            val.append(features_df[col_serch].values)
                    label_encoders[sub].fit(np.concatenate(val))
                #print(col)
                features_df[col]=features_df[col].astype(str)
                safe_transform(label_encoders[sub],features_df, col)
    return features_df, labels, dep_labels

# %%
def safe_transform(labelEncoder, df,column_name):
    dic =dict(zip(labelEncoder.classes_, labelEncoder.transform(labelEncoder.classes_)))
    df[column_name]=df[column_name].map(dic).fillna(-1).astype(int)

# %%
with open('../UD_Ukrainian-IU/uk_iu-ud-train.conllu') as f:
    c= f.read()
    trees= parse(c)

X_train, y_train, y_train_dep =get_vectors(trees)
# Out:
# 100%|██████████| 4513/4513 [06:23<00:00, 11.76it/s]
# q0_POS
# q1_POS
# q2_POS
# s0_POS
# s1_POS
# q0_animacy
# q1_animacy
# q2_animacy
# s0_animacy
# s1_animacy
# q0_aspect
# q1_aspect
# q2_aspect
# s0_aspect
# s1_aspect
# q0_case
# q1_case
# q2_case
# s0_case
# s1_case
# q0_number
# q1_number
# q2_number
# s0_number
# s1_number
# q0_person
# q1_person
# q2_person
# s0_person
# s1_person
# q0_tense
# q1_tense
# q2_tense
# s0_tense
# s1_tense
# q0_item_right
# q0_left_item
# q1_item_right
# q1_left_item
# q2_item_right
# q2_left_item
# s0_item_right
# s0_left_item
# s1_item_right
# s1_left_item
# q0_left_right
# q1_left_right
# q2_left_right
# s0_left_right
# s1_left_right

# %%
1+1
# Out:
# 2

# %%
y_train = [i.value for i in y_train]

# %% [markdown]
# # get test

# %%
with open('../UD_Ukrainian-IU/uk_iu-ud-test.conllu') as f:
    c= f.read()
    trees= parse(c)

X_test, y_test, y_test_dep =get_vectors(trees)
y_test = [i.value for i in y_test]
# Out:
# 100%|██████████| 783/783 [01:03<00:00, 12.34it/s]
# q0_POS
# q1_POS
# q2_POS
# s0_POS
# s1_POS
# q0_animacy
# q1_animacy
# q2_animacy
# s0_animacy
# s1_animacy
# q0_aspect
# q1_aspect
# q2_aspect
# s0_aspect
# s1_aspect
# q0_case
# q1_case
# q2_case
# s0_case
# s1_case
# q0_number
# q1_number
# q2_number
# s0_number
# s1_number
# q0_person
# q1_person
# q2_person
# s0_person
# s1_person
# q0_tense
# q1_tense
# q2_tense
# s0_tense
# s1_tense
# q0_item_right
# q0_left_item
# q1_item_right
# q1_left_item
# q2_item_right
# q2_left_item
# s0_item_right
# s0_left_item
# s1_item_right
# s1_left_item
# q0_left_right
# q1_left_right
# q2_left_right
# s0_left_right
# s1_left_right

# %%
import gc
gc.collect()
# Out:
# 45363

# %%
1+1
# Out:
# 2

# %%
test_trees=trees

# %% [markdown]
# # build model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(max_depth=19, random_state=0)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=19, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
predicted_test = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predicted_test, target_names=['Left','Right','Reduse','Shift']))
# Out:
#              precision    recall  f1-score   support
#
#        Left       0.81      0.90      0.86      7352
#       Right       0.76      0.77      0.76      7182
#      Reduse       0.82      0.76      0.79      8370
#       Shift       0.87      0.84      0.86      7757
#
# avg / total       0.82      0.82      0.82     30661

# %% [markdown]
# # feature importance

# %%
 X_test.columns[clf.feature_importances_.argsort()[::-1][:40]]
# Out:
# Index(['distance', 'queue_len', 'q0_item_right', 'q1_left_item', 'q2_POS',
#        'word_index', 'history_step1', 'q0_vector+173', 'q0_vector+197',
#        'q0_left_item', 'q2_left_item', 'q0_vector+100', 'parrent_of',
#        'q0_case', 's0_item_right', 'q0_POS', 'q2_left_right', 'q2_case',
#        'q0_animacy', 'q0_aspect', 'q0_tense', 'q1_case', 'q0_vector+13',
#        'q0_vector+126', 'q1_POS', 'q0_vector+230', 'q1_item_right',
#        'q0_vector+41', 'q0_vector+293', 'q0_vector+175', 'q0_vector+32',
#        'histiry_step2', 'q2_item_right', 'q0_vector+149', 'q0_vector+240',
#        'q1_left_right', 'q0_left_right', 's0_animacy', 'q0_vector+250',
#        's0_aspect'],
#       dtype='object')

# %% [markdown]
# # generate featurs

# %%
next steps:
1 fix bugs in oracl transitions
4 запустити лайт gbm
5 динамічний оракул

# %% [markdown]
# # Calculate the unlabeled attachment score

# %%
def get_df_features(features): 
    features_df = pd.DataFrame(features)
    features_df.shape
    features_df.fillna(0, inplace=True)
    #print(features_df)
    for sub in label_encode_columns:
        for col in features_df.columns:
            if sub in col:
                if sub not in label_encoders:
                    #print('train encoder', sub)
                    label_encoders[sub]= preprocessing.LabelEncoder()
                    val = []
                    for col_serch in features_df.columns:
                        if sub in col_serch:
                            features_df[col_serch]=features_df[col_serch].astype(str)
                            val.append(features_df[col_serch].values)
                    label_encoders[sub].fit(np.concatenate(val))
                #print(col)
                features_df[col]=features_df[col].astype(str)
                safe_transform(label_encoders[sub],features_df, col)
    return features_df

# %%
def dep_parse(sentence, model):
    stack, queue, relations = [OrderedDict([('id', 0),('form','ROOT'),("head",0),("lemma","root")])], sentence[:], []
    history_step1=-1
    history_step2=-1
    while queue or stack:
        if stack and not queue:
            stack.pop()
        else:
            features = extract_features(stack, queue, relations,history_step1, history_step2)
            df = get_df_features([features])
            action = model.predict(df.values)[0]
            # actual parsing
            if action == 4: #:Action_type.Shift:
                stack.append(queue.pop(0))
            elif action == 3: #:Action_type.Reduse:
                stack.pop()
            elif action == 1: #Action_type.Left:
                relations.append((stack[-1]["id"], queue[0]["id"]))
                stack.pop()
            elif action == 2: #Action_type.Right:
                relations.append((queue[0]["id"], stack[-1]["id"]))
                stack.append(queue.pop(0))
            else:
                print("Unknown action.", action)
            histiry_step2=history_step1
            history_step1=action
    return sorted(relations)

# %%
print([node["form"] for node in test_trees[1]])
print(dep_parse(test_trees[1], clf))
print([(node["id"], node["head"]) for node in test_trees[1]])
# Out:
# ['Продавши', 'свій', 'шедевр', 'Меценатові', ',', 'еллінський', 'скульптор', 'споневажив', 'саме', 'мистецтво', ':', 'Ти', 'не', 'продався', ',', '—', 'гірше', '!']
# [(1, 0), (2, 3), (3, 1), (4, 3), (5, 8), (6, 7), (7, 8), (8, 1), (9, 10), (10, 8), (11, 14), (12, 14), (13, 14), (14, 1), (15, 1), (18, 1)]
# [(1, 8), (2, 3), (3, 1), (4, 1), (5, 1), (6, 7), (7, 8), (8, 0), (9, 10), (10, 8), (11, 14), (12, 14), (13, 14), (14, 8), (15, 17), (16, 17), (17, 14), (18, 14)]

# %%
gc.collect()
# Out:
# 613

# %%
from tqdm import tqdm 
total, tp = 0, 0
for index in tqdm(range(0,len(test_trees))):
    tree=test_trees[index]
    golden = [(node["id"], node["head"]) for node in tree]
    predicted = dep_parse(tree, clf)
    total += len(tree)
    tp += len(set(golden).intersection(set(predicted)))

print("Total:", total)
print("Correctly defined:", tp)
print("UAS:", round(tp/total, 2))
# Out:
#   0%|          | 0/783 [00:00<?, ?it/s]
#   0%|          | 1/783 [00:01<25:58,  1.99s/it]
#   0%|          | 2/783 [00:06<39:41,  3.05s/it]
# Exception in thread Thread-25:
# Traceback (most recent call last):
#   File "/Users/grycshuknazar/anaconda2/envs/env_36/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Users/grycshuknazar/anaconda2/envs/env_36/lib/python3.6/site-packages/tqdm/_tqdm.py", line 148, in run
#     for instance in self.tqdm_cls._instances:
#   File "/Users/grycshuknazar/anaconda2/envs/env_36/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#
# 100%|██████████| 783/783 [48:16<00:00,  3.70s/it]
# Total: 14939
# Correctly defined: 9950
# UAS: 0.67
