# %%
# %matplotlib inline

import pandas as pd 
import numpy as np
import itertools

import tokenize_uk
import cld3
import pymorphy2

from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score, classification_report, confusion_matrix

from sklearn.utils import resample

import matplotlib.pyplot as plt

# %%
df = pd.read_json('reviews.json')

df['text'] = df['text'].apply(lambda x: ' '.join(x))
df['lang'] = df['text'].apply(lambda x: cld3.get_language(x)[0])

# %% [markdown]
# #### Distribution among classes:

# %%
df.groupby(['stars'])['text'].count()
# Out:
# stars
# 1     2305
# 2     2304
# 3     4676
# 4    15051
# 5    42405
# Name: text, dtype: int64

# %%
df.groupby(['lang']).count().reset_index().sort_values(['stars'], ascending=False)
# Out:
#        lang  stars   text
# 36       ru  55852  55852
# 43       uk   9871   9871
# 3        bg    261    261
# 2        be    184    184
# 38       sr    117    117
# 29       mn    101    101
# 28       mk     74     74
# 24       ky     61     61
# 42       tg     44     44
# 22       kk     35     35
# 20       ja     33     33
# 4        ca     12     12
# 33       pl     11     11
# 37  ru-Latn      9      9
# 7        en      6      6
# 34       pt      6      6
# 11       fr      4      4
# 12       fy      4      4
# 39       st      3      3
# 32       no      3      3
# 14  hi-Latn      3      3
# 5        cy      3      3
# 6        de      3      3
# 15      hmn      3      3
# 13       ga      3      3
# 44       vi      3      3
# 46       yo      2      2
# 30       mt      2      2
# 47       zh      2      2
# 0        af      2      2
# 27       lt      2      2
# 25       la      2      2
# 1        az      2      2
# 9        es      2      2
# 17       hu      2      2
# 41       sv      1      1
# 8        eo      1      1
# 45       xh      1      1
# 10       et      1      1
# 16       ht      1      1
# 18       id      1      1
# 40       su      1      1
# 31       nl      1      1
# 19       is      1      1
# 21       jv      1      1
# 23       ku      1      1
# 35       ro      1      1
# 26       lb      1      1
# 48  zh-Latn      1      1

# %% [markdown]
# ##### CLD detected other languages except ru and uk, let's see what are those
# Some of them are full of numbers and abbreviations, some of them are legit reviews:

# %%
df.query('lang in ("lb", "ro", "ku", "jv", "is", "nl", "su", "id", "ht", "et", "xh", "eo", "sv", "hu", "es", "az")')
# Out:
#        stars                                               text lang
# 653        5                                    Супер миксер!!!   eo
# 4439       4                                  Чайник как чайник   et
# 7867       3                              проработал ровно год.   ro
# 11498      5                                         Це фул хд?   ht
# 12947      4  CrystalDiskMark test : Read 240 MB/s, Write 23...   hu
# 15886      4                      Какое разшерение экрана? FHD?   lb
# 18598      4                              MSI Z370 gaming plus?   id
# 18618      5                        Совместим ли с Asus Z170-A?   es
# 22307      5                                               Мыщь   sv
# 29168      4                           Для её цены хорошая мышь   is
# 45473      5                                      Уши супер!!!!   xh
# 49237      5                                  Здесь kaby lake ?   jv
# 49791      4                                     это IPS экран?   nl
# 54974      5                                     #ThankYouSteve   hu
# 63268      5  Biostar H55A , xeon x3440 в разгоне до 4ггц, g...   ku
# 63722      4  Msi b350 tomahawk arctic, ryzen 5 1600, msi gt...   su
# 64166      5                           Gtx 1060 i5 4460 8gb ram   az
# 65081      5      Поместиться ли в корпус IN WIN 703 Black/Red?   az
# 65468      3                                       Кулер 89 см.   es

# %% [markdown]
# Some transliteration:

# %%
df.query('lang in ("ru-Latn")')
# Out:
#        stars                                               text     lang
# 3751       5  Prekrasnaya i praktichnaya mashyna. Protestiro...  ru-Latn
# 31156      4  Otli4nie ushi, skuzhat uzhe 6 let, dazhe sey4a...  ru-Latn
# 31736      4  Pol'zovalsja porta pro i etimi, membrani poxoz...  ru-Latn
# 39266      4                             А откуда идёт посылка?  ru-Latn
# 39490      3  slomalis cherez 2 nedeli v sumke Достоинства: ...  ru-Latn
# 41563      4  Horoshaya model'. Oni nebol'shie po sravneniyu...  ru-Latn
# 47502      4  poka rabotayut Достоинства: horoshiy zvuk, udo...  ru-Latn
# 51107      4                                     vse nravitsya!  ru-Latn
# 64278      5  Потянет gigabyte gtx 1060 6gb. Extreme Gaming?...  ru-Latn

# %% [markdown]
# Here are some very clear 5 star reviews (which are detected as `be` I think due to the length of string)

# %%
df.query('lang in ("be")')
# Out:
#        stars                                               text lang
# 395        5                                              супер   be
# 973        5                                            Супер!)   be
# 1613       5                                              супер   be
# 1944       5                                             Супер!   be
# 2219       5                                              Супер   be
# 2317       5                                              Супер   be
# 3446       5                   Какая разница между х700 и х710?   be
# 3872       5                                              супер   be
# 4239       5  Качество выше цены! Достоинства: Качество выше...   be
# 4280       5                   Классный чайник за такую цену!!!   be
# 4604       4                                              Дякую   be
# 6055       5                                          СУПЕР )))   be
# 6119       5                                              супер   be
# 6372       5                                              супер   be
# 7107       5                                  Дешёвый . Быстрый   be
# 7226       4  по работал 4 месяца и перестал зараджатись не ...   be
# 7612       5                   Потянет программы для монтажа???   be
# 7689       5                                        Быстрый ссд   be
# 8358       5                                            Быстрая   be
# 8556       5  Підійде на acer aspire e5-574g- 58kO замість д...   be
# 8757       5                                             супер,   be
# 9660       4            Підійде на ноут HP pavilion g6-2397 er?   be
# 10220      5  моя распаковка планшета Lenovo Tab 3 Essential...   be
# 10979      5                     Камера, прямо скажем, зачетная   be
# 11223      5                                              Супер   be
# 11291      5                                         Всё супер!   be
# 12013      5                                             супер"   be
# 12226      5                                  Дуже гарна камера   be
# 12583      5                              К dell 7537 подойдёт?   be
# 13393      5  Что надёжней и долговечней: Kingston SSDNow V3...   be
# ...      ...                                                ...  ...
# 51227      5                                   Шустрый ноутбук.   be
# 51363      5                                             Супер!   be
# 52063      4                        Какая здесь матрица?? IPS??   be
# 52157      5                                  А каэс пайдет????   be
# 52807      5                                              Супер   be
# 53172      5                                     #мояраспаковка   be
# 54020      5                           українська. ціна хороша.   be
# 55048      5                                              Супер   be
# 55559      4                      Два месяца, полёт нормальный.   be
# 55904      4                                           Неплохая   be
# 56392      5  оперативная выход на связь менеджера...а также...   be
# 57000      3                           нормальная штука, мощная   be
# 63729      5                                    Хороший товар   mn
# 64266      5              блок хороший. жужит тихонечко...)))   mn
# 64647      5                                       Всё хорошо   mn
# 64764      5                                            хорош   mn
# 64781      5                              Тихий, очень тихий)   mn
# 64971      4      Хто уже бралподскажыте а он сильно шумит???   mn
# 65524      5                                 Хороший и тихий!   mn
# 66158      5                                    хороший блок!   mn
# 66304      5                         Хороший и очень тихий БП   mn
# 66450      5                                   Шикарний блок)   mn
# 66467      5                            Хороший бюджетный БП.   mn
#
# [101 rows x 3 columns]

# %% [markdown]
# If we filter out all those and take only ru and uk reviews, distibution is still more or less same as initial. 1, 2 and 3 stars reviews
# weren't filtered out.

# %%
data = df.query('lang in ("uk", "ru")')
print('Initial:', len(df), 'Filtered:', len(data))

data.groupby(['stars'])['text'].count()
# Out:
# Initial: 66741 Filtered: 65723
# stars
# 1     2298
# 2     2297
# 3     4642
# 4    14870
# 5    41616
# Name: text, dtype: int64

# %% [markdown]
# #### Feature engineering
# First, I'll try to use inly reviews with correctly detected language

# %% [markdown]
# I found that some reviews aren't reviews but simple questions, like:
# review `Страна производитель?` with 5 stars. I think those may need special treatment

# %%
def is_question(text): 
    return text.strip().endswith('?')
    
        
data['is_question'] = data['text'].apply(lambda x: is_question(x))
data[(data['is_question'] == True) & (data['stars'] == 5)]
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        stars                                               text lang  \
# 1          5  Вопрос к представителю:. Можно ли надеяться на...   ru
# 7          5  Майнкрафт на минимальных настройках графики по...   ru
# 8          5                      Adobe P и Adobe I как пойдут?   ru
# 32         5  Доброго времени суток. Подскажите пожалуйста, ...   ru
# 66         5  Добрый день. Подскажите пожалуйста, в данной м...   ru
# 565        5  Очень довольны покупкой!но вопрос Можно ли им ...   ru
# 614        5  Блендер дуже хороший, вся сім'я залишилась рад...   uk
# 660        5  Добрый день!  Сегодня получила эту модель, под...   ru
# 666        5  Добрый день,подскажите прошу  гарантия есть на...   ru
# 698        5  Я очень рада что купила именно этот блендер! Д...   ru
# 772        5  Підкажіть будь ласка чи можна купити кришку до...   uk
# 1069       5                        Какая страна производитель?   ru
# 1297       5  Скажите, пожалуйста есть ли таймер на автомати...   ru
# 1309       5  Закинул шоколад Корона, завоняло пластмассой))...   ru
# 1402       5  Підкажіть чи можна купити чашу для блендера ок...   uk
# 1450       5     Є можливість подрібнювати лід даним блендером?   uk
# 1473       5  Напишите плиз после приготовления отключается ...   ru
# 1550       5                              Страна производитель?   ru
# 1740       5  для каких продуктов нужно использовать режим т...   ru
# 1936       5  А есть насадка для нарезки кубиками? И модно л...   ru
# 1968       5  Подскажите, а отдельно телескопические направл...   ru
# 2113       5  Подскажите где находится сервисный центр в Кри...   ru
# 2194       5  Сам миксер съёмный? Можно им пользоваться как ...   ru
# 2229       5  Сам миксер съёмный? Можно им пользоваться как ...   ru
# 2345       5  цена-качество вполне устраивает,425 ватт-это н...   ru
# 2383       5  Данная кофеварка отключается автоматически пос...   ru
# 2855       5  Собираюсь купить. Подскажите: меню на русском ...   ru
# 2919       5                            А что в комплекте есть?   ru
# 2934       5  Скажите пожалуйста, зачем нужен второй USB каб...   ru
# 2967       5  Я хочу такуж,як її тепер заказати як вона закі...   uk
# ...      ...                                                ...  ...
# 66291      5          Подойдет ли к материнской плате Asus m3a?   ru
# 66292      5                 Хватит этого блока для gtx960 4gb?   ru
# 66337      5  Вопрос к представителю компании. Подойдет ли э...   ru
# 66339      5  Купил блок пару дней назад, решил подключить к...   ru
# 66350      5  Потянет ли данный блок питания сборку на проце...   ru
# 66357      5                             Подойдет для gtx 1050?   ru
# 66370      5  Доброго времени суток! Когда появится данный т...   ru
# 66395      5                     У него есть сертификация 80+ ?   ru
# 66417      5  Вопрос представителю компании. Этот БП годится...   ru
# 66430      5  Могу ли я купив этот БП в случае нехватки мощн...   ru
# 66512      5  а для inno 3d gtx770 , intel core i5-4670K и M...   ru
# 66553      5                    Подскажите потянет он R9 390X ?   uk
# 66555      5  Брал для r9 290 + fx8300 (4,7GHz). Cо своей за...   ru
# 66579      5        Хватит ли мощности для i7 8700k и gtx 1080?   ru
# 66587      5  Отличный блок - год назад гарантия была 60 мес...   ru
# 66595      5  i3-6100 Msi H110m pro-vd DDR4 8GB(2x4) Msi GTX...   ru
# 66598      5           Подскажите, а подойдет этот блок к 4340?   ru
# 66609      5  Ребят , на данном блоке никаких проблем с разг...   ru
# 66612      5                Есть ли в комплекте кабель к блоку?   ru
# 66613      5  Здравствуйте! Хотел бы спросить, данный блок п...   ru
# 66619      5  Материнская плата ASUS P5K-VM, Процессор Intel...   ru
# 66622      5                Под i3 6100 и GTX 1050 Ti подойдет?   ru
# 66624      5            Хватит ли для pentium g 4400 I Rx 460 ?   ru
# 66636      5  Хватит ли мощности этого блока на мою систему ...   ru
# 66677      5         Тут провода полностью в тканевой оплетке ?   ru
# 66678      5                          Здесь провода в оплетке ?   ru
# 66686      5       Ожидается ли поставка данного блока питания?   ru
# 66705      5  Я знаю что БП очень качественный японские канд...   ru
# 66719      5  Покупал данный БП, проц xeon e5440, 4 ram, ssd...   ru
# 66721      5  Вопрос к представителям Aerocool: Хватит ли да...   ru
#
#        is_question
# 1             True
# 7             True
# 8             True
# 32            True
# 66            True
# 565           True
# 614           True
# 660           True
# 666           True
# 698           True
# 772           True
# 1069          True
# 1297          True
# 1309          True
# 1402          True
# 1450          True
# 1473          True
# 1550          True
# 1740          True
# 1936          True
# 1968          True
# 2113          True
# 2194          True
# 2229          True
# 2345          True
# 2383          True
# 2855          True
# 2919          True
# 2934          True
# 2967          True
# ...            ...
# 66291         True
# 66292         True
# 66337         True
# 66339         True
# 66350         True
# 66357         True
# 66370         True
# 66395         True
# 66417         True
# 66430         True
# 66512         True
# 66553         True
# 66555         True
# 66579         True
# 66587         True
# 66595         True
# 66598         True
# 66609         True
# 66612         True
# 66613         True
# 66619         True
# 66622         True
# 66624         True
# 66636         True
# 66677         True
# 66678         True
# 66686         True
# 66705         True
# 66719         True
# 66721         True
#
# [1818 rows x 4 columns]

# %%
data[data['is_question'] == False].groupby(['stars'])['text'].count()
# Out:
# stars
# 1     2264
# 2     2269
# 3     4530
# 4    14235
# 5    39798
# Name: text, dtype: int64

# %% [markdown]
# Considering the fact that distribution is still good, I'll filter out questions for now, although there might be some interesting questions in 1th class
# like
# ```
# Працювали поки був заряджний акумулятор.НЕ ВМИКАЮТЬСЯ.Як оформити поврнення?
# ```

# %%
data[data['text'].str.contains(':\(')]['text'].head(10).values
# Out:
# array(['Появилася тріщина на одній із шкал через 4 роки використання ТЕЧЕ:( Достоинства: Швидко нагріває. Недостатки: Шумить, неякійсний пластик на шкалах',
#        'очень мощный комбайн, соковыжималка супер, взбивание коктейлей супер, но нарезка овощей тут конечно подкачало....режет не равномерно, нашинковать огурец невозможно, комбайн его захватывает и по кругу тащит, т.к. от насадки до крышки много места, на штуке, которой толкаешь овощи в комбайн нет зубчиков чтоб зафиксировать овощ, в этом плане не продумано совсем, очень расстроил этот момент, т.к. в основном из-за этого его и брала, очень люблю овощные салаты...за помидоры вообще молчу, делает из них просто пюре и опять же большие куски остаются между насадкой и крышкой.... ну это ладно, помидоры то понятно, а вот за огурцы и все что имеет продолговатой формы (крабовые палочки допустим тоже не получается нарезать красиво) обидно...:(( и даже специальное отделение в штуке, которая проталкивает овощи в комбайн не помогает...(очень расстроена..... Достоинства: мощная, безопасная, не включается если его полностью не собрать, а в собранном виде очень безопасна, удобная, незаменимый помощник на кухне Недостатки: нашинковать огурцы и как-то вообще порезать помидоры не реально.',
#        'Жена безумно рада и счастлива. Достоинства: Очень простой в использовании. Хороший дизайн и приятный внешний вид. Мощный, за неск. секунд перебивает до состояния кашицы не только овощи и фрукты, но и мясо. Легко моется. Компактный, вместительный не занимает много места. Стал незаменимым помощником на кухне, заменив собой миксер, тёрку, мясорубку и некоторые виды нарезки и шинковки. Очень рекомендую. Недостатки: Пластик, из которого сделана чаша низкого качества. После двух раз помола апельсина - помутнела, полностью потеряла товарный вид и больше не отмывается:(((',
#        'Этот супер помощник у нас 3 месяца. Он должен быть у каждого на кухне: у супер хозяйки и просто любителя иногда что-то приготовить. Достоинства: Он может все!!! Отлично замешивает тесто Прекрасно измельчает и замешивает Можно готовить несколько блюд одновременно в блендере и миске (замешивать крем и измельчать ягоды; делать фарш и взбивать тесто для блинов; ну и тд) Недостатки: Он правда шумноват :) ребёнок или муж от звука проснуться :( По столу он не скачет, как некоторые пишут, это происходит только если он стоит на не ровной поверхности, так же будет эффективно немного намочить присоски Центробежная соковыжималка способна только на создание стакана сока и не очень удобно ее мыть - но как по мне, для любителей фрешей нужно покупать хорошую соковыжималку',
идала большего,еще и за такие деньги Потом попробую что она скажет мне на виноград Достоинства: 1)Дизайн 2)Достаточно тихая 3)Легко мыть/разбирать/собирать да и работать с ней быстро,легко и приятно Недостатки: 1. Мягкие плоды плохо отжимает. (Нет, скорость я ставила первую, как и пишет в инструкции) Жмых от помидор катастрофически мокрый был,лучше бы советской "шнековой" крутила,литр сока где-то потеряла. 2. Нельзя отжимать плоды,которые содержат волокна (бананы, инжир, финики, манго, папайя и др. )',
#        'Долго выбирала универсальный комбайн,и для взбивания белков и для мяса,и для коктейле,и конечно,с большим разнообразием терок. В итоге остановилась на этой модели,ПОВЕРИВ рекламным роликам и хорошим отзывам. В итоге купила. Терла морковь,лук,капусту,яблоки,грибы.Претензий нет.Быстро,большая чаша.Острые терки. При попытке сделать шарлотку,пришлось понять что взяла не то....НЕ ВЗБИВАЕТ.Вообще!Просто перемешало яйца и все,такое этой насадкой -юбочкой пойдет только для майонеза,а о пышной пене для бисквита забудьте! Достоинства: Компактный. Большая чаша,и блендер на литр молока. Недостатки: Не взбивает яйца и белки,АБСОЛЮТНО!Не верьте видеороликам,в которых так красиво это показывают!Надо отдельно покупать миксер или блендер с венчиком:( Съемный нож,один для блендера и мельнички.Там между ним и кувшином идет уплотнительное кольцо,но боюсь при постоянном снимании на долго герметичности не хватит. Съемные диски,надо аккуратно менять,чтоб не сточить при частой замене пластмассовую защелку,за которую они крепятся.'],
#       dtype=object)

# %%
data[data['text'].str.contains("=\)")]['text'].head(10).values
# Out:
# array(['пользуемся полтора года пока работает отлично =)',
#        'Купил этот миксер и теперь благодаря ему и мама и сестра довольно часто им пользуются(не ложкой мешать).Всё хорошо взбивает и готовка в радость.Сам миксер достаточно мощный,а кнопка турбо режима=пятой скорости.=)В общем всем советую.#мояраспаковка Достоинства: Мощный,классные венчики. Недостатки: Тяжело нажимается кнопка Eject.',
#        'Не поганий міксер.Купив 1 тиждень назад і не жалію. Тихо працює а креми до тортиків такі пухкі получаються, що аж пальчики оближеш. Блендером пюре класно робиться . Досить зручний в використанні . РАджу купляти прилади від БОШ=)',
#        'Заказал для подарка... Жена довольна - я доволен =). Спасибо! Достоинства: Соотношение цена/качество. Мощность. Недостатки: Нож мини-измельчителя не всегда поднимает продукт.',
#        'Духовкою ми дуже задоволені! Для своєї ціни виконана дуже якісно і виглядає дуже стильно.  Виник ще нюанс при монтажі у мебель, духовка має знизу підвищення вилиті в нижній плиті(ніжки) і в нішу зроблену по стандарту не ввійде(чи ввійде зі скрипом). Достоинства: Довго вибирали і зупинились на цій моделі духовки. Багато функцій, високі температури, телескопічна полиця, плюсів купа. Температуру тримає круто! Перше наше приготування це була піца на 210 градусів по рекомендації інструкції, дверцята духовки та верхня панель повністю холодні в процесі. Виставили таймер в 15хв, час відтікав і духовка виключилась з звуковим сигналом, дуже зручно!  Великий плюс наявність блокування сенсору!Наше чадо маленьке тіль