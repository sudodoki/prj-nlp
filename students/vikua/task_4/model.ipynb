# %%
# %load_ext autoreload
# %autoreload 2

import os
import pandas as pd
import numpy as np

import spacy
from spacy import displacy
from sklearn.model_selection import train_test_split

from rules import *
from rule_model import RuleModel, build_dataframe, score_row
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = './out'
files = os.listdir(data)

nlp = spacy.load('en')

# %%
train_files, test_files = train_test_split(files, train_size=0.5, random_state=1234)

# %%
train = build_dataframe(data, train_files).fillna('no')
test = build_dataframe(data, test_files).fillna('no')

train['cast'] = train['cast'].apply(lambda x: x.split(','))
test['cast'] = test['cast'].apply(lambda x: x.split(','))

# %%
train.head(10)
# Out:
#                                                 cast  \
# 0  [Matt Damon, Jeff Daniels, Jessica Chastain, K...
# 0  [Lily James, Kevin Spacey, Ansel Elgort, Eiza ...
# 0  [Ted Levine, Ruby Dee, Denzel Washington, Josh...
# 0  [Eric Bana, Ewan McGregor, Tom Sizemore, Sam S...
# 0  [Alan Tudyk, Bruce Greenwood, Chi McBride, Jam...
# 0                 [Audrey Tautou, Mathieu Kassovitz]
# 0  [Alan Rickman, Colin Firth, Hugh Grant, Rowan ...
# 0  [Robert Carlyle, Ewan McGregor, Kevin McKidd, ...
# 0  [Jean Reno, Natalie Portman, Danny Aiello, Gar...
# 0  [Martina Gedeck, Ulrich Tukur, Sebastian Koch,...
#
#                                            paragraph  \
# 0  The Martian is a 2015 science fiction film dir...
# 0  Baby Driver is a 2017 action crime film writte...
# 0  American Gangster is a 2007 American biographi...
# 0  Black Hawk Down is a 2001 war film produced an...
# 0  I, Robot (stylized as i,robot) is a 2004 Ameri...
# 0  Amélie (also known as Le Fabuleux Destin d'Amé...
# 0  Love Actually is a 2003 Christmas-themed roman...
# 0  Trainspotting is a 1996 British black comedy f...
# 0  Léon: The Professional (French: Léon; original...
# 0  The Lives of Others (German: Das Leben der And...
#
#                           movie
# 0        The_Martian_(film).txt
# 0        Baby_Driver_(film).txt
# 0  American_Gangster_(film).txt
# 0    Black_Hawk_Down_(film).txt
# 0           I,_Robot_(film).txt
# 0                    Amélie.txt
# 0             Love_Actually.txt
# 0      Trainspotting_(film).txt
# 0    Léon:_The_Professional.txt
# 0       The_Lives_of_Others.txt

# %%
rules = [ActorPerformanceMentionRule(), ActorCastRule(), FilmStartsRule()]
model = RuleModel(rules)

# %%
# pre-analyse data (fit to spacy), because it takes a lot of time 

train['X'] = model.analyse(train['paragraph'])
test['X'] = model.analyse(test['paragraph'])

# %%
train['pred'] = model.predict(train['X'], analyse=False)
scores = train[['cast', 'pred']].apply(lambda x: score_row(x['cast'], x['pred']), axis=1)

print('Train F1 score:', scores.mean())

test['pred'] = model.predict(test['X'], analyse=False)
scores = test[['cast', 'pred']].apply(lambda x: score_row(x['cast'], x['pred']), axis=1)
print('Test F1 score', scores.mean())
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Train F1 score: 0.40944665104764544
# Test F1 score 0.3774518937262914

# %%
train[['cast', 'pred', 'movie']].head(10)
# Out:
#                                                 cast  \
# 0  [Matt Damon, Jeff Daniels, Jessica Chastain, K...
# 0  [Lily James, Kevin Spacey, Ansel Elgort, Eiza ...
# 0  [Ted Levine, Ruby Dee, Denzel Washington, Josh...
# 0  [Eric Bana, OBE, Ewan McGregor, Tom Sizemore, ...
# 0  [Alan Tudyk, Bruce Greenwood, Chi McBride, Jam...
# 0                 [Audrey Tautou, Mathieu Kassovitz]
# 0  [Alan Rickman, Colin Firth, Hugh Grant, Rowan ...
# 0  [Robert Carlyle, OBE, Ewan McGregor, Kevin McK...
# 0  [Jean Reno, Natalie Portman, Danny Aiello, Gar...
# 0  [Martina Gedeck, Ulrich Tukur, Sebastian Koch,...
#
#                                                 pred  \
# 0  {Jessica Chastain, Matt Damon, Sebastian Stan,...
# 0  {Kevin Spacey, Ansel Elgort, Jon Bernthal, Jam...
# 0          {Russell Crowe, Denzel Washington, Crowe}
# 0                                                 {}
# 0                                                 {}
# 0                                                 {}
# 0                                                 {}
# 0  {Jonny Lee Miller, Robert Carlyle, Ewen Bremne...
# 0                   {Jean Reno, Oldman, Gary Oldman}
# 0                             {Dreyman, Ulrich Mühe}
#
#                           movie
# 0        The_Martian_(film).txt
# 0        Baby_Driver_(film).txt
# 0  American_Gangster_(film).txt
# 0    Black_Hawk_Down_(film).txt
# 0           I,_Robot_(film).txt
# 0                    Amélie.txt
# 0             Love_Actually.txt
# 0      Trainspotting_(film).txt
# 0    Léon:_The_Professional.txt
# 0       The_Lives_of_Others.txt

# %% [markdown]
# Looks like some of the movies doesn't have any actor detected. For example `Black Hawk Down` has following line in text
#
# _The film features a large ensemble cast, including Josh Hartnett, Ewan McGregor, Eric Bana, Tom Sizemore, William Fichtner, Jason Isaacs, Tom Hardy in his feature film debut, and Sam Shepard._
#
# which is not covered by rules.
#
# Also `I, Robot` has the line which is covered by rules, but in some reasons was not detected
#
# _The film stars Will Smith, Bridget Moynahan, Bruce Greenwood, James Cromwell, Chi McBride and Alan Tudyk._

# %%
nlp = spacy.load('en')
doc = nlp("The film stars Will Smith, Bridget Moynahan, Bruce Greenwood, James Cromwell, Chi McBride and Alan Tudyk.")
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="2850" height="399.5" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">film</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">stars</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Smith,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Bridget</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Moynahan,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Bruce</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Greenwood,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">James</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Cromwell,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Chi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">McBride</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Alan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Tudyk.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,266.5 L753.0,254.5 737.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M770,264.5 C770,89.5 1095.0,89.5 1095.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,266.5 L1103.0,254.5 1087.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing:

# %% [markdown]
# Looks like _stars_ is not a verb, so let's add rule for nouns.
#
# I also made similar analysis and added other rules, like:
# - extracting actors from phrases like "played by somebody"
# - removing detected actors with names longer then 3 words (The BAFTA Award for Best Screenplay was detected and others)
#
# Changed approach from checking each sentence separatelly to applying rules to entire doc at once

# %%
rules = [ActorPerformanceMentionRule(), ActorCastRule(), FilmStartsRule(), 
         FilmStarsRuleAsNoun(), IncludingRule(), PlayedByRule()]
model = RuleModel(rules)

train['pred'] = model.predict(train['X'], analyse=False)
scores = train[['cast', 'pred']].apply(lambda x: score_row(x['cast'], x['pred']), axis=1)

print('Train F1 score:', scores.mean())
# Out:
# Train F1 score: 0.4631426613993872
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# F1 score improved a bit, but still low
#
# ### Let's see articles with lowest F1 score:

# %%
results = pd.concat([train[['cast', 'pred', 'movie']], scores], axis=1).reset_index(drop=True).sort_values([0], ascending=True)
results.head(20)
# Out:
#                                                  cast  \
# 12  [Tom Cruise, Timothy Spall, Koyuki, Billy Conn...
# 89  [Dave Franco, Woody Harrelson, Morgan Freeman,...
# 78  [Leonardo DiCaprio, Ray Winstone, Matt Damon, ...
# 74  [Rory Culkin, William Mapother, Robin Tunney, ...
# 64  [Malin Åkerman, Matthew Goode, Jeffrey Dean Mo...
# 88  [Nicolas Cage, Christopher Mintz-Plasse, Aaron...
# 56  [Brian d'Arcy James, Liev Schreiber, Rachel Mc...
# 45  [Rip Torn, Linda Fiorentino, Vincent D'Onofrio...
# 63                                    [Daisy Ridley"]
# 6   [Alan Rickman, Colin Firth, Hugh Grant, Rowan ...
# 33  [Douglas Silva, Jonathan Haagensen, Matheus Na...
# 75  [Samuel L. Jackson, Chris Hemsworth, Cobie Smu...
# 50  [Samuel L. Jackson, Chris Hemsworth, Cobie Smu...
# 61  [Tom Hanks, Bae Doona, Jim Sturgess, Hugh Gran...
# 51  [Eva Green, Giancarlo Giannini, Jeffrey Wright...
# 67  [Alec Baldwin, Rebecca Ferguson, Simon Pegg, V...
# 2   [Ted Levine, Ruby Dee, Denzel Washington, Josh...
# 80  [Eddie Redmayne, Emily Watson, (OBE), David Th...
# 44  [Chris Pine, Robin Wright, Gal Gadot, Connie N...
# 32  [Tom Hanks, Matt Damon, Tom Sizemore, Edward B...
#
#                                                  pred  \
# 12  [Golden Satellite Awards, Academy Awards, Gold...
# 89                                      [Jack Wilder]
# 78            [Raging Bull, J. Hoberman, Taxi Driver]
# 74                                                 []
# 64  [Leonid Brezhnev, Richard Nixon, John Lennon, ...
# 88  [Universal Studios, Christopher Tookey, Andrew...
# 56                                      [Gary Galone]
# 45                                                 []
# 63  [John Boyega, Andy Serkis, Mark Hamill, Lupita...
# 6                                       [Julia Davis]
# 33                                  [the Red Brigade]
# 75  [Iron Man 2, VES Awards, Clint Barton, Teen Ch...
# 50  [Thomas Kretschmann, Claudia Kim, Fort Bard, L...
# 61  [Martin Wuttke, Brody Nicholas Lee, Sylvestra ...
# 51  [Daniel Craig, Alexander Korda Award, Jimmy Bo...
# 67  [Rebecca Ferguson, Tom Cruise Productions, Tom...
# 2   [Frank Lucas', Russell Crowe, Frank Lucas[13, ...
# 80  [Eddie Redmayne, Anthony McCarten, Eddie Redma...
# 44  [Geoff Johns, Joel Silver, Elena Anaya, Patty ...
# 32  [Best Film Editing, Steven Spielberg, Barry Pe...
#
#                                        movie         0
# 12                      The_Last_Samurai.txt  0.000000
# 89                 Now_You_See_Me_(film).txt  0.000000
# 78                          The_Departed.txt  0.000000
# 74                     The_Zodiac_(film).txt  0.000000
# 64                       Watchmen_(film).txt  0.000000
# 88                       Kick-Ass_(film).txt  0.000000
# 56                      Spotlight_(film).txt  0.000000
# 45                   Men_in_Black_(film).txt  0.000000
# 63          Star_Wars:_The_Force_Awakens.txt  0.000000
# 6                          Love_Actually.txt  0.000000
# 33               City_of_God_(2002_film).txt  0.000000
# 75              The_Avengers_(2012_film).txt  0.071429
# 50               Avengers:_Age_of_Ultron.txt  0.083333
# 61                    Cloud_Atlas_(film).txt  0.100000
# 51             Casino_Royale_(2006_film).txt  0.111111
# 67    Mission:_Impossible_–_Rogue_Nation.txt  0.166667
# 2               American_Gangster_(film).txt  0.173913
# 80  The_Theory_of_Everything_(2014_film).txt  0.181818
# 44              Wonder_Woman_(2017_film).txt  0.181818
# 32                   Saving_Private_Ryan.txt  0.181818

# %% [markdown]
# After further analysis I found that labeling method is wrong. It pulls cast from prepared database (json file created from DBPedia),
# but crawled html files may not have some actors mentioned.
# That's why I changed `label_data.py` script to add only actors, which are present in text.
# This improved F1 score for couple percent:

# %%
rules = [ActorPerformanceMentionRule(), ActorCastRule(), FilmStartsRule(),  FilmStartsWithRule(),
         FilmStarsRuleAsNoun(), IncludingRule(), PlayedByRule(), IncludesRuleDObjWithCompount(),
         AnsembleOfCastOfRule(), InBrackets()]
model = RuleModel(rules)

train['pred'] = model.predict(train['X'], analyse=False)
scores = train[['cast', 'pred']].apply(lambda x: score_row(x['cast'], x['pred']), axis=1)

print('Train F1 score:', scores.mean())
# Out:
# Train F1 score: 0.5501887400760639

# %%
results = pd.concat([train[['cast', 'pred', 'movie']], scores], axis=1).reset_index(drop=True).sort_values([0], ascending=True)
results.head(20)
# Out:
#                                                  cast  \
# 56  [Brian d'Arcy James, Liev Schreiber, Rachel Mc...
# 27  [Finn Wittrock, Rosemarie DeWitt, Ryan Gosling...
# 32  [Tom Hanks, Matt Damon, Tom Sizemore, Edward B...
# 61  [Tom Hanks, Hugh Grant, Hugo Weaving, Halle Be...
# 50  [Samuel L. Jackson, Chris Hemsworth, Cobie Smu...
# 67  [Alec Baldwin, Rebecca Ferguson, Simon Pegg, V...
# 44  [Chris Pine, Robin Wright, Gal Gadot, Connie N...
# 77                 [Jaeden Lieberher, Bill Skarsgård]
# 63  [Harrison Ford, Oscar Isaac, Adam Driver, John...
# 80  [Eddie Redmayne, Emily Watson, David Thewlis, ...
# 72  [Tony Revolori, Donald Glover, Tom Holland, Ze...
# 91  [Harrison Ford, Lennie James, Robin Wright, Ry...
# 58  [Ed Harris, Nicolas Cage, Sean Connery, Willia...
# 25  [Sacha Baron Cohen, Eddie Redmayne, Hugh Jackm...
# 37  [Glenn Close, Zoe Saldana, Bradley Cooper, Eli...
# 74  [Rory Culkin, Robin Tunney, Justin Chambers, P...
# 51                          [Eva Green, Daniel Craig]
# 2   [Ted Levine, Ruby Dee, Denzel Washington, Josh...
# 24  [Riley Keough, Charlize Theron, Courtney Eaton...
# 86                   [Ethan Hawke, Denzel Washington]
#
#                                                  pred  \
# 56                                      [Gary Galone]
# 27  [Best Production Design, Best Film Editing, Be...
# 32  [Ranger Battalion, Vin Diesel, Inglourious Bas...
# 61  [Cala Tuent, Jim Broadbent, Music Magazine, Su...
# 50  [Infinity Stones, Claudia Kim, MCU Phase, Marv...
# 67  [Rebecca Ferguson, Tom Cruise Productions, Tom...
# 44  [Geoff Johns, Steve Trevor, Joel Silver, Elena...
# 77  [The Invasion (2007, Tania McGowan, Bill Skars...
# 63  [Starkiller Base, Ridley, Fisher, The Detroit ...
# 80  [Eddie Redmayne, Eddie Redmayne[2][1, Anthony ...
# 72  [Michael Barbieri, Robert Downey Jr., Logan Ma...
# 91  [Blade Runner 2049, Blade Runner, Carla Juri, ...
# 58  [Jonathan Hensleigh, Todd McCarthy, Ian La, To...
# 25  [Jennifer Hudson, Bath, Somerset, Cameron Mack...
# 37  [Michelle Yeoh, Michael Rosenbaum, Pom Klement...
# 74  [Vallejo (Benicia, Rory Culkin, Justin Chamber...
# 51  [Daniel Craig, Phil Meheux, Alexander Korda Aw...
# 2   [Frank Lucas', Russell Crowe, Frank Lucas[13, ...
# 24  [Production Design, Best Production Design, Ch...
# 86  [Eva Mendes, Bill Paxton, Justin Cornwell, Den...
#
#                                        movie         0
# 56                      Spotlight_(film).txt  0.000000
# 27                     La_La_Land_(film).txt  0.133333
# 32                   Saving_Private_Ryan.txt  0.136364
# 61                    Cloud_Atlas_(film).txt  0.155844
# 50               Avengers:_Age_of_Ultron.txt  0.160000
# 67    Mission:_Impossible_–_Rogue_Nation.txt  0.166667
# 44              Wonder_Woman_(2017_film).txt  0.166667
# 77                        It_(2017_film).txt  0.173913
# 63          Star_Wars:_The_Force_Awakens.txt  0.180556
# 80  The_Theory_of_Everything_(2014_film).txt  0.200000
# 72                Spider-Man:_Homecoming.txt  0.200000
# 91                     Blade_Runner_2049.txt  0.200000
# 58                       The_Rock_(film).txt  0.205128
# 25            Les_Misérables_(2012_film).txt  0.222222
# 37        Guardians_of_the_Galaxy_Vol._2.txt  0.230769
# 74                     The_Zodiac_(film).txt  0.250000
# 51             Casino_Royale_(2006_film).txt  0.250000
# 2               American_Gangster_(film).txt  0.260870
# 24                    Mad_Max:_Fury_Road.txt  0.260870
# 86                          Training_Day.txt  0.285714

# %%
test['pred'] = model.predict(test['X'], analyse=False)
scores = test[['cast', 'pred']].apply(lambda x: score_row(x['cast'], x['pred']), axis=1)

print('Test F1 score:', scores.mean())
# Out:
# Test F1 score: 0.48334154968984683
