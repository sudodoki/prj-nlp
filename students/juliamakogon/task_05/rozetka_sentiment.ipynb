# %% [markdown]
# # Sentiment classification for category https://bt.rozetka.com.ua/ua/tehnika-dlya-kuhni/c435974/

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r'C:\work\jul\prj-nlp\students\juliamakogon\task_05\rozetka\rozetka_kitchen.csv')
df.shape
# Out:
# (13067, 6)

# %%
df
# Out:
#       lang                                               item  rating  \
# 0       ru           \r\nЯйцеварка PROFI COOK PC-EK 1084 \r\n     1.0
# 1       ru     \r\nЕлектрична піч PANASONIC NU-SC101WZPE \r\n     4.0
# 2       ru     \r\nЕлектрична піч PANASONIC NU-SC101WZPE \r\n     5.0
# 3       ru     \r\nЕлектрична піч PANASONIC NU-SC101WZPE \r\n     NaN
# 4       uk            \r\nМікрохвильова піч ERGO EM-2075 \r\n     5.0
# 5       ru            \r\nМікрохвильова піч ERGO EM-2075 \r\n     4.0
# 6       ru            \r\nМікрохвильова піч ERGO EM-2075 \r\n     5.0
# 7       ru            \r\nМікрохвильова піч ERGO EM-2075 \r\n     NaN
# 8       uk            \r\nМікрохвильова піч ERGO EM-2075 \r\n     NaN
# 9       uk            \r\nМікрохвильова піч ERGO EM-2075 \r\n     5.0
# 10      ru            \r\nМікрохвильова піч ERGO EM-2075 \r\n     NaN
# 11      ru            \r\nМікрохвильова піч ERGO EM-2075 \r\n     NaN
# 12      ru            \r\nМікрохвильова піч ERGO EM-2075 \r\n     NaN
# 13      uk            \r\nМікрохвильова піч ERGO EM-2075 \r\n     NaN
# 14      ru                \r\nЯйцеварка CUISINART CEC10E \r\n     3.0
# 15      ru                \r\nЯйцеварка CUISINART CEC10E \r\n     5.0
# 16      ru                \r\nЯйцеварка CUISINART CEC10E \r\n     1.0
# 17      ru        \r\nТостер HOTPOINT ARISTON TT 22E UP0 \r\n     5.0
# 18      ru                \r\nЯйцеварка CUISINART CEC10E \r\n     NaN
# 19      uk        \r\nТостер HOTPOINT ARISTON TT 22E UP0 \r\n     5.0
# 20      ru        \r\nТостер HOTPOINT ARISTON TT 22E UP0 \r\n     NaN
# 21      ru                \r\nБлендер BRAUN MQ 9087 X BK \r\n     NaN
# 22      ru                \r\nБлендер BRAUN MQ 9087 X BK \r\n     NaN
# 23      ru                \r\nБлендер BRAUN MQ 9087 X BK \r\n     NaN
# 24      ru                \r\nБлендер BRAUN MQ 9087 X BK \r\n     NaN
# 25      ru                \r\nБлендер BRAUN MQ 9087 X BK \r\n     NaN
# 26      ru                \r\nБлендер BRAUN MQ 9087 X BK \r\n     NaN
# 27      ru                \r\nБлендер BRAUN MQ 9087 X BK \r\n     NaN
# 28      uk                \r\nБлендер BRAUN MQ 9087 X BK \r\n     5.0
# 29      ru                \r\nБлендер BRAUN MQ 9087 X BK \r\n     5.0
# ...    ...                                                ...     ...
# 13037   ru        \r\nКавомашина SAECO Incanto HD8916/09 \r\n     2.0
# 13038   ru  \r\nКавомашина DELONGHI ESAM 3500 S + 1 кг Кав...     5.0
# 13039   ru  \r\nКавомашина DELONGHI ESAM 3500 S + 1 кг Кав...     NaN
# 13040   ru  \r\nКавомашина DELONGHI ESAM 3500 S + 1 кг Кав...     NaN
# 13041   ru  \r\nКавомашина DELONGHI ESAM 3500 S + 1 кг Кав...     NaN
# 13042   ru        \r\nКавомашина SAECO Incanto HD8916/09 \r\n     3.0
# 13043   ru        \r\nКавомашина SAECO Incanto HD8916/09 \r\n     2.0
# 13044   uk  \r\nКавомашина SAECO Xelsis SM7685/00+Електрич...     5.0
# 13045   ru  \r\nКавомашина SAECO Xelsis SM7685/00+Електрич...     NaN
# 13046   ru  \r\nКавомашина DELONGHI ESAM 4500 S + 1 кг Кав...     4.0
# 13047   uk  \r\nКавомашина DELONGHI ESAM 4500 S + 1 кг Кав...     5.0
# 13048   uk  \r\nКавомашина DELONGHI ESAM 4500 S + 1 кг Кав...     2.0
# 13049   ru  \r\nКавомашина DELONGHI ESAM 4500 S + 1 кг Кав...     NaN
# 13050   ru  \r\nКавомашина DELONGHI ESAM 4500 S + 1 кг Кав...     NaN
# 13051   ru  \r\nКавомашина DELONGHI ESAM 4500 S + 1 кг Кав...     5.0
# 13052   uk  \r\nКавомашина DELONGHI ESAM 4500 S + 1 кг Кав...     NaN
# 13053   ru  \r\nКавомашина DELONGHI ESAM 4500 S + 1 кг Кав...     4.0
# 13054   ru  \r\nКавомашина DELONGHI ESAM 4500 S + 1 кг Кав...     5.0
# 13055   ru  \r\nКавомашина DELONGHI ESAM 4500 S + 1 кг Кав...     NaN
# 13056   ru  \r\nКавомашина DELONGHI ETAM 29.660 SB + 1 кг ...     NaN
# 13057   ru  \r\nКавомашина DELONGHI ETAM 29.660 SB + 1 кг ...     5.0
# 13058   ru  \r\nКавомашина DELONGHI ETAM 29.660 SB + 1 кг ...     4.0
# 13059   ru  \r\nКавомашина DELONGHI ETAM 29.660 SB + 1 кг ...     NaN
# 13060   ru  \r\nКавомашина DELONGHI ETAM 29.660 SB + 1 кг ...     5.0
# 13061   ru  \r\nКавомашина DELONGHI ETAM 29.660 SB + 1 кг ...     5.0
# 13062   ru  \r\nКавомашина DELONGHI ETAM 29.660 SB + 1 кг ...     5.0
# 13063   ru  \r\nКавомашина DELONGHI ETAM 29.660 SB + 1 кг ...     NaN
# 13064   ru  \r\nКавомашина DELONGHI ETAM 29.660 SB + 1 кг ...     5.0
# 13065   ru  \r\nКавомашина DELONGHI ETAM 29.660 SB + 1 кг ...     5.0
# 13066   ru  \r\nКавомашина DELONGHI PrimaDonna S Evo ECAM ...     NaN
#
#                                                     text  \
# 0      Можно положить на полку для бесполезных вещей ...
# 1      Очень хорошее впечатление. Пока делали только ...
# 2      Первый раз пишу отзыв от покупке) С появление ...
# 3      Помимо всех функций и режимов, как хорошо она ...
# 4      Чудова та проста мікрохвильовка з гарним дизай...
# 5      микроволновка хорошая я всем довольна. для сво...
# 6                                 Хорошая микроволновке.
# 7      Дорогой магазин, пишу тут т.к. другого способа...
# 8      #моєрозпакування В цілому дуже задоволені. Про...
# 9      Все добре,їжу гріє відмінно.Сервіс на висоті! ...
# 10     34,8 см глибина, це з ручкою вказано чи ручка ...
# 11     Вчера забрали в новом магазине на петровке.Маг...
# 12     Заказала в подарок маме. Быстро доставили и вы...
# 13                              Чи є лампочка всередині?
# 14     Все хорошо, но омлет она не готовит (точнее эт...
# 15           Отличная вещь!омлеты получаются бесподобны)
# 16     Покупал, чтоб эта штука быстренько и без моего...
# 17     Замечательное приобретение, несколько режимов ...
# 18     Быстрое приготовление. Очень вкусные свежие яй...
# 19     Виглядає дуже стильно. У використанні зрозуміл...
# 20     Доставка была быстрой, за что спасибо магазину...
# 21     Добрый день Есть ли насадка кубики? Если нет м...
# 22     Купила 3 месяца назад. Заказом безумно довольн...
# 23     Подскажите, с помощью какой насадки можно коло...
# 24     Даже не знаю,как прокоментировать свою покупку...
# 25                                    Как длина провода?
# 26     Добрый день всем! Кто пробовал делать фарш и т...
# 27                             А терка для дерунов есть?
# 28     Купили для приготування дитячих овочевих, фрук...
# 29     Полностью доволен покупкой. Начинал с фруктов ...
# ...                                                  ...
# 13037  Не рекомендую покупать любую с кофемашин компа...
# 13038  Классная вещь, рекомендую, как на подарок так ...
# 13039  Хотел узнать. Может ли данная машинка обрабаты...
# 13040  Готовит ли ESAM 3500 S латте макиато? В описан...
# 13041                                кто производитель ?
# 13042  Напишу своё мнение по данной кофемашине. . Цен...
# 13043  Покупал в ноябре 2017 г. Это моя вторая кофема...
# 13044                 мелену каву можна використовувати?
# 13045  Данная модель подойдет для кафе/бара? Какова с...
# 13046  Не смотря на то, что я так подробно расписала ...
# 13047                                 Кавоварка супер!!!
# 13048  Вистрілила плата... Сервіс жахливий... у Львов...
# 13049  Скажите пожалуйста, а в этой кофемашине есть а...
# 13050  Количество настроек помогает варить любой кофе...
# 13051  Классный аппарат. Капучино реально вкусный. Вк...
# 13052      Почему у нее 110-127 вольт. Куда ее включать?
# 13053  Пользуемся этим чудесным аппаратом почти год. ...
# 13054  Молочная пенка делается двукратным нажатием на...
# 13055  Можно уточнить, какой температуры должно быть ...
# 13056  Так сколько лет гарантии на эту кофемашину?? В...
# 13057  Сегодня уже пили вкусный кофе!!!! Капучино про...
# 13058  При работе машины нужно придерживать чашку или...
# 13059            Здравствуйте, подскажите срок гарантии?
# 13060                                отличная кофемашина
# 13061  Пользуюсь уже месяца два, проблем нет. Единств...
# 13062          Отличный аппарат, легкий в использовании.
# 13063  Вопрос в сервисный центр. Через несколько дней...
# 13064  Классная кофемашина такой фирмы, хорошо справл...
# 13065      Спустя месяц использования абсолютно доволен.
# 13066  Купил в офис эту кофе машину! Долго определяли...
#
#                                                     pros  \
# 0      аж 8 яиц можно сварить! Отличный вариант для к...
# 1          Функции понятны, все делается легко и приятно
# 2      Быстро греется и готовит, небольшие габариты, ...
# 3                                                    NaN
# 4                                 Зручність та простота.
# 5                                                    NaN
# 6                                     Цена, компактность
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11             красивая и дешевая.функции свои выполняет
# 12                                         Цена, дизайн.
# 13                                                   NaN
# 14      быстро готовит яйца пашот с легкостью, компактна
# 15                                                   NaN
# 16                                                 Пашот
# 17                                                   NaN
# 18     Замечательная вещь для тех, кто придерживается...
# 19     Выглядає дуже стильно у використанні легкий і ...
# 20     качество прожаривания хлеба стандартный функци...
# 21                                                   NaN
# 22         Порой просто незаменимый помощник на кухне!!!
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                        багато насадок
# 29                            мощный,качественная сборка
# ...                                                  ...
# 13037                                    Кофе нормальный
# 13038                             Все которые могут быть
# 13039                                                NaN
# 13040                                                NaN
# 13041                                                NaN
# 13042                                             Дизайн
# 13043  Кофе готовит вкусно, хорошо прогревает воду , ...
# 13044                                                NaN
# 13045                                                NaN
# 13046  Очень удобна в использовании. Пользоваться смо...
# 13047                                                NaN
# 13048                                                NaN
# 13049                                                NaN
# 13050                                     Много настроек
# 13051                Удобна в пользовании, вкусный кофе.
# 13052                                                NaN
# 13053  Многофункциональная, готовит вкусный кофе, про...
# 13054  Простая регулировка количества кофе, все прогр...
# 13055                                                NaN
# 13056                                                NaN
# 13057            Сама себя моет. Проста в использовании.
# 13058               Хорошая машина, работает как ожидали
# 13059                                                NaN
# 13060                                         компактная
# 13061                           Простота в использовании
# 13062                                                NaN
# 13063                                                NaN
# 13064  Разные виды кофе, регулировка размера чашки и ...
# 13065  Готовит хороший кофе, компактная, относительно...
# 13066                              Легкость в управлении
#
#                                                     cons
# 0      Очень тяжело отмывается, если яйца треснет вну...
# 1                            Маловат объем, высокая цена
# 2                                          не нашел пока
# 3                                                    NaN
# 4                                          Не вияввлено.
# 5                                                    NaN
# 6                       Чуть-чуть слабоватая на разогрев
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                           отсутствие разных программ.
# 12                                     Долго разогревает
# 13                                                   NaN
# 14     ну очень маленькая! Особенно для омлета. Какой...
# 15                                                   NaN
# 16                                         Всю остальное
# 17                                                   NaN
# 18                                      пока не заметила
# 19     Тости йдуть дуже швидко, не встигаєшь купляти ...
# 20                                                   NaN
# 21                                                   NaN
# 22     Т.к. отсутствуют кнопки различных скоростей, в...
# 23                                                   NaN
# 24     Перетирала творог в пластиковой миске, творог ...
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                 немає
# 29                                                   нет
# ...                                                  ...
# 13037  Течёт, сервис Филипса это полная торба! Не рек...
# 13038                                                нет
# 13039                                                NaN
# 13040                                                NaN
# 13041                                                NaN
# 13042                                         Функционал
# 13043  Спустя 3 нед. стала плохо взбивать молоко, хот...
# 13044                                                NaN
# 13045                                                NaN
# 13046  Используем в основном кофе в зернах, а когда п...
# 13047                       Боїться перепадів напруги...
# 13048                                                NaN
# 13049                                                NaN
# 13050                                      Пока не нашли
# 13051           Не отключается подогрев плиты для чашек.
# 13052      Почему у нее 110-127 вольт. Куда ее включать?
# 13053  капучинатор не всегда подает вспененное молоко...
# 13054                                                нет
# 13055                                                NaN
# 13056                                                NaN
# 13057                                                NaN
# 13058                       Вибрация площадки для чашки.
# 13059                                                NaN
# 13060                                           нет пока
# 13061                                           Пока нет
# 13062                             Маленький бак для воды
# 13063                                                NaN
# 13064              маленький резервуар для воды и молока
# 13065                 Глянцевый поддон легко поцарапать.
# 13066                                                NaN
#
# [13067 rows x 6 columns]

# %% [markdown]
# **Preparing data**

# %%
def mapping_rating(x):
    if x < 1e-15:
        return 'neutral'
    elif x > 3.5:
        return 'positive'
    else: return 'negative'
    
df['rating'] = df['rating'].fillna(0)
df = df.fillna('')
df['item'] = df['item'].str.strip() # well, i've added strip to spider already, but the file still needs preprocessing
df = df.join(df['rating'].fillna(0).map(mapping_rating).rename('category'))

# %%
df.groupby(['lang', 'category']).count() # data distribution for ru/uk languages is similar
# Out:
#                item  rating  text  pros  cons
# lang category
# en   neutral      2       2     2     2     2
#      positive    10      10    10    10    10
# ru   negative  1121    1121  1121  1121  1121
#      neutral   4871    4871  4871  4871  4871
#      positive  4849    4849  4849  4849  4849
# uk   negative   220     220   220   220   220
#      neutral    982     982   982   982   982
#      positive  1012    1012  1012  1012  1012

# %%
df_uk = df.loc[df['lang'] == 'uk']
df_uk.shape
# Out:
# (2214, 7)

# %% [markdown]
# **Splitting for train and test**

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from operator import itemgetter 

X = df_uk[['text', 'pros', 'cons']].apply(lambda x: ' '.join(x), axis=1)
X1 = df_uk['text']
y = df_uk['category'].values
X_train, X_test, X1_train, X1_test, y_train, y_test = train_test_split(X, X1, y, random_state=42, #test_size=0.3, 
                                                                       stratify = y, shuffle=True)
print(len(X_train), len(X_test))
# Out:
# 1660 554

# %% [markdown]
# ## Sentiment classification baseline - without any language features

# %%
from sklearn.metrics import classification_report

def show_predicted(X, y, y_predicted, labels, show_data = 15):
    data = pd.DataFrame(columns=['X', 'y', 'y_predicted'])
    data['X'] = pd.Series(X).values
    data['y'] = pd.Series(y).values
    data['y_predicted'] = pd.Series(y_predicted).values
    if show_data > 0:
        print('\nPredicted data sample')
        print(data.head(show_data))
    print(data.groupby(['y', 'y_predicted']).count())
    pstat = np.unique(y_predicted, return_counts=True)
    ystat = np.unique(y, return_counts=True)
    print('\nClassification report')
    print(pstat[0])
    print(pstat[1])
    print(ystat[1])
    print(classification_report(y, y_predicted, labels))
    
def classifyNB(X_train, X_test, y_train, y_test, show_vocabulary = 0, show_analyzer = False, show_data = 0, analyzer = 'word', tokenizer = None, 
               min_df = 7, max_df = 0.9, ngram_range = (1, 1), stop_words = None, alpha = 1.0, preprocessor = None):
    tfidf = TfidfVectorizer(analyzer = analyzer, tokenizer = tokenizer, min_df = min_df, max_df = max_df, 
                            ngram_range = ngram_range, stop_words = stop_words, binary = True, preprocessor = preprocessor)
    train = tfidf.fit_transform(X_train)
    test = tfidf.transform(X_test)
    print("Vocabulary size:", len(tfidf.vocabulary_))
    if tfidf.stop_words:
        print("Stop words count:", len(tfidf.stop_words))
    if show_vocabulary > 0: 
        print(tfidf.get_feature_names()[:show_vocabulary])
    if show_analyzer:
        teststr = "Багато м'ясних закусок не вийшло."
        print('Checking analyzer:', teststr, tfidf.build_analyzer()(teststr))
    clf = BernoulliNB(alpha = alpha)
    clf.fit(train.toarray(), y_train)
    y_predicted = clf.predict(test.toarray())
    show_predicted(X_test, y_test, y_predicted, clf.classes_, show_data)
    

classifyNB(X_train, X_test, y_train, y_test, show_analyzer = True, show_vocabulary = 100)
# Out:
# Vocabulary size: 930
# ['10', '100', '12', '15', '180', '20', '30', '40', 'philips', 'rozetka', 'ua', 'або', 'автоматично', 'адже', 'аж', 'акції', 'але', 'апарат', 'багато', 'батарейки', 'бачу', 'без', 'би', 'бистро', 'блендер', 'блендера', 'блендером', 'близько', 'бо', 'брак', 'брала', 'брали', 'брати', 'був', 'буде', 'буду', 'будь', 'була', 'були', 'було', 'бутерброди', 'бути', 'білки', 'більш', 'більше', 'біля', 'вага', 'ваги', 'вагу', 'важко', 'вам', 'варто', 'вартість', 'варіант', 'вас', 'вафлі', 'вважаю', 'вдома', 'велика', 'великий', 'велику', 'великі', 'верхня', 'весь', 'вже', 'взагалі', 'взбиває', 'взяти', 'ви', 'вибір', 'вигляд', 'виглядає', 'видно', 'вийшло', 'вийшов', 'виключається', 'виконує', 'використання', 'використанні', 'використовувати', 'використовую', 'вимикається', 'виправдовує', 'випробувала', 'випікає', 'виробник', 'виробника', 'висновок', 'висоті', 'вистачає', 'виходить', 'виходять', 'вище', 'виявив', 'виявила', 'виявили', 'виявлено', 'вказано', 'вкл', 'включення']
# Checking analyzer: Багато м'ясних закусок не вийшло. ['багато', 'ясних', 'закусок', 'не', 'вийшло']
#                         X
# y        y_predicted
# negative negative      16
#          neutral       27
#          positive      12
# neutral  negative      21
#          neutral      159
#          positive      66
# positive negative      14
#          neutral       82
#          positive     157
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 51 268 235]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.31      0.29      0.30        55
#     neutral       0.59      0.65      0.62       246
#    positive       0.67      0.62      0.64       253
#
# avg / total       0.60      0.60      0.60       554

# %% [markdown]
# **Adding 'pros' as positive dataset and 'cons' as negative to classify just the 'text' field - didn't work**

# %%
y_pos = df_uk['rating'].map(lambda x: 'positive')
y_neg = df_uk['rating'].map(lambda x: 'negative')
X1_train_union = np.concatenate((X1_train, df_uk['pros'], df_uk['cons']))
y_union = np.concatenate((y_train, y_pos, y_neg))

classifyNB(X1_train_union, X1_test, y_union, y_test, show_vocabulary = 0, show_data = 0)
# Out:
# Vocabulary size: 1043
#                         X
# y        y_predicted
# negative negative      19
#          neutral       31
#          positive       5
# neutral  negative      53
#          neutral      112
#          positive      81
# positive negative      21
#          neutral      100
#          positive     132
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 93 243 218]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.20      0.35      0.26        55
#     neutral       0.46      0.46      0.46       246
#    positive       0.61      0.52      0.56       253
#
# avg / total       0.50      0.47      0.48       554

# %% [markdown]
# # Adding language specific tokenization and negation

# %%
import string
from tokenize_uk import tokenize_uk
s = "Купили для приготування 20-ти дитячих овочевих, фруктових і м'ясних сумішей. Все блендерить швидко і без комочків. Особливо смачно виходить сирок з фруктами. Дитина їсть все із задоволенням. Що ще треба для щастя? Покористувавшись декілька днів, можу сказати, що духовка посередня по якості. Не раджу для прибвання. Легко обпектись."

def tokenize(text):
    pars = tokenize_uk.tokenize_text(text)
    tokens = []
    for par in pars:
        for sent in par:
            tokens = tokens + sent
    return tokens

def negate(words):
    neg = False
    tokens = []
    for i in range(len(words)):
        w = words[i].lower()
        if w in ['не', 'немає', 'ні']:
            neg = True
            w = ''
        elif w[0] in string.punctuation:
            neg = False
            if w not in '!?':
                w = ''
        elif w[0] in string.digits:
            w = ''
        elif neg:
            w = 'не '+ w
        if w:
            tokens.append(w)
    return tokens

def remove_questions(text):
    if text.strip().endswith('?'):
        return ''
    else: return text

def tokenize_negate(text):
    return negate(tokenize(text))


print(tokenize_negate(s))
# Out:
# ['купили', 'для', 'приготування', 'дитячих', 'овочевих', 'фруктових', 'і', "м'ясних", 'сумішей', 'все', 'блендерить', 'швидко', 'і', 'без', 'комочків', 'особливо', 'смачно', 'виходить', 'сирок', 'з', 'фруктами', 'дитина', 'їсть', 'все', 'із', 'задоволенням', 'що', 'ще', 'треба', 'для', 'щастя', '?', 'покористувавшись', 'декілька', 'днів', 'можу', 'сказати', 'що', 'духовка', 'посередня', 'по', 'якості', 'не раджу', 'не для', 'не прибвання', 'легко', 'обпектись']

# %%
classifyNB(X_train, X_test, y_train, y_test, show_vocabulary = 0, tokenizer=tokenize_negate, show_data = 0)
# Out:
# Vocabulary size: 913
#                         X
# y        y_predicted
# negative negative      20
#          neutral       27
#          positive       8
# neutral  negative      22
#          neutral      153
#          positive      71
# positive negative      15
#          neutral       83
#          positive     155
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 57 263 234]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.35      0.36      0.36        55
#     neutral       0.58      0.62      0.60       246
#    positive       0.66      0.61      0.64       253
#
# avg / total       0.60      0.59      0.59       554

# %% [markdown]
# ## Adding lemmatization

# %%
import pymorphy2

class Morphology():
    _morph = None
    def __init__(self, lang='uk'):
        Morphology.load(lang=lang)

    @staticmethod
    def load(path = None, lang='uk'):
        if (Morphology._morph == None):
            Morphology._morph = pymorphy2.MorphAnalyzer(lang=lang)

    def getAnalyzer(self):
        return Morphology._morph
    
       
    
def lemmatize(words):
    morph = Morphology()
    for i in range(len(words)):
        ww = morph.getAnalyzer().parse(words[i])
        if ww:
            words[i] = ww[0].normal_form
    return words

def tokenize_lemmatize_negate(text):
    return negate(lemmatize(tokenize(text)))


print(tokenize_lemmatize_negate(s))
# Out:
# ['купити', 'для', 'приготування', 'дитячий', 'овочевий', 'фруктовий', 'і', "м'ясний", 'суміш', 'весь', 'блендерити', 'швидко', 'і', 'без', 'комочок', 'особливо', 'смачно', 'виходити', 'сирок', 'з', 'фрукт', 'дитина', 'їсти', 'весь', 'із', 'задоволення', 'що', 'ще', 'треба', 'для', 'щастя', '?', 'покористувавшись', 'декілька', 'дніти', 'могти', 'сказати', 'що', 'духовка', 'посередній', 'по', 'якість', 'не радити', 'не для', 'не прибвання', 'легко', 'обпектися']

# %%
classifyNB(X_train, X_test, y_train, y_test, tokenizer=tokenize_lemmatize_negate)
# Out:
# Vocabulary size: 903
#                         X
# y        y_predicted
# negative negative      21
#          neutral       28
#          positive       6
# neutral  negative      22
#          neutral      162
#          positive      62
# positive negative      14
#          neutral       87
#          positive     152
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 57 277 220]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.37      0.38      0.37        55
#     neutral       0.58      0.66      0.62       246
#    positive       0.69      0.60      0.64       253
#
# avg / total       0.61      0.60      0.61       554

# %% [markdown]
# **Using 1-2-grams and stop-words**

# %%
classifyNB(X_train, X_test, y_train, y_test, show_vocabulary = 0, tokenizer=tokenize_lemmatize_negate, ngram_range = (1,2), show_data = 30)
# Out:
# Vocabulary size: 1222
#
# Predicted data sample
#                                                     X         y y_predicted
# 0   Не було сказано, що є дефект. Ціна нормальна Р...   neutral     neutral
# 1   Купував на подарунок, але купив би і собі. Над...  positive     neutral
# 2   Купив недавно, інструкція зрозуміла, швидко ро...  positive    positive
# 3   я хочу ксвомашину щоб робити капучіно, лате як...   neutral     neutral
# 4    Хороша та якісна мікрохвильовка за такі гроші.    positive    positive
# 5   Я не раджу купувати цю вафельницю. Саме перше ...  negative    negative
# 6   Обирала блендер з декількох моделей, купувала ...  positive    positive
# 7   сподобався, приємний, міцний. Не смердить плас...  positive     neutral
# 8   Скажіть чи є змінні пластини для цієї моделі? ...   neutral     neutral
# 9   Чому після розігріву їжі мікрохвильовка продов...   neutral     neutral
# 10  Доброго дня. Хочу спитати чи підходить цей мік...   neutral     neutral
# 11  Купували в подарунок мамі. Їй все подобається....  positive    positive
# 12  Толковий тостер. Металевий корпус (сіре на фот...   neutral     neutral
# 13  дякуємо від усієї сім'ї Швидко доставили, гарн...   neutral    positive
# 14  Довго вибирала між блендером Kenwood з двома ш...  positive    positive
# 15    тількі для дтячого сирочку ціна мала потужність  positive     neutral
# 16  Кофеварка сподобалась. Все пряцює, готує каву ...  positive    positive
# 17  Класна плитка! Все працює, дуже зручна! Якісна...  positive    positive
# 18  Користуємся десь дві неділі. Зламалась нижня ч...  negative     neutral
# 19  Має і низькі швидкості і високі, зручний, легк...  positive     neutral
# 20  Дуже задоволена покупкою, 5 хвилин-і смачна фр...  positive    positive
# 21  Чудова піч. Користуюсь рік майже щоденно. Проб...  positive    positive
# 22  ха свою цену норма) цена воняет пластиком, про...  negative     neutral
# 23           гарний ,якісний товар дизайн,швидкість,   positive     neutral
# 24  Замовив електрочайник 15 листопада 2017 року. ...   neutral    negative
# 25  Дуже хороша кавоварка , п'ю смачну каву з цієї...   neutral    positive
# 26  Робив сік з яблук, вийшла пюрешка. Не те що хо...  positive     neutral
# 27  За півроку експлуатації кавоваркою повністю за...  positive    positive
# 28  За свою ціну хороша річ, єдине, могли б заміст...  positive    positive
# 29  користуюсь 6 міс. рідкий об'єм більше 1 л вже ...  negative    positive
#                         X
# y        y_predicted
# negative negative      20
#          neutral       26
#          positive       9
# neutral  negative      23
#          neutral      157
#          positive      66
# positive negative      13
#          neutral       85
#          positive     155
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 56 268 230]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.36      0.36      0.36        55
#     neutral       0.59      0.64      0.61       246
#    positive       0.67      0.61      0.64       253
#
# avg / total       0.60      0.60      0.60       554

# %%
stop_words = []
with open(r'C:\work\jul\prj-nlp\students\juliamakogon\task_05\stop_words.txt', encoding='utf-8') as f:
    stop_words = f.read().split()
classifyNB(X_train, X_test, y_train, y_test, show_vocabulary = 0, tokenizer=tokenize_lemmatize_negate, 
           ngram_range = (1,2), stop_words = stop_words)
# Out:
# Vocabulary size: 893
# Stop words count: 389
#                         X
# y        y_predicted
# negative negative      23
#          neutral       27
#          positive       5
# neutral  negative      19
#          neutral      159
#          positive      68
# positive negative       8
#          neutral       76
#          positive     169
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 50 262 242]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.46      0.42      0.44        55
#     neutral       0.61      0.65      0.63       246
#    positive       0.70      0.67      0.68       253
#
# avg / total       0.63      0.63      0.63       554

# %%
classifyNB(X_train, X_test, y_train, y_test, tokenizer=tokenize_lemmatize_negate, stop_words = stop_words)
# Out:
# Vocabulary size: 773
# Stop words count: 389
#                         X
# y        y_predicted
# negative negative      23
#          neutral       26
#          positive       6
# neutral  negative      19
#          neutral      158
#          positive      69
# positive negative       9
#          neutral       81
#          positive     163
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 51 265 238]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.45      0.42      0.43        55
#     neutral       0.60      0.64      0.62       246
#    positive       0.68      0.64      0.66       253
#
# avg / total       0.62      0.62      0.62       554

# %%
#remove smoothing and min_df=7
classifyNB(X_train, X_test, y_train, y_test, tokenizer=tokenize_lemmatize_negate, stop_words = stop_words, alpha = 0.05, min_df = 7)
# Out:
# Vocabulary size: 773
# Stop words count: 389
#                         X
# y        y_predicted
# negative negative      22
#          neutral       22
#          positive      11
# neutral  negative      12
#          neutral      157
#          positive      77
# positive negative       5
#          neutral       78
#          positive     170
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 39 257 258]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.56      0.40      0.47        55
#     neutral       0.61      0.64      0.62       246
#    positive       0.66      0.67      0.67       253
#
# avg / total       0.63      0.63      0.63       554

# %%
# preprocessing: removing questions
classifyNB(X_train, X_test, y_train, y_test, tokenizer=tokenize_lemmatize_negate, stop_words = stop_words, 
           preprocessor=remove_questions, alpha = 0.05, min_df=7)
# Out:
# Vocabulary size: 731
# Stop words count: 389
#                         X
# y        y_predicted
# negative negative      20
#          neutral       25
#          positive      10
# neutral  negative      11
#          neutral      165
#          positive      70
# positive negative       5
#          neutral       79
#          positive     169
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 36 269 249]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.56      0.36      0.44        55
#     neutral       0.61      0.67      0.64       246
#    positive       0.68      0.67      0.67       253
#
# avg / total       0.64      0.64      0.64       554

# %% [markdown]
# **Conclusion:** The best result we have for now with:
# - lemmatization and negation
# - without numbers
# - excluding all punctuation but '!?'
# - with stop words
# - to make a conclusion about using a combination of uni- and bigrams we need to collect more data; for now, the best approach is to use unigrams only
# - for such a small dataset smoothing makes worse
#
# BernoulliNB was chosen because MultinomialNB failed to predict negative sentiment. The best result was obtained with preprocessing and dimensionality reduction to about 750 words.

# %% [markdown]
# ## MultinomialNB 'by hand'

# %%
# Binary MultinomialNB classifier 
from sklearn.feature_extraction.text import CountVectorizer

def train_clf(train, y_train, alpha, inv_labels):
    n = len(inv_labels)
    counts = np.ndarray((n, train.shape[1]))
    for i in range(n):
        counts[i] = np.log(np.sum(train[y_train==inv_labels[i]], axis = 0) + alpha)
    voc_size = np.sum(counts)
    for i in range(n):
        cc = np.log(np.sum(
            
            train[y_train==inv_labels[i]]) + alpha*voc_size)
        counts[i] -= cc*np.ones(counts[i].shape)
    return counts

def calc_test_clf(test, prior, counts):
    score = np.reshape(np.tile(prior, test.shape[0]), (test.shape[0], len(prior))) + test*counts.T
    return score

def predict_clf(score, inv_labels):
    i_test = score.argmax(axis=1)
    y_predicted = np.ndarray(i_test.shape, dtype=object)
    for i in range(len(y_predicted)):
        y_predicted[i] = inv_labels[i_test[i]]
    return y_predicted

        

def classify_onemore(X_train, X_test, y_train, y_test, show_data = 0, min_df = 1, alpha = 0.05, 
                     tokenizer = None, stop_words = stop_words, preprocessor=None):
    #get labels and priors
    categories = np.unique(y_train, return_counts=True)
    n = len(categories[0])
    labels = dict(zip(categories[0], range(n)))
    inv_labels = categories[0]
    prior = np.log(categories[1]) - np.log(len(y_train))
    #training
    counter = CountVectorizer(analyzer = 'word', tokenizer = tokenizer, binary=True, 
                              min_df = min_df, stop_words = stop_words, preprocessor=preprocessor)
    train = counter.fit_transform(X_train)
    counts = train_clf(train, y_train, alpha, inv_labels)
    #classify
    test = counter.transform(X_test)
    score = calc_test_clf(test, prior, counts)
    y_predicted = predict_clf(score, inv_labels)
    
    show_predicted(X_test, y_test, y_predicted, inv_labels, show_data)     
        
        
classify_onemore(X_train, X_test, y_train, y_test, show_data=25)
# Out:
# Predicted data sample
#                                                     X         y y_predicted
# 0   Не було сказано, що є дефект. Ціна нормальна Р...   neutral    negative
# 1   Купував на подарунок, але купив би і собі. Над...  positive    negative
# 2   Купив недавно, інструкція зрозуміла, швидко ро...  positive    negative
# 3   я хочу ксвомашину щоб робити капучіно, лате як...   neutral     neutral
# 4    Хороша та якісна мікрохвильовка за такі гроші.    positive    positive
# 5   Я не раджу купувати цю вафельницю. Саме перше ...  negative    negative
# 6   Обирала блендер з декількох моделей, купувала ...  positive    positive
# 7   сподобався, приємний, міцний. Не смердить плас...  positive    negative
# 8   Скажіть чи є змінні пластини для цієї моделі? ...   neutral     neutral
# 9   Чому після розігріву їжі мікрохвильовка продов...   neutral    positive
# 10  Доброго дня. Хочу спитати чи підходить цей мік...   neutral     neutral
# 11  Купували в подарунок мамі. Їй все подобається....  positive    positive
# 12  Толковий тостер. Металевий корпус (сіре на фот...   neutral    negative
# 13  дякуємо від усієї сім'ї Швидко доставили, гарн...   neutral    positive
# 14  Довго вибирала між блендером Kenwood з двома ш...  positive    positive
# 15    тількі для дтячого сирочку ціна мала потужність  positive    negative
# 16  Кофеварка сподобалась. Все пряцює, готує каву ...  positive     neutral
# 17  Класна плитка! Все працює, дуже зручна! Якісна...  positive    positive
# 18  Користуємся десь дві неділі. Зламалась нижня ч...  negative    negative
# 19  Має і низькі швидкості і високі, зручний, легк...  positive    positive
# 20  Дуже задоволена покупкою, 5 хвилин-і смачна фр...  positive     neutral
# 21  Чудова піч. Користуюсь рік майже щоденно. Проб...  positive    positive
# 22  ха свою цену норма) цена воняет пластиком, про...  negative    positive
# 23           гарний ,якісний товар дизайн,швидкість,   positive    positive
# 24  Замовив електрочайник 15 листопада 2017 року. ...   neutral    negative
#                         X
# y        y_predicted
# negative negative      41
#          neutral        6
#          positive       8
# neutral  negative      67
#          neutral       96
#          positive      83
# positive negative      51
#          neutral       42
#          positive     160
#
# Classification report
# ['negative' 'neutral' 'positive']
# [159 144 251]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.26      0.75      0.38        55
#     neutral       0.67      0.39      0.49       246
#    positive       0.64      0.63      0.63       253
#
# avg / total       0.61      0.54      0.55       554

# %%
# cutting with min_df makes worse classification of the smaller category
classify_onemore(X_train, X_test, y_train, y_test, min_df = 5)
# Out:
#                         X
# y        y_predicted
# negative negative      15
#          neutral       19
#          positive      21
# neutral  negative      11
#          neutral      125
#          positive     110
# positive negative       6
#          neutral       54
#          positive     193
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 32 198 324]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.47      0.27      0.34        55
#     neutral       0.63      0.51      0.56       246
#    positive       0.60      0.76      0.67       253
#
# avg / total       0.60      0.60      0.59       554

# %%
classify_onemore(X_train, X_test, y_train, y_test, tokenizer = tokenize_lemmatize_negate, stop_words = stop_words,
                show_data = 10)
# Out:
# Predicted data sample
#                                                    X         y y_predicted
# 0  Не було сказано, що є дефект. Ціна нормальна Р...   neutral    positive
# 1  Купував на подарунок, але купив би і собі. Над...  positive    negative
# 2  Купив недавно, інструкція зрозуміла, швидко ро...  positive    positive
# 3  я хочу ксвомашину щоб робити капучіно, лате як...   neutral     neutral
# 4   Хороша та якісна мікрохвильовка за такі гроші.    positive    positive
# 5  Я не раджу купувати цю вафельницю. Саме перше ...  negative     neutral
# 6  Обирала блендер з декількох моделей, купувала ...  positive    positive
# 7  сподобався, приємний, міцний. Не смердить плас...  positive     neutral
# 8  Скажіть чи є змінні пластини для цієї моделі? ...   neutral     neutral
# 9  Чому після розігріву їжі мікрохвильовка продов...   neutral     neutral
#                         X
# y        y_predicted
# negative negative      38
#          neutral        7
#          positive      10
# neutral  negative      29
#          neutral      111
#          positive     106
# positive negative      19
#          neutral       47
#          positive     187
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 86 165 303]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.44      0.69      0.54        55
#     neutral       0.67      0.45      0.54       246
#    positive       0.62      0.74      0.67       253
#
# avg / total       0.62      0.61      0.60       554

# %% [markdown]
# ## With sentiment dictionary

# %%
class SentimentDict:
    def __init__(self, sd):
        self.sd = sd
        
    
    def get_vector(self, vocabulary, analyzer, condition = None):
        v = np.zeros(len(vocabulary))
        for key, value in self.sd.items():
            w = analyzer(key)[0]
            nw = analyzer('не '+ key)[0]
            if w in vocabulary:
                if condition == None or condition(value):
                    v[vocabulary[w]] += value
            if nw in vocabulary:
                if condition == None or condition(-value):
                    v[vocabulary[nw]] += -value
                    
        return v

   
sd=pd.read_csv('C:\\work\\jul\\prj-nlp\\students\\juliamakogon\\task_05\\tone-dict-uk.tsv', sep='\t',header=None)
    
sd_dict = dict(zip(sd.to_dict()[0].values(), sd.to_dict()[1].values()))

# %% [markdown]
# **Only on tonal dictionary**

# %%
def classify_sentiment(X_train, X_test, y_train, y_test, sd = {}, show_data = 0, min_df = 1, 
                     tokenizer = None, stop_words = stop_words, preprocessor=None):
    #get labels and priors
    categories = np.unique(y_train, return_counts=True)
    n = len(categories[0])
    labels = dict(zip(categories[0], range(n)))
    inv_labels = categories[0]
    #training
    counter = CountVectorizer(analyzer = 'word', tokenizer = tokenizer, binary=True, 
                              min_df = min_df, stop_words = stop_words, preprocessor=preprocessor)
    train = counter.fit_transform(X_train)
    sdict = SentimentDict(sd)
    sentiment = sdict.get_vector(counter.vocabulary_, tokenizer)
    sent_score = (sentiment*train.T)
    sent_borders = np.ndarray(n-1)
    means = [np.mean(sent_score[y_train == inv_labels[i]]) for i in range(n)]
    sent_borders[0] = min(-0.05, 0.5*(means[labels['negative']] + means[labels['neutral']]))
    sent_borders[1] = max(0.5, 0.5*(means[labels['positive']] + means[labels['neutral']]))
    #classify
    test = counter.transform(X_test)
    sent_score = (sentiment*test.T)
    sent_predicted = y_test.copy()
    for i in range(sent_predicted.shape[0]):
        k = n-1
        while k > 0 and sent_score[i] < sent_borders[k-1]:
            k -= 1
        sent_predicted[i] = inv_labels[k] # hook, but ok
    show_predicted(X_test, y_test, sent_predicted, inv_labels, show_data)    
    
# the result is better with remove_questions preprocessor
classify_sentiment(X_train, X_test, y_train, y_test, sd_dict, tokenizer = tokenize_lemmatize_negate, stop_words = stop_words,
                   preprocessor=remove_questions,
                show_data = 10 )
# Out:
# Predicted data sample
#                                                    X         y y_predicted
# 0  Не було сказано, що є дефект. Ціна нормальна Р...   neutral    negative
# 1  Купував на подарунок, але купив би і собі. Над...  positive    positive
# 2  Купив недавно, інструкція зрозуміла, швидко ро...  positive    positive
# 3  я хочу ксвомашину щоб робити капучіно, лате як...   neutral     neutral
# 4   Хороша та якісна мікрохвильовка за такі гроші.    positive    positive
# 5  Я не раджу купувати цю вафельницю. Саме перше ...  negative     neutral
# 6  Обирала блендер з декількох моделей, купувала ...  positive    negative
# 7  сподобався, приємний, міцний. Не смердить плас...  positive    positive
# 8  Скажіть чи є змінні пластини для цієї моделі? ...   neutral     neutral
# 9  Чому після розігріву їжі мікрохвильовка продов...   neutral     neutral
#                         X
# y        y_predicted
# negative negative      18
#          neutral       32
#          positive       5
# neutral  negative      27
#          neutral      165
#          positive      54
# positive negative      28
#          neutral      107
#          positive     118
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 73 304 177]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.25      0.33      0.28        55
#     neutral       0.54      0.67      0.60       246
#    positive       0.67      0.47      0.55       253
#
# avg / total       0.57      0.54      0.54       554

# %% [markdown]
# **Combining decisions of classifiers: boosting the decision of MultinomialNB by tonal dictionary with beta**

# %%
def classify_weighted_sentiment(X_train, X_test, y_train, y_test, sd = {}, show_data = 0, min_df = 1, 
                     tokenizer = None, stop_words = stop_words, preprocessor=None, alpha = 0.05, beta = 0.5):
    #get labels and priors
    categories = np.unique(y_train, return_counts=True)
    n = len(categories[0])
    labels = dict(zip(categories[0], range(n)))
    inv_labels = categories[0]
    prior = np.log(categories[1]) - np.log(len(y_train))
    #training
    counter = CountVectorizer(analyzer = 'word', tokenizer = tokenizer, binary=True, 
                              min_df = min_df, stop_words = stop_words, preprocessor=preprocessor)
    train = counter.fit_transform(X_train)
    sdict = SentimentDict(sd)
    sentiment = sdict.get_vector(counter.vocabulary_, tokenizer)
    sent_score = (sentiment*train.T)
    sent_borders = np.ndarray(n-1)
    means = [np.mean(sent_score[y_train == inv_labels[i]]) for i in range(n)]
    sent_borders[0] = min(-0.05, 0.5*(means[labels['negative']] + means[labels['neutral']]))
    sent_borders[1] = max(0.5, 0.5*(means[labels['positive']] + means[labels['neutral']]))
    counts = train_clf(train, y_train, alpha, inv_labels)    
    #classify
    test = counter.transform(X_test)
    sent_score = (sentiment*test.T)
    score = calc_test_clf(test, prior, counts)
    sent_predicted = y_test.copy()
    for i in range(sent_predicted.shape[0]):
        k = n-1
        while k > 0 and sent_score[i] < sent_borders[k-1]:
            k -= 1
        sent_predicted[i] = k
    sent_p = sent_score.copy()
    score = np.exp(score)
    for i in range(n):
        min_ = min(sent_score[sent_predicted==i])
        max_ = max(sent_score[sent_predicted==i])
        sent_p[sent_predicted==i] = (sent_score[sent_predicted==i] - min_)/(max_-min_)
    max_ = np.max(score, axis=1)
    max_[max_ < 1e-30] = 1
    for i in range(n):
        score[:, i] = score[:, i]/max_
    for i in range(score.shape[1]):
        score[i, sent_predicted[i]] += beta*sent_p[i]
    y_predicted = predict_clf(score, inv_labels)
    show_predicted(X_test, y_test, y_predicted, inv_labels, show_data)
    
    
classify_weighted_sentiment(X_train, X_test, y_train, y_test, sd_dict, 
                            tokenizer = tokenize_lemmatize_negate, stop_words = stop_words, 
                            show_data = 30 )
# Out:
# Predicted data sample
#                                                     X         y y_predicted
# 0   Не було сказано, що є дефект. Ціна нормальна Р...   neutral    negative
# 1   Купував на подарунок, але купив би і собі. Над...  positive    negative
# 2   Купив недавно, інструкція зрозуміла, швидко ро...  positive    positive
# 3   я хочу ксвомашину щоб робити капучіно, лате як...   neutral     neutral
# 4    Хороша та якісна мікрохвильовка за такі гроші.    positive    positive
# 5   Я не раджу купувати цю вафельницю. Саме перше ...  negative     neutral
# 6   Обирала блендер з декількох моделей, купувала ...  positive    positive
# 7   сподобався, приємний, міцний. Не смердить плас...  positive     neutral
# 8   Скажіть чи є змінні пластини для цієї моделі? ...   neutral     neutral
# 9   Чому після розігріву їжі мікрохвильовка продов...   neutral     neutral
# 10  Доброго дня. Хочу спитати чи підходить цей мік...   neutral     neutral
# 11  Купували в подарунок мамі. Їй все подобається....  positive    positive
# 12  Толковий тостер. Металевий корпус (сіре на фот...   neutral     neutral
# 13  дякуємо від усієї сім'ї Швидко доставили, гарн...   neutral    positive
# 14  Довго вибирала між блендером Kenwood з двома ш...  positive    positive
# 15    тількі для дтячого сирочку ціна мала потужність  positive    positive
# 16  Кофеварка сподобалась. Все пряцює, готує каву ...  positive    positive
# 17  Класна плитка! Все працює, дуже зручна! Якісна...  positive    positive
# 18  Користуємся десь дві неділі. Зламалась нижня ч...  negative    negative
# 19  Має і низькі швидкості і високі, зручний, легк...  positive     neutral
# 20  Дуже задоволена покупкою, 5 хвилин-і смачна фр...  positive    positive
# 21  Чудова піч. Користуюсь рік майже щоденно. Проб...  positive    positive
# 22  ха свою цену норма) цена воняет пластиком, про...  negative    positive
# 23           гарний ,якісний товар дизайн,швидкість,   positive    positive
# 24  Замовив електрочайник 15 листопада 2017 року. ...   neutral    negative
# 25  Дуже хороша кавоварка , п'ю смачну каву з цієї...   neutral    positive
# 26  Робив сік з яблук, вийшла пюрешка. Не те що хо...  positive     neutral
# 27  За півроку експлуатації кавоваркою повністю за...  positive    positive
# 28  За свою ціну хороша річ, єдине, могли б заміст...  positive    positive
# 29  користуюсь 6 міс. рідкий об'єм більше 1 л вже ...  negative    negative
#                         X
# y        y_predicted
# negative negative      38
#          neutral        7
#          positive      10
# neutral  negative      31
#          neutral      111
#          positive     104
# positive negative      19
#          neutral       47
#          positive     187
#
# Classification report
# ['negative' 'neutral' 'positive']
# [ 88 165 301]
# [ 55 246 253]
#              precision    recall  f1-score   support
#
#    negative       0.43      0.69      0.53        55
#     neutral       0.67      0.45      0.54       246
#    positive       0.62      0.74      0.68       253
#
# avg / total       0.63      0.61      0.60       554

# %% [markdown]
# **Conclusion:** Boosting Naive Bayes classifier with a tonal dictionary can improve the classification quality. There is some limitation to quality measurement on this dataset because many, especially positive, feedbacks are marked as neutral.
